# %% [markdown]
# ## Bibliotecas e carregamento de arquivo

# %%
import pandas as pd
import numpy as np
import re
import requests
import os
from bs4 import BeautifulSoup
import unidecode
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter

df = pd.read_csv('01-MF.csv')

# %% [markdown]
# ## Formatação / limpeza

# %%
columns = [
        'ID', 'Perfil', 'Nome', 'Nome Completo', 'URL Nome Completo', 'Repetido Nome', 'Posição',
        'Idade', 'Valor de Mercado', 'Nacionalidade', 'URL Clube Antigo', 'Vazio 1', 'URL Clube Antigo Repetido',
        'Vazio 2', 'URL Clube Antigo Repetido 2', 'Clube Antigo', 'URL Liga Antiga', 'Liga Antiga',
        'URL Clube Novo', 'Vazio 3', 'URL Clube Novo Repetido', 'Vazio 4', 'URL Clube Novo Repetido 2',
        'Clube Novo', 'URL Liga Nova', 'Liga Nova', 'Valor Transferência'
    ]
df.columns = columns

# Função para mover os valores para a direita se não houver '/' na coluna 'URL da linha antiga'
def shift_row_if_no_slash(row, col_name):
    # Verifica se não contém '/' na coluna especificada
    if '/' not in str(row[col_name]):
        # Move valores a partir da coluna especificada uma posição à direita
        row.loc[col_name:] = row.loc[col_name:].shift(1)
    return row

df.drop('Vazio 1', axis=1, inplace=True)
df.drop('Vazio 2', axis=1, inplace=True)
df.drop('URL Clube Antigo Repetido', axis=1, inplace=True)
df.drop('URL Clube Antigo Repetido 2', axis=1, inplace=True)

df = df.apply(lambda row: shift_row_if_no_slash(row, 'URL Liga Antiga'), axis=1)

df.drop('Vazio 3', axis=1, inplace=True)
df.drop('Vazio 4', axis=1, inplace=True)
df.drop('URL Clube Novo Repetido', axis=1, inplace=True)
df.drop('URL Clube Novo Repetido 2', axis=1, inplace=True)

df = df.apply(lambda row: shift_row_if_no_slash(row, 'URL Liga Nova'), axis=1)

df.drop('URL Nome Completo', axis=1, inplace=True)
df.drop('Nome Completo', axis=1, inplace=True)
df.drop('Repetido Nome', axis=1, inplace=True)


df['ID'] = df['Perfil'].str.extract(r'/(\d+)$')
df['ID'] = df['ID'].astype(int)

# Filtra as linhas que não contêm 'transfer' ou '?' na coluna 'Valor Transferencia'
df = df[~df['Valor Transferência'].str.contains(r'loan|draft|\?', case=False, na=False)]
df['Valor Transferência'] = df['Valor Transferência'].replace('free transfer', 0)
df['Valor de Mercado'] = df['Valor de Mercado'].replace('-',1)

print(df['Valor Transferência'].unique())
# Out:
# ['€15.00m' '€13.00m' '€7.50m' 0 '€6.00m' '€3.00m' '€4.00m' '€1.25m'
#  '€4.75m' '€4.50m' '€3.50m' '€341k' '€300k' '€70k' '€100k' '€170k'
#  '€2.35m' '€1.70m' '€200k' '€1.80m' '€1.10m' '€1.65m' '€350k' '€1.50m'
#  '€1.20m' '€850k' '€330k' '€700k' '€600k' '€220k' '€28.00m' '€14.00m'
#  '€11.50m' '€11.00m' '€9.00m' '€8.00m' '€7.20m' '€5.00m' '€2.00m' '€520k'
#  '€3.10m' '€3.44m' '€450k' '€120k' '€250k' '€209k' '€190k' '€12k' '€37k'
#  '€915k' '€2.65m' '€2.40m' '€1.30m' '€2.20m' '€1.82m' '€500k' '€1.00m'
#  '€671k' '€1.36m' '€620k' '€237k' '€750k' '€375k' '€245k' '€60.00m'
#  '€18.50m' '€12.50m' '€9.50m' '€9.20m' '€7.00m' '€2.50m' '€180k' '€75k'
#  '€3.30m' '€400k' '€1.42m' '€730k' '€150k' '€135.00m' '€40.00m' '€12.00m'
#  '€10.00m' '€5.70m' '€2.55m' '€175k' '€255k' '€275k' '0' '€110k' '€38k'
#  '€2.70m' '€340k' '€1.27m' '€125k' '€50k' '€966k' '€800k' '€260k' '€130k'
#  '€25k' '€59.00m' '€45.00m' '€42.00m' '€38.40m' '€31.00m' '€19.20m'
#  '€10.50m' '€9.60m' '€6.60m' '€5.10m' '€4.90m' '€4.80m' '€20k' '€460k'
#  '€115k' '€145k' '€35k' '€150' '€2.52m' '€2.30m' '€1.02m' '€1.26m'
#  '€1.18m' '€910k' '€235k' '€650k' '€43.50m' '€30.00m' '€22.00m' '€20.00m'
#  '€16.80m' '€295k' '€165k' '€84k' '€2.85m' '€1.55m' '€1.35m' '€680k'
#  '€670k' '€80.60m' '€24.60m' '€20.30m' '€23.00m' '€8.25m' '€7.60m'
#  '€6.47m' '€3.64m' '€3.60m' '€60k' '€10k' '€1.60m' '€1.33m' '€2.27m'
#  '€550k' '€30k' '€42.10m' '€20.50m' '€18.00m' '€6.50m' '€3.92m' '€1.85m'
#  '€3.20m' '€455k' '€160k' '€70.65m' '€42.95m' '€18.70m' '€22.90m' '€55k'
#  '€291k' '€1.48m' '€900k' '€270k' '€80k' '€46.70m' '€9.74m' '€8.20m'
#  '€5.50m' '€4.21m' '€225k' '€95k' '€67k' '€3.75m' '€1.31m' '€940k' '€320k'
#  nan '€1.40m' '€372k' '€832k' '€565k' '€745k' '€580k' '€276k' '€430k'
#  '€557k' '€51.50m' '€8.50m' '€4.55m' '€4.10m' '€5k' '€78k' '€523k' '€465k'
#  '€66k' '€4k' '€1.89m']

# %%
# Função para converter os valores de string para numéricos
def convert_value(val):
    if isinstance(val, str):
        # Remove o símbolo '€'
        val = val.replace('€', '')
        # Converte valores com 'm' (milhões) para números
        if 'm' in val:
            return float(val.replace('m', '')) * 1000000
        # Converte valores com 'k' (milhares) para números
        elif 'k' in val:
            return float(val.replace('k', '')) * 1000
        # Se for só um número sem 'm' ou 'k', retorna o número como float
        else:
            return float(val)
    return val

# Aplica a função a toda a coluna 'Valor Transferência'

df['Valor Transferência'] = df['Valor Transferência'].apply(convert_value)
# Converte a coluna para tipo numérico, caso ainda tenha algum valor não numérico
df['Valor Transferência'] = pd.to_numeric(df['Valor Transferência'], errors='coerce')

df['Valor de Mercado'] = df['Valor de Mercado'].apply(convert_value)
df['Valor de Mercado'] = pd.to_numeric(df['Valor de Mercado'], errors='coerce')

# Exibe os valores únicos após a conversão
#print(df['Valor Transferência'].unique())
df['Ano da Tranferência'] = df['URL Clube Antigo'].str.extract(r'.*/(\d+)$')
df.to_csv('02-MF.csv', index=False)

# %% [markdown]
# ## Gráficos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Agrupamento de dados
agrupado_temp = df.groupby('Ano da Tranferência').size()

# Configurar o estilo do gráfico
sns.set(style="whitegrid")

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x=agrupado_temp.index, y=agrupado_temp.values, palette="viridis")

# Adicionar título e rótulos aos eixos
plt.title('Número de Transferências de Defensores por Temporada')
plt.xlabel('Temporada')
plt.ylabel('Número de Transferências')

# Rotacionar os rótulos do eixo x para melhor visualização
plt.xticks(rotation=45)

# Adicionar os valores em cima de cada barra
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.0f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', 
                     xytext = (0, 9), 
                     textcoords = 'offset points')

# Mostrar o gráfico
plt.show()

# %%
# Filtrar jogadores com valor de mercado e valor de transferência maiores que zero
filtered_df = df[(df['Valor de Mercado'] > 0) & (df['Valor Transferência'] > 0)]

# Criar o vetor de índices para o eixo x
x = range(len(filtered_df))  # Índice para o eixo x

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
plt.plot(x, filtered_df['Valor de Mercado'], label='Valor de Mercado', marker='o', linestyle='-', color='blue')
plt.plot(x, filtered_df['Valor Transferência'], label='Valor Transferência', marker='o', linestyle='-', color='orange')

# Adicionando título e rótulos
plt.title('Comparação entre Valor de Mercado e Valor de Transferência')
plt.xlabel('Jogadores (Index)')
plt.ylabel('Valor (em Euros)')
plt.legend()
plt.grid(True)

# Exibir o gráfico
plt.show()

# %%
# Filtrar jogadores com valor de mercado e valor de transferência maiores que zero
filtered_df = df[(df['Valor de Mercado'] >5) & (df['Valor Transferência'] > 5)]

# Função para remover outliers
def remove_outliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    return data[(data >= (Q1 - 1.5 * IQR)) & (data <= (Q3 + 1.5 * IQR))]

# Remover outliers
filtered_df['Valor de Mercado'] = remove_outliers(filtered_df['Valor de Mercado'])
filtered_df['Valor Transferência'] = remove_outliers(filtered_df['Valor Transferência'])

# Criar uma figura
plt.figure(figsize=(4, 6))

# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar box plots
sns.boxplot(data=filtered_df[['Valor de Mercado', 'Valor Transferência']])

# Ajustar limites do eixo y
plt.ylim(0, filtered_df[['Valor de Mercado', 'Valor Transferência']].max().max() * 1.1)

# Adicionando título e rótulos
plt.title('Box Plot de Valor de Mercado e Valor de Transferência (sem outliers)')
plt.ylabel('Valor (em Milhões de Euros)')
plt.xticks([0, 1], ['Valor de Mercado', 'Valor de Transferência'])

# Função para formatar o eixo y em milhões
def millions(x, pos):
    return f'{int(x / 1_000_000)}M'

# Aplicar a formatação ao eixo y
formatter = FuncFormatter(millions)
plt.gca().yaxis.set_major_formatter(formatter)

# Exibir o gráfico
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_21644\1447094067.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Valor de Mercado'] = remove_outliers(filtered_df['Valor de Mercado'])
# C:\Users\User\AppData\Local\Temp\ipykernel_21644\1447094067.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Valor Transferência'] = remove_outliers(filtered_df['Valor Transferência'])

# %% [markdown]
# ## Transfers

# %%
url_site = "https://www.transfermarkt.us/" ## https://www.transfermarkt.us/Jan-Oblak/leistungsdatendetails/spieler/121483 ## https://www.transfermarkt.us/Jan-Oblak/leistungsdatendetails/spieler/121483/saison/2014/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 ## https://www.transfermarkt.us/Jan-Oblak/transfers/spieler/121483/transfer_id/1087965

# Get headers from https://www.whatismybrowser.com/detect/what-http-headers-is-my-browser-sending
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
}

# %%
# Definir a função
def get_home(nome_hifen, id):
    url_principal = url_site + str(nome_hifen) + "/leistungsdatendetails/spieler/" + str(id)
    response = requests.get(url_principal, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    print(url_principal)
   
    # Inicializar valores padrão
    date_of_birth = "N/A"
    place_of_birth = "N/A"
    citizenship = "N/A"
    height = "N/A"
    caps = "0"
    goals = "0"

    # Extrai a data de nascimento/idade
    birth_date_elem = soup.find('span', itemprop='birthDate')
    if birth_date_elem:
        date_of_birth = birth_date_elem.get_text(strip=True)

    # Extrai o local de nascimento
    birth_place_elem = soup.find('span', itemprop='birthPlace')
    if birth_place_elem:
        place_of_birth = birth_place_elem.get_text(strip=True)

    # Extrai a cidadania
    citizenship_elem = soup.find('span', itemprop='nationality')
    if citizenship_elem:
        citizenship = citizenship_elem.get_text(strip=True)

    # Extrai a altura
    height_elem = soup.find('span', itemprop='height')
    if height_elem:
        height = height_elem.get_text(strip=True)

    # Extrai Caps/Goals
    highlight_elems = soup.find_all('a', class_='data-header__content--highlight')
    if len(highlight_elems) > 1:
        caps = highlight_elems[0].get_text(strip=True)
        goals = highlight_elems[1].get_text(strip=True)
        
    #####    PE_FAVORITO
    url_profile = url_site + str(nome_hifen) + "/profil/spieler/" + str(id)
    print(url_profile)
    response = requests.get(url_profile, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")

    # Encontra o elemento que contém a informação sobre o pé
    foot_element = soup.find('span', class_='info-table__content info-table__content--regular', text='Foot:')

    if foot_element:
        # O próximo irmão (o conteúdo que está em <span class="info-table__content info-table__content--bold">)
        foot_value = foot_element.find_next_sibling('span', class_='info-table__content info-table__content--bold').text
        print(f'Foot: {foot_value}')
    else:
        foot_value = "N/A"
        print('NA')
    #####    #####    #####    #####    #####    #####    #####    

    # Dados extraídos em uma lista
    data = [
        id,
        nome_hifen,
        foot_value,
        date_of_birth,
        place_of_birth,
        citizenship,
        height,
        caps,
        goals
        ]
    return data

# %%
def get_stats(nome_hifen, id, ano):
    ano = int(ano) - 1

    url_detalhada = url_site + str(nome_hifen) + "/leistungsdatendetails/spieler/" + str(id) + "/saison/20" + str(ano) + "/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1"
    response = requests.get(url_detalhada, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    data = []
    print(url_detalhada)
    
    # Encontrar a tabela
    table = soup.find('table', class_='items')

                
    if table:
        # Extrair todas as linhas da tabela
        rows = table.find_all('tr')

        # Inicializar variáveis
        escalado = jogou = ppm = gols_para = assistencias = gols_contra = entrou = saiu = amarelo = amarelo_duplo = vermelho = gols_de_penalti = minutos_por_gol = minutos = "0"

        # Identificar a última linha que contém o texto "Total"
        for row in rows:
            if 'Total' in row.text:
                cols = row.find_all('td')
                if len(cols) > 1:  # Verifique se a linha não está vazia
                    escalado = cols[3].get_text(strip=True)
                    jogou = cols[4].get_text(strip=True)
                    ppm = cols[5].get_text(strip=True)
                    gols_para = cols[6].get_text(strip=True)
                    assistencias = cols[7].get_text(strip=True)
                    gols_contra = cols[8].get_text(strip=True)
                    entrou = cols[9].get_text(strip=True)
                    saiu = cols[10].get_text(strip=True)
                    amarelo = cols[11].get_text(strip=True)
                    amarelo_duplo = cols[12].get_text(strip=True)
                    vermelho = cols[13].get_text(strip=True)
                    gols_de_penalti = cols[14].get_text(strip=True)
                    minutos_por_gol = cols[15].get_text(strip=True)
                    minutos = cols[16].get_text(strip=True)
    else:
        # Definir todas as variáveis como "0" se a tabela não for encontrada
        escalado = jogou = ppm = gols_para = assistencias = gols_contra = entrou = saiu = amarelo = amarelo_duplo = vermelho = gols_de_penalti = minutos_por_gol = minutos = "0"
                
    # Dados extraídos em uma lista
    data = [
        id,
        ano,
        escalado,
        jogou,
        ppm, 
        gols_para,
        assistencias,
        gols_contra,
        entrou,
        saiu,
        amarelo,
        amarelo_duplo,
        vermelho,
        gols_de_penalti,
        minutos_por_gol,
        minutos
    ]
    return data

# %%
def get_transfer(nome_hifen, id, tid):
    url_transferencia = url_site + str(nome_hifen) + "/transfers/spieler/" + str(id) + "/transfer_id/" + str(tid)
    response = requests.get(url_transferencia, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    print(url_transferencia)
    
    def get_text_or_empty(element):
        return element.get_text(strip=True) if element else ""

    # Extrair dados relevantes
    transfer_details_div = soup.find("div", class_="box", id=tid)

    # Transfer date and season
    transfer_date_season = get_text_or_empty(transfer_details_div.find("tr", class_="table-highlight").find("td"))
    transfer_date_season = transfer_date_season.replace("Transfer dateSeason", "").strip()
    season, date = transfer_date_season.split(" -")   

    #Ex-clube  +  #Liga do ex-clube
    ex_club = get_text_or_empty(transfer_details_div.find("td", class_="zentriert hauptlink no-border-rechts"))
    ex_club_league = get_text_or_empty(transfer_details_div.find_all("tr")[2].find("td"))
    
    # Novo clube +  # Liga do novo clube
    new_club = get_text_or_empty(transfer_details_div.find("td", class_="zentriert hauptlink no-border-links"))
    new_club_league = get_text_or_empty(transfer_details_div.find_all("tr")[2].find_all("td")[2])
      
    # Encontra todos os <td> com a classe 'zentriert' e colspan '3'
    td_elements = transfer_details_div.find_all('td', class_='zentriert', colspan='3')

    # Percorre os elementos encontrados para verificar o texto interno - Market value at time of transfer
    market_value = None
    for td in td_elements:
        if 'Market value at time of transfer' in td.get_text():
            # Extrai o valor em euro do <td>
            text = td.get_text(strip=True)
            market_value = text.split('€')[-1].strip()
            break

    # Percorre os elementos encontrados para verificar o texto interno - Age at time of transfer
    idade_transfer = None
    for td in td_elements:
        if 'Age at time of transfer' in td.get_text():
            # Extrai a idade na transferencia <td>
            idade_transfer = td.get_text(strip=True)
            idade_transfer = idade_transfer.replace("Age at time of transfer", "").strip()
            break
    
    # Percorre os elementos encontrados para verificar o texto interno - Remaining contract duration at
    contrato_rest = None
    for td in td_elements:
        if 'Remaining contract duration at' in td.get_text():
            # Extrai a idade na transferencia <td>
            contrato_rest = td.get_text(strip=True)
            contrato_rest = contrato_rest.replace("Remaining contract duration at", "").strip()
            contrato_rest = contrato_rest.replace(str(ex_club), "").strip()
            contrato_rest = contrato_rest.split('(')[0].strip()
            break
    
    # Taxa de transferência
    transfer_fee = get_text_or_empty(transfer_details_div.find_all("tr")[-1].find("p", class_="hauptfact"))

    # Dados extraídos em um dicionário
    transfer_data = [
        id,
        tid,
        season,
        date,
        ex_club, 
        ex_club_league,
        new_club,
        new_club_league,
        market_value,
        idade_transfer,
        contrato_rest,
        transfer_fee
    ]
    return transfer_data

# %%
from datetime import datetime
# Obtém a hora atual
hora_atual = datetime.now()
hora_formatada = hora_atual.strftime("%H:%M:%S")
print("Hora Inicial:", hora_formatada)

# Definir os nomes das colunas
home_columns = ["ID", "nome_hifen", "pe", "data_nasc", "local_nasc", "cidadania", "altura", "convocacoes", "gols_selecao"]
stats_columns = ["ID", "ano_stat", "escalado", "jogou", "ppm", "gols_para", "assistencias", "gols_contra", "entrou", "saiu", "amarelo", "amarelo_duplo", "vermelho", "Gols_de_penalti", "minutos_por_gol", "minutos"]
transfer_columns = ["ID","tid", "Temporada", "Data", "Ex-clube", "Liga do ex-clube", "Novo_clube", "L_novo_clube", "VdM_epoca", "Idade_transfer", "Duração restante do contrato", "Taxa de transferência"]

df_home = pd.DataFrame(columns=home_columns)
df_stats = pd.DataFrame(columns=stats_columns)
df_transfer = pd.DataFrame(columns=transfer_columns)
print("AGORA VEM O LOOP")

# Loop através de cada linha do DataFrame Id_Temp
for index, row in Nome_Id_Temp.iterrows():
    nome_val = row['Nome'].strip().replace(' ', '-')
    nome_val = nome_val.replace('\'', '')
    nome_val = nome_val.replace('.', '')
    nome_val = unidecode.unidecode(nome_val)
    id_val = row['ID']
    tid_val = row['T_ID']
    ano = row['Temp'].split('/')[0]  # Pegar o ano antes da barra

    
    print(f'\n Dados de {nome_val}')
    lista_home=get_home(nome_val, id_val)
    #print(f'{lista_home}')
    
    lista_stats=get_stats(nome_val, id_val, ano)
    #print(f'{lista_stats}')

    lista_transfer = get_transfer(nome_val, id_val, tid_val)
    #print(f'{lista_transfer}')
    
    # New list for append into df
    df_home.loc[len(df_home)] = lista_home
    df_stats.loc[len(df_stats)] = lista_stats
    df_transfer.loc[len(df_transfer)] = lista_transfer

df_home=df_home.drop_duplicates()
df_stats=df_stats.drop_duplicates()
df_transfer=df_transfer.drop_duplicates()

df_home.to_csv('dt_home_22.csv', index=True)
df_stats.to_csv('dt_stats_22.csv', index=True)
df_transfer.to_csv('dt_transfer_22.csv', index=True)

    
# Realizar o merge dos DataFrames
#merged_df = df_home.merge(df_stats, on='ID').merge(df_transfer, on='ID')

# DataFrame final
#merged_df.to_csv('dados_transferencias.csv', index=True)

# Obtém a hora atual
hora_atual = datetime.now()
hora_formatada = hora_atual.strftime("%H:%M:%S")
print("Hora Final:", hora_formatada)
# Out:
# Hora Inicial: 13:55:17
# AGORA VEM O LOOP
#
#  Dados de Enzo-Fernandez
# https://www.transfermarkt.us/Enzo-Fernandez/leistungsdatendetails/spieler/648195
# https://www.transfermarkt.us/Enzo-Fernandez/profil/spieler/648195
# Foot: right
# https://www.transfermarkt.us/Enzo-Fernandez/leistungsdatendetails/spieler/648195/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Enzo-Fernandez/transfers/spieler/648195/transfer_id/4254228
#
#  Dados de Aurelien-Tchouameni
# https://www.transfermarkt.us/Aurelien-Tchouameni/leistungsdatendetails/spieler/413112
# https://www.transfermarkt.us/Aurelien-Tchouameni/profil/spieler/413112
# Foot: right
# https://www.transfermarkt.us/Aurelien-Tchouameni/leistungsdatendetails/spieler/413112/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Aurelien-Tchouameni/transfers/spieler/413112/transfer_id/3882196
#
#  Dados de Casemiro
# https://www.transfermarkt.us/Casemiro/leistungsdatendetails/spieler/16306
# https://www.transfermarkt.us/Casemiro/profil/spieler/16306
# Foot: right
# https://www.transfermarkt.us/Casemiro/leistungsdatendetails/spieler/16306/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Casemiro/transfers/spieler/16306/transfer_id/4025542
#
#  Dados de Kalvin-Phillips
# https://www.transfermarkt.us/Kalvin-Phillips/leistungsdatendetails/spieler/351749
# https://www.transfermarkt.us/Kalvin-Phillips/profil/spieler/351749
# Foot: right
# https://www.transfermarkt.us/Kalvin-Phillips/leistungsdatendetails/spieler/351749/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Kalvin-Phillips/transfers/spieler/351749/transfer_id/3919572
#
#  Dados de Matheus-Nunes
# https://www.transfermarkt.us/Matheus-Nunes/leistungsdatendetails/spieler/601883
# https://www.transfermarkt.us/Matheus-Nunes/profil/spieler/601883
# Foot: right
# https://www.transfermarkt.us/Matheus-Nunes/leistungsdatendetails/spieler/601883/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Matheus-Nunes/transfers/spieler/601883/transfer_id/4021841
#
#  Dados de Enzo-Fernandez
# https://www.transfermarkt.us/Enzo-Fernandez/leistungsdatendetails/spieler/648195
# https://www.transfermarkt.us/Enzo-Fernandez/profil/spieler/648195
# Foot: right
# https://www.transfermarkt.us/Enzo-Fernandez/leistungsdatendetails/spieler/648195/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Enzo-Fernandez/transfers/spieler/648195/transfer_id/3943263
#
#  Dados de Lucas-Paqueta
# https://www.transfermarkt.us/Lucas-Paqueta/leistungsdatendetails/spieler/444523
# https://www.transfermarkt.us/Lucas-Paqueta/profil/spieler/444523
# Foot: left
# https://www.transfermarkt.us/Lucas-Paqueta/leistungsdatendetails/spieler/444523/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Lucas-Paqueta/transfers/spieler/444523/transfer_id/4043826
#
#  Dados de Vitinha
# https://www.transfermarkt.us/Vitinha/leistungsdatendetails/spieler/487469
# https://www.transfermarkt.us/Vitinha/profil/spieler/487469
# Foot: right
# https://www.transfermarkt.us/Vitinha/leistungsdatendetails/spieler/487469/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Vitinha/transfers/spieler/487469/transfer_id/3913110
#
#  Dados de Charles-De-Ketelaere
# https://www.transfermarkt.us/Charles-De-Ketelaere/leistungsdatendetails/spieler/435772
# https://www.transfermarkt.us/Charles-De-Ketelaere/profil/spieler/435772
# Foot: left
# https://www.transfermarkt.us/Charles-De-Ketelaere/leistungsdatendetails/spieler/435772/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Charles-De-Ketelaere/transfers/spieler/435772/transfer_id/3988003
#
#  Dados de Fabio-Vieira
# https://www.transfermarkt.us/Fabio-Vieira/leistungsdatendetails/spieler/537598
# https://www.transfermarkt.us/Fabio-Vieira/profil/spieler/537598
# Foot: left
# https://www.transfermarkt.us/Fabio-Vieira/leistungsdatendetails/spieler/537598/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Fabio-Vieira/transfers/spieler/537598/transfer_id/3890560
#
#  Dados de Amadou-Onana
# https://www.transfermarkt.us/Amadou-Onana/leistungsdatendetails/spieler/485706
# https://www.transfermarkt.us/Amadou-Onana/profil/spieler/485706
# Foot: right
# https://www.transfermarkt.us/Amadou-Onana/leistungsdatendetails/spieler/485706/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Amadou-Onana/transfers/spieler/485706/transfer_id/4002220
#
#  Dados de Brenden-Aaronson
# https://www.transfermarkt.us/Brenden-Aaronson/leistungsdatendetails/spieler/393323
# https://www.transfermarkt.us/Brenden-Aaronson/profil/spieler/393323
# Foot: right
# https://www.transfermarkt.us/Brenden-Aaronson/leistungsdatendetails/spieler/393323/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Brenden-Aaronson/transfers/spieler/393323/transfer_id/3862354
#
#  Dados de Morgan-Gibbs-White
# https://www.transfermarkt.us/Morgan-Gibbs-White/leistungsdatendetails/spieler/429014
# https://www.transfermarkt.us/Morgan-Gibbs-White/profil/spieler/429014
# Foot: right
# https://www.transfermarkt.us/Morgan-Gibbs-White/leistungsdatendetails/spieler/429014/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Morgan-Gibbs-White/transfers/spieler/429014/transfer_id/4024198
#
#  Dados de Yves-Bissouma
# https://www.transfermarkt.us/Yves-Bissouma/leistungsdatendetails/spieler/410425
# https://www.transfermarkt.us/Yves-Bissouma/profil/spieler/410425
# Foot: right
# https://www.transfermarkt.us/Yves-Bissouma/leistungsdatendetails/spieler/410425/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Yves-Bissouma/transfers/spieler/410425/transfer_id/3890638
#
#  Dados de Robin-Gosens
# https://www.transfermarkt.us/Robin-Gosens/leistungsdatendetails/spieler/273132
# https://www.transfermarkt.us/Robin-Gosens/profil/spieler/273132
# Foot: left
# https://www.transfermarkt.us/Robin-Gosens/leistungsdatendetails/spieler/273132/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Robin-Gosens/transfers/spieler/273132/transfer_id/3815725
#
#  Dados de Ederson
# https://www.transfermarkt.us/Ederson/leistungsdatendetails/spieler/607854
# https://www.transfermarkt.us/Ederson/profil/spieler/607854
# Foot: right
# https://www.transfermarkt.us/Ederson/leistungsdatendetails/spieler/607854/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ederson/transfers/spieler/607854/transfer_id/3925022
#
#  Dados de Cheick-Doucoure
# https://www.transfermarkt.us/Cheick-Doucoure/leistungsdatendetails/spieler/543387
# https://www.transfermarkt.us/Cheick-Doucoure/profil/spieler/543387
# Foot: right
# https://www.transfermarkt.us/Cheick-Doucoure/leistungsdatendetails/spieler/543387/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Cheick-Doucoure/transfers/spieler/543387/transfer_id/3934484
#
#  Dados de Fabian-Ruiz
# https://www.transfermarkt.us/Fabian-Ruiz/leistungsdatendetails/spieler/350219
# https://www.transfermarkt.us/Fabian-Ruiz/profil/spieler/350219
# Foot: left
# https://www.transfermarkt.us/Fabian-Ruiz/leistungsdatendetails/spieler/350219/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Fabian-Ruiz/transfers/spieler/350219/transfer_id/4046339
#
#  Dados de Romeo-Lavia
# https://www.transfermarkt.us/Romeo-Lavia/leistungsdatendetails/spieler/628451
# https://www.transfermarkt.us/Romeo-Lavia/profil/spieler/628451
# Foot: right
# https://www.transfermarkt.us/Romeo-Lavia/leistungsdatendetails/spieler/628451/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Romeo-Lavia/transfers/spieler/628451/transfer_id/3925100
#
#  Dados de Joao-Palhinha
# https://www.transfermarkt.us/Joao-Palhinha/leistungsdatendetails/spieler/257455
# https://www.transfermarkt.us/Joao-Palhinha/profil/spieler/257455
# Foot: right
# https://www.transfermarkt.us/Joao-Palhinha/leistungsdatendetails/spieler/257455/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Joao-Palhinha/transfers/spieler/257455/transfer_id/3919573
#
#  Dados de Danilo
# https://www.transfermarkt.us/Danilo/leistungsdatendetails/spieler/808509
# https://www.transfermarkt.us/Danilo/profil/spieler/808509
# Foot: left
# https://www.transfermarkt.us/Danilo/leistungsdatendetails/spieler/808509/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Danilo/transfers/spieler/808509/transfer_id/4226831
#
#  Dados de Philippe-Coutinho
# https://www.transfermarkt.us/Philippe-Coutinho/leistungsdatendetails/spieler/80444
# https://www.transfermarkt.us/Philippe-Coutinho/profil/spieler/80444
# Foot: right
# https://www.transfermarkt.us/Philippe-Coutinho/leistungsdatendetails/spieler/80444/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Philippe-Coutinho/transfers/spieler/80444/transfer_id/3847814
#
#  Dados de Joao-Gomes
# https://www.transfermarkt.us/Joao-Gomes/leistungsdatendetails/spieler/735570
# https://www.transfermarkt.us/Joao-Gomes/profil/spieler/735570
# Foot: right
# https://www.transfermarkt.us/Joao-Gomes/leistungsdatendetails/spieler/735570/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Joao-Gomes/transfers/spieler/735570/transfer_id/4249805
#
#  Dados de Ryan-Gravenberch
# https://www.transfermarkt.us/Ryan-Gravenberch/leistungsdatendetails/spieler/478573
# https://www.transfermarkt.us/Ryan-Gravenberch/profil/spieler/478573
# Foot: right
# https://www.transfermarkt.us/Ryan-Gravenberch/leistungsdatendetails/spieler/478573/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ryan-Gravenberch/transfers/spieler/478573/transfer_id/3884551
#
#  Dados de Carlos-Soler
# https://www.transfermarkt.us/Carlos-Soler/leistungsdatendetails/spieler/372246
# https://www.transfermarkt.us/Carlos-Soler/profil/spieler/372246
# Foot: right
# https://www.transfermarkt.us/Carlos-Soler/leistungsdatendetails/spieler/372246/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Carlos-Soler/transfers/spieler/372246/transfer_id/4051821
#
#  Dados de Carney-Chukwuemeka
# https://www.transfermarkt.us/Carney-Chukwuemeka/leistungsdatendetails/spieler/659459
# https://www.transfermarkt.us/Carney-Chukwuemeka/profil/spieler/659459
# Foot: right
# https://www.transfermarkt.us/Carney-Chukwuemeka/leistungsdatendetails/spieler/659459/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Carney-Chukwuemeka/transfers/spieler/659459/transfer_id/3991227
#
#  Dados de Tyler-Adams
# https://www.transfermarkt.us/Tyler-Adams/leistungsdatendetails/spieler/332705
# https://www.transfermarkt.us/Tyler-Adams/profil/spieler/332705
# Foot: right
# https://www.transfermarkt.us/Tyler-Adams/leistungsdatendetails/spieler/332705/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Tyler-Adams/transfers/spieler/332705/transfer_id/3925001
#
#  Dados de Frank-Anguissa
# https://www.transfermarkt.us/Frank-Anguissa/leistungsdatendetails/spieler/354361
# https://www.transfermarkt.us/Frank-Anguissa/profil/spieler/354361
# Foot: right
# https://www.transfermarkt.us/Frank-Anguissa/leistungsdatendetails/spieler/354361/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Frank-Anguissa/transfers/spieler/354361/transfer_id/3862596
#
#  Dados de Nicolo-Zaniolo
# https://www.transfermarkt.us/Nicolo-Zaniolo/leistungsdatendetails/spieler/392085
# https://www.transfermarkt.us/Nicolo-Zaniolo/profil/spieler/392085
# Foot: left
# https://www.transfermarkt.us/Nicolo-Zaniolo/leistungsdatendetails/spieler/392085/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Nicolo-Zaniolo/transfers/spieler/392085/transfer_id/4267021
#
#  Dados de Renato-Sanches
# https://www.transfermarkt.us/Renato-Sanches/leistungsdatendetails/spieler/258027
# https://www.transfermarkt.us/Renato-Sanches/profil/spieler/258027
# Foot: right
# https://www.transfermarkt.us/Renato-Sanches/leistungsdatendetails/spieler/258027/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Renato-Sanches/transfers/spieler/258027/transfer_id/3992248
#
#  Dados de Leander-Dendoncker
# https://www.transfermarkt.us/Leander-Dendoncker/leistungsdatendetails/spieler/168157
# https://www.transfermarkt.us/Leander-Dendoncker/profil/spieler/168157
# Foot: right
# https://www.transfermarkt.us/Leander-Dendoncker/leistungsdatendetails/spieler/168157/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Leander-Dendoncker/transfers/spieler/168157/transfer_id/4051851
#
#  Dados de Mohamed-Camara
# https://www.transfermarkt.us/Mohamed-Camara/leistungsdatendetails/spieler/543382
# https://www.transfermarkt.us/Mohamed-Camara/profil/spieler/543382
# Foot: right
# https://www.transfermarkt.us/Mohamed-Camara/leistungsdatendetails/spieler/543382/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mohamed-Camara/transfers/spieler/543382/transfer_id/4012994
#
#  Dados de Gerson
# https://www.transfermarkt.us/Gerson/leistungsdatendetails/spieler/341705
# https://www.transfermarkt.us/Gerson/profil/spieler/341705
# Foot: left
# https://www.transfermarkt.us/Gerson/leistungsdatendetails/spieler/341705/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Gerson/transfers/spieler/341705/transfer_id/4201449
#
#  Dados de Cesare-Casadei
# https://www.transfermarkt.us/Cesare-Casadei/leistungsdatendetails/spieler/622380
# https://www.transfermarkt.us/Cesare-Casadei/profil/spieler/622380
# Foot: right
# https://www.transfermarkt.us/Cesare-Casadei/leistungsdatendetails/spieler/622380/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Cesare-Casadei/transfers/spieler/622380/transfer_id/4024647
#
#  Dados de Filip-Kostic
# https://www.transfermarkt.us/Filip-Kostic/leistungsdatendetails/spieler/161011
# https://www.transfermarkt.us/Filip-Kostic/profil/spieler/161011
# Foot: left
# https://www.transfermarkt.us/Filip-Kostic/leistungsdatendetails/spieler/161011/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Filip-Kostic/transfers/spieler/161011/transfer_id/4007624
#
#  Dados de Brais-Mendez
# https://www.transfermarkt.us/Brais-Mendez/leistungsdatendetails/spieler/309110
# https://www.transfermarkt.us/Brais-Mendez/profil/spieler/309110
# Foot: left
# https://www.transfermarkt.us/Brais-Mendez/leistungsdatendetails/spieler/309110/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Brais-Mendez/transfers/spieler/309110/transfer_id/3925164
#
#  Dados de Carlos-Alcaraz
# https://www.transfermarkt.us/Carlos-Alcaraz/leistungsdatendetails/spieler/748319
# https://www.transfermarkt.us/Carlos-Alcaraz/profil/spieler/748319
# Foot: right
# https://www.transfermarkt.us/Carlos-Alcaraz/leistungsdatendetails/spieler/748319/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Carlos-Alcaraz/transfers/spieler/748319/transfer_id/4213327
#
#  Dados de Orel-Mangala
# https://www.transfermarkt.us/Orel-Mangala/leistungsdatendetails/spieler/289592
# https://www.transfermarkt.us/Orel-Mangala/profil/spieler/289592
# Foot: right
# https://www.transfermarkt.us/Orel-Mangala/leistungsdatendetails/spieler/289592/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Orel-Mangala/transfers/spieler/289592/transfer_id/3981536
#
#  Dados de Lucas-Gourna-Douath
# https://www.transfermarkt.us/Lucas-Gourna-Douath/leistungsdatendetails/spieler/620313
# https://www.transfermarkt.us/Lucas-Gourna-Douath/profil/spieler/620313
# Foot: right
# https://www.transfermarkt.us/Lucas-Gourna-Douath/leistungsdatendetails/spieler/620313/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Lucas-Gourna-Douath/transfers/spieler/620313/transfer_id/3939940
#
#  Dados de Andrey-Santos
# https://www.transfermarkt.us/Andrey-Santos/leistungsdatendetails/spieler/743600
# https://www.transfermarkt.us/Andrey-Santos/profil/spieler/743600
# Foot: right
# https://www.transfermarkt.us/Andrey-Santos/leistungsdatendetails/spieler/743600/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Andrey-Santos/transfers/spieler/743600/transfer_id/4207516
#
#  Dados de Jordan-Veretout
# https://www.transfermarkt.us/Jordan-Veretout/leistungsdatendetails/spieler/164771
# https://www.transfermarkt.us/Jordan-Veretout/profil/spieler/164771
# Foot: right
# https://www.transfermarkt.us/Jordan-Veretout/leistungsdatendetails/spieler/164771/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jordan-Veretout/transfers/spieler/164771/transfer_id/3994883
#
#  Dados de Fernando-Gorriaran
# https://www.transfermarkt.us/Fernando-Gorriaran/leistungsdatendetails/spieler/310744
# https://www.transfermarkt.us/Fernando-Gorriaran/profil/spieler/310744
# Foot: right
# https://www.transfermarkt.us/Fernando-Gorriaran/leistungsdatendetails/spieler/310744/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Fernando-Gorriaran/transfers/spieler/310744/transfer_id/4178004
#
#  Dados de Xaver-Schlager
# https://www.transfermarkt.us/Xaver-Schlager/leistungsdatendetails/spieler/223979
# https://www.transfermarkt.us/Xaver-Schlager/profil/spieler/223979
# Foot: left
# https://www.transfermarkt.us/Xaver-Schlager/leistungsdatendetails/spieler/223979/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Xaver-Schlager/transfers/spieler/223979/transfer_id/3890307
#
#  Dados de Marc-Roca
# https://www.transfermarkt.us/Marc-Roca/leistungsdatendetails/spieler/336869
# https://www.transfermarkt.us/Marc-Roca/profil/spieler/336869
# Foot: left
# https://www.transfermarkt.us/Marc-Roca/leistungsdatendetails/spieler/336869/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Marc-Roca/transfers/spieler/336869/transfer_id/3890799
#
#  Dados de Naouirou-Ahamada
# https://www.transfermarkt.us/Naouirou-Ahamada/leistungsdatendetails/spieler/538971
# https://www.transfermarkt.us/Naouirou-Ahamada/profil/spieler/538971
# Foot: right
# https://www.transfermarkt.us/Naouirou-Ahamada/leistungsdatendetails/spieler/538971/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Naouirou-Ahamada/transfers/spieler/538971/transfer_id/4253573
#
#  Dados de Alexis-Beka-Beka
# https://www.transfermarkt.us/Alexis-Beka-Beka/leistungsdatendetails/spieler/539065
# https://www.transfermarkt.us/Alexis-Beka-Beka/profil/spieler/539065
# Foot: right
# https://www.transfermarkt.us/Alexis-Beka-Beka/leistungsdatendetails/spieler/539065/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Alexis-Beka-Beka/transfers/spieler/539065/transfer_id/3983529
#
#  Dados de Marcus-Tavernier
# https://www.transfermarkt.us/Marcus-Tavernier/leistungsdatendetails/spieler/399434
# https://www.transfermarkt.us/Marcus-Tavernier/profil/spieler/399434
# Foot: left
# https://www.transfermarkt.us/Marcus-Tavernier/leistungsdatendetails/spieler/399434/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Marcus-Tavernier/transfers/spieler/399434/transfer_id/3983333
#
#  Dados de Julio-Enciso
# https://www.transfermarkt.us/Julio-Enciso/leistungsdatendetails/spieler/660867
# https://www.transfermarkt.us/Julio-Enciso/profil/spieler/660867
# Foot: right
# https://www.transfermarkt.us/Julio-Enciso/leistungsdatendetails/spieler/660867/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Julio-Enciso/transfers/spieler/660867/transfer_id/3890069
#
#  Dados de Youssouf-Ndayishimiye
# https://www.transfermarkt.us/Youssouf-Ndayishimiye/leistungsdatendetails/spieler/674612
# https://www.transfermarkt.us/Youssouf-Ndayishimiye/profil/spieler/674612
# Foot: right
# https://www.transfermarkt.us/Youssouf-Ndayishimiye/leistungsdatendetails/spieler/674612/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Youssouf-Ndayishimiye/transfers/spieler/674612/transfer_id/4242260
#
#  Dados de Jorginho
# https://www.transfermarkt.us/Jorginho/leistungsdatendetails/spieler/102017
# https://www.transfermarkt.us/Jorginho/profil/spieler/102017
# Foot: right
# https://www.transfermarkt.us/Jorginho/leistungsdatendetails/spieler/102017/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jorginho/transfers/spieler/102017/transfer_id/4253365
#
#  Dados de Matteo-Guendouzi
# https://www.transfermarkt.us/Matteo-Guendouzi/leistungsdatendetails/spieler/465830
# https://www.transfermarkt.us/Matteo-Guendouzi/profil/spieler/465830
# Foot: right
# https://www.transfermarkt.us/Matteo-Guendouzi/leistungsdatendetails/spieler/465830/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Matteo-Guendouzi/transfers/spieler/465830/transfer_id/3767963
#
#  Dados de Maximo-Perrone
# https://www.transfermarkt.us/Maximo-Perrone/leistungsdatendetails/spieler/668547
# https://www.transfermarkt.us/Maximo-Perrone/profil/spieler/668547
# Foot: left
# https://www.transfermarkt.us/Maximo-Perrone/leistungsdatendetails/spieler/668547/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Maximo-Perrone/transfers/spieler/668547/transfer_id/4238945
#
#  Dados de Jean-Victor-Makengo
# https://www.transfermarkt.us/Jean-Victor-Makengo/leistungsdatendetails/spieler/322305
# https://www.transfermarkt.us/Jean-Victor-Makengo/profil/spieler/322305
# Foot: left
# https://www.transfermarkt.us/Jean-Victor-Makengo/leistungsdatendetails/spieler/322305/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jean-Victor-Makengo/transfers/spieler/322305/transfer_id/4250364
#
#  Dados de Mario-Lemina
# https://www.transfermarkt.us/Mario-Lemina/leistungsdatendetails/spieler/170934
# https://www.transfermarkt.us/Mario-Lemina/profil/spieler/170934
# Foot: right
# https://www.transfermarkt.us/Mario-Lemina/leistungsdatendetails/spieler/170934/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mario-Lemina/transfers/spieler/170934/transfer_id/4222260
#
#  Dados de Flynn-Downes
# https://www.transfermarkt.us/Flynn-Downes/leistungsdatendetails/spieler/506189
# https://www.transfermarkt.us/Flynn-Downes/profil/spieler/506189
# Foot: right
# https://www.transfermarkt.us/Flynn-Downes/leistungsdatendetails/spieler/506189/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Flynn-Downes/transfers/spieler/506189/transfer_id/3927490
#
#  Dados de Gabriel-Sara
# https://www.transfermarkt.us/Gabriel-Sara/leistungsdatendetails/spieler/553469
# https://www.transfermarkt.us/Gabriel-Sara/profil/spieler/553469
# Foot: left
# https://www.transfermarkt.us/Gabriel-Sara/leistungsdatendetails/spieler/553469/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Gabriel-Sara/transfers/spieler/553469/transfer_id/3945913
#
#  Dados de James-Garner
# https://www.transfermarkt.us/James-Garner/leistungsdatendetails/spieler/505219
# https://www.transfermarkt.us/James-Garner/profil/spieler/505219
# Foot: right
# https://www.transfermarkt.us/James-Garner/leistungsdatendetails/spieler/505219/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/James-Garner/transfers/spieler/505219/transfer_id/4052162
#
#  Dados de Kristian-Thorstvedt
# https://www.transfermarkt.us/Kristian-Thorstvedt/leistungsdatendetails/spieler/564785
# https://www.transfermarkt.us/Kristian-Thorstvedt/profil/spieler/564785
# Foot: left
# https://www.transfermarkt.us/Kristian-Thorstvedt/leistungsdatendetails/spieler/564785/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Kristian-Thorstvedt/transfers/spieler/564785/transfer_id/3936186
#
#  Dados de Ruben-Vinagre
# https://www.transfermarkt.us/Ruben-Vinagre/leistungsdatendetails/spieler/357158
# https://www.transfermarkt.us/Ruben-Vinagre/profil/spieler/357158
# Foot: left
# https://www.transfermarkt.us/Ruben-Vinagre/leistungsdatendetails/spieler/357158/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ruben-Vinagre/transfers/spieler/357158/transfer_id/3763844
#
#  Dados de Sasa-Lukic
# https://www.transfermarkt.us/Sasa-Lukic/leistungsdatendetails/spieler/245056
# https://www.transfermarkt.us/Sasa-Lukic/profil/spieler/245056
# Foot: right
# https://www.transfermarkt.us/Sasa-Lukic/leistungsdatendetails/spieler/245056/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Sasa-Lukic/transfers/spieler/245056/transfer_id/4253203
#
#  Dados de Mattias-Svanberg
# https://www.transfermarkt.us/Mattias-Svanberg/leistungsdatendetails/spieler/342405
# https://www.transfermarkt.us/Mattias-Svanberg/profil/spieler/342405
# Foot: right
# https://www.transfermarkt.us/Mattias-Svanberg/leistungsdatendetails/spieler/342405/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mattias-Svanberg/transfers/spieler/342405/transfer_id/3946746
#
#  Dados de Evander
# https://www.transfermarkt.us/Evander/leistungsdatendetails/spieler/323874
# https://www.transfermarkt.us/Evander/profil/spieler/323874
# Foot: right
# https://www.transfermarkt.us/Evander/leistungsdatendetails/spieler/323874/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Evander/transfers/spieler/323874/transfer_id/4164287
#
#  Dados de Andreas-Pereira
# https://www.transfermarkt.us/Andreas-Pereira/leistungsdatendetails/spieler/203394
# https://www.transfermarkt.us/Andreas-Pereira/profil/spieler/203394
# Foot: right
# https://www.transfermarkt.us/Andreas-Pereira/leistungsdatendetails/spieler/203394/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Andreas-Pereira/transfers/spieler/203394/transfer_id/3934828
#
#  Dados de Raphael-Onyedika
# https://www.transfermarkt.us/Raphael-Onyedika/leistungsdatendetails/spieler/699783
# https://www.transfermarkt.us/Raphael-Onyedika/profil/spieler/699783
# Foot: right
# https://www.transfermarkt.us/Raphael-Onyedika/leistungsdatendetails/spieler/699783/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Raphael-Onyedika/transfers/spieler/699783/transfer_id/4041789
#
#  Dados de Lewis-OBrien
# https://www.transfermarkt.us/Lewis-OBrien/leistungsdatendetails/spieler/560694
# https://www.transfermarkt.us/Lewis-OBrien/profil/spieler/560694
# Foot: left
# https://www.transfermarkt.us/Lewis-OBrien/leistungsdatendetails/spieler/560694/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Lewis-OBrien/transfers/spieler/560694/transfer_id/3957971
#
#  Dados de Marko-Grujic
# https://www.transfermarkt.us/Marko-Grujic/leistungsdatendetails/spieler/222813
# https://www.transfermarkt.us/Marko-Grujic/profil/spieler/222813
# Foot: right
# https://www.transfermarkt.us/Marko-Grujic/leistungsdatendetails/spieler/222813/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Marko-Grujic/transfers/spieler/222813/transfer_id/3451915
#
#  Dados de Andrea-Colpani
# https://www.transfermarkt.us/Andrea-Colpani/leistungsdatendetails/spieler/392959
# https://www.transfermarkt.us/Andrea-Colpani/profil/spieler/392959
# Foot: left
# https://www.transfermarkt.us/Andrea-Colpani/leistungsdatendetails/spieler/392959/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Andrea-Colpani/transfers/spieler/392959/transfer_id/3865819
#
#  Dados de Samuele-Ricci
# https://www.transfermarkt.us/Samuele-Ricci/leistungsdatendetails/spieler/467992
# https://www.transfermarkt.us/Samuele-Ricci/profil/spieler/467992
# Foot: right
# https://www.transfermarkt.us/Samuele-Ricci/leistungsdatendetails/spieler/467992/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Samuele-Ricci/transfers/spieler/467992/transfer_id/3876585
#
#  Dados de Remo-Freuler
# https://www.transfermarkt.us/Remo-Freuler/leistungsdatendetails/spieler/148252
# https://www.transfermarkt.us/Remo-Freuler/profil/spieler/148252
# Foot: right
# https://www.transfermarkt.us/Remo-Freuler/leistungsdatendetails/spieler/148252/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Remo-Freuler/transfers/spieler/148252/transfer_id/4014002
#
#  Dados de Billy-Gilmour
# https://www.transfermarkt.us/Billy-Gilmour/leistungsdatendetails/spieler/423744
# https://www.transfermarkt.us/Billy-Gilmour/profil/spieler/423744
# Foot: right
# https://www.transfermarkt.us/Billy-Gilmour/leistungsdatendetails/spieler/423744/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Billy-Gilmour/transfers/spieler/423744/transfer_id/4052474
#
#  Dados de Rolando-Mandragora
# https://www.transfermarkt.us/Rolando-Mandragora/leistungsdatendetails/spieler/308279
# https://www.transfermarkt.us/Rolando-Mandragora/profil/spieler/308279
# Foot: left
# https://www.transfermarkt.us/Rolando-Mandragora/leistungsdatendetails/spieler/308279/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Rolando-Mandragora/transfers/spieler/308279/transfer_id/3920594
#
#  Dados de Azzedine-Ounahi
# https://www.transfermarkt.us/Azzedine-Ounahi/leistungsdatendetails/spieler/593482
# https://www.transfermarkt.us/Azzedine-Ounahi/profil/spieler/593482
# Foot: right
# https://www.transfermarkt.us/Azzedine-Ounahi/leistungsdatendetails/spieler/593482/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Azzedine-Ounahi/transfers/spieler/593482/transfer_id/4248491
#
#  Dados de Ismael-Kone
# https://www.transfermarkt.us/Ismael-Kone/leistungsdatendetails/spieler/921655
# https://www.transfermarkt.us/Ismael-Kone/profil/spieler/921655
# Foot: right
# https://www.transfermarkt.us/Ismael-Kone/leistungsdatendetails/spieler/921655/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ismael-Kone/transfers/spieler/921655/transfer_id/4164459
#
#  Dados de Andre-Almeida
# https://www.transfermarkt.us/Andre-Almeida/leistungsdatendetails/spieler/375382
# https://www.transfermarkt.us/Andre-Almeida/profil/spieler/375382
# Foot: right
# https://www.transfermarkt.us/Andre-Almeida/leistungsdatendetails/spieler/375382/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Andre-Almeida/transfers/spieler/375382/transfer_id/4037581
#
#  Dados de Antonin-Barak
# https://www.transfermarkt.us/Antonin-Barak/leistungsdatendetails/spieler/272261
# https://www.transfermarkt.us/Antonin-Barak/profil/spieler/272261
# Foot: left
# https://www.transfermarkt.us/Antonin-Barak/leistungsdatendetails/spieler/272261/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Antonin-Barak/transfers/spieler/272261/transfer_id/4252687
#
#  Dados de Marcos-Antonio
# https://www.transfermarkt.us/Marcos-Antonio/leistungsdatendetails/spieler/468301
# https://www.transfermarkt.us/Marcos-Antonio/profil/spieler/468301
# Foot: right
# https://www.transfermarkt.us/Marcos-Antonio/leistungsdatendetails/spieler/468301/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Marcos-Antonio/transfers/spieler/468301/transfer_id/3914061
#
#  Dados de Casper-Nielsen
# https://www.transfermarkt.us/Casper-Nielsen/leistungsdatendetails/spieler/148365
# https://www.transfermarkt.us/Casper-Nielsen/profil/spieler/148365
# Foot: right
# https://www.transfermarkt.us/Casper-Nielsen/leistungsdatendetails/spieler/148365/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Casper-Nielsen/transfers/spieler/148365/transfer_id/3951189
#
#  Dados de Bartol-Franjic
# https://www.transfermarkt.us/Bartol-Franjic/leistungsdatendetails/spieler/370998
# https://www.transfermarkt.us/Bartol-Franjic/profil/spieler/370998
# Foot: left
# https://www.transfermarkt.us/Bartol-Franjic/leistungsdatendetails/spieler/370998/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Bartol-Franjic/transfers/spieler/370998/transfer_id/3906088
#
#  Dados de Quinten-Timber
# https://www.transfermarkt.us/Quinten-Timber/leistungsdatendetails/spieler/420213
# https://www.transfermarkt.us/Quinten-Timber/profil/spieler/420213
# Foot: right
# https://www.transfermarkt.us/Quinten-Timber/leistungsdatendetails/spieler/420213/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Quinten-Timber/transfers/spieler/420213/transfer_id/3976241
#
#  Dados de Joe-Aribo
# https://www.transfermarkt.us/Joe-Aribo/leistungsdatendetails/spieler/468198
# https://www.transfermarkt.us/Joe-Aribo/profil/spieler/468198
# Foot: left
# https://www.transfermarkt.us/Joe-Aribo/leistungsdatendetails/spieler/468198/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Joe-Aribo/transfers/spieler/468198/transfer_id/3931949
#
#  Dados de Matheus-Henrique
# https://www.transfermarkt.us/Matheus-Henrique/leistungsdatendetails/spieler/552549
# https://www.transfermarkt.us/Matheus-Henrique/profil/spieler/552549
# Foot: right
# https://www.transfermarkt.us/Matheus-Henrique/leistungsdatendetails/spieler/552549/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Matheus-Henrique/transfers/spieler/552549/transfer_id/3544789
#
#  Dados de Christopher-Martins-Pereira
# https://www.transfermarkt.us/Christopher-Martins-Pereira/leistungsdatendetails/spieler/248054
# https://www.transfermarkt.us/Christopher-Martins-Pereira/profil/spieler/248054
# Foot: right
# https://www.transfermarkt.us/Christopher-Martins-Pereira/leistungsdatendetails/spieler/248054/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Christopher-Martins-Pereira/transfers/spieler/248054/transfer_id/3847131
#
#  Dados de Oscar-Gloukh
# https://www.transfermarkt.us/Oscar-Gloukh/leistungsdatendetails/spieler/930571
# https://www.transfermarkt.us/Oscar-Gloukh/profil/spieler/930571
# Foot: both
# https://www.transfermarkt.us/Oscar-Gloukh/leistungsdatendetails/spieler/930571/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Oscar-Gloukh/transfers/spieler/930571/transfer_id/4245530
#
#  Dados de Jonjo-Shelvey
# https://www.transfermarkt.us/Jonjo-Shelvey/leistungsdatendetails/spieler/71292
# https://www.transfermarkt.us/Jonjo-Shelvey/profil/spieler/71292
# Foot: right
# https://www.transfermarkt.us/Jonjo-Shelvey/leistungsdatendetails/spieler/71292/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jonjo-Shelvey/transfers/spieler/71292/transfer_id/4253942
#
#  Dados de Lucas-Torreira
# https://www.transfermarkt.us/Lucas-Torreira/leistungsdatendetails/spieler/318077
# https://www.transfermarkt.us/Lucas-Torreira/profil/spieler/318077
# Foot: right
# https://www.transfermarkt.us/Lucas-Torreira/leistungsdatendetails/spieler/318077/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Lucas-Torreira/transfers/spieler/318077/transfer_id/4000418
#
#  Dados de Angelo-Fulgini
# https://www.transfermarkt.us/Angelo-Fulgini/leistungsdatendetails/spieler/250013
# https://www.transfermarkt.us/Angelo-Fulgini/profil/spieler/250013
# Foot: right
# https://www.transfermarkt.us/Angelo-Fulgini/leistungsdatendetails/spieler/250013/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Angelo-Fulgini/transfers/spieler/250013/transfer_id/3937596
#
#  Dados de Facundo-Buonanotte
# https://www.transfermarkt.us/Facundo-Buonanotte/leistungsdatendetails/spieler/983989
# https://www.transfermarkt.us/Facundo-Buonanotte/profil/spieler/983989
# Foot: left
# https://www.transfermarkt.us/Facundo-Buonanotte/leistungsdatendetails/spieler/983989/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Facundo-Buonanotte/transfers/spieler/983989/transfer_id/4129528
#
#  Dados de Giuliano-Galoppo
# https://www.transfermarkt.us/Giuliano-Galoppo/leistungsdatendetails/spieler/567249
# https://www.transfermarkt.us/Giuliano-Galoppo/profil/spieler/567249
# Foot: right
# https://www.transfermarkt.us/Giuliano-Galoppo/leistungsdatendetails/spieler/567249/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Giuliano-Galoppo/transfers/spieler/567249/transfer_id/3972471
#
#  Dados de Gedson-Fernandes
# https://www.transfermarkt.us/Gedson-Fernandes/leistungsdatendetails/spieler/337800
# https://www.transfermarkt.us/Gedson-Fernandes/profil/spieler/337800
# Foot: right
# https://www.transfermarkt.us/Gedson-Fernandes/leistungsdatendetails/spieler/337800/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Gedson-Fernandes/transfers/spieler/337800/transfer_id/3726289
#
#  Dados de Pep-Biel
# https://www.transfermarkt.us/Pep-Biel/leistungsdatendetails/spieler/263804
# https://www.transfermarkt.us/Pep-Biel/profil/spieler/263804
# Foot: left
# https://www.transfermarkt.us/Pep-Biel/leistungsdatendetails/spieler/263804/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Pep-Biel/transfers/spieler/263804/transfer_id/4051636
#
#  Dados de Fausto-Vera
# https://www.transfermarkt.us/Fausto-Vera/leistungsdatendetails/spieler/491701
# https://www.transfermarkt.us/Fausto-Vera/profil/spieler/491701
# Foot: right
# https://www.transfermarkt.us/Fausto-Vera/leistungsdatendetails/spieler/491701/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Fausto-Vera/transfers/spieler/491701/transfer_id/3969815
#
#  Dados de Matias-Galarza
# https://www.transfermarkt.us/Matias-Galarza/leistungsdatendetails/spieler/909737
# https://www.transfermarkt.us/Matias-Galarza/profil/spieler/909737
# Foot: right
# https://www.transfermarkt.us/Matias-Galarza/leistungsdatendetails/spieler/909737/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Matias-Galarza/transfers/spieler/909737/transfer_id/4004412
#
#  Dados de Fabio-Carvalho
# https://www.transfermarkt.us/Fabio-Carvalho/leistungsdatendetails/spieler/559263
# https://www.transfermarkt.us/Fabio-Carvalho/profil/spieler/559263
# Foot: right
# https://www.transfermarkt.us/Fabio-Carvalho/leistungsdatendetails/spieler/559263/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Fabio-Carvalho/transfers/spieler/559263/transfer_id/3858852
#
#  Dados de Darko-Gyabi
# https://www.transfermarkt.us/Darko-Gyabi/leistungsdatendetails/spieler/663264
# https://www.transfermarkt.us/Darko-Gyabi/profil/spieler/663264
# Foot: right
# https://www.transfermarkt.us/Darko-Gyabi/leistungsdatendetails/spieler/663264/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Darko-Gyabi/transfers/spieler/663264/transfer_id/3919628
#
#  Dados de Juan-Ignacio-Nardoni
# https://www.transfermarkt.us/Juan-Ignacio-Nardoni/leistungsdatendetails/spieler/689211
# https://www.transfermarkt.us/Juan-Ignacio-Nardoni/profil/spieler/689211
# Foot: right
# https://www.transfermarkt.us/Juan-Ignacio-Nardoni/leistungsdatendetails/spieler/689211/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Juan-Ignacio-Nardoni/transfers/spieler/689211/transfer_id/4206561
#
#  Dados de Diego-Rossi
# https://www.transfermarkt.us/Diego-Rossi/leistungsdatendetails/spieler/317454
# https://www.transfermarkt.us/Diego-Rossi/profil/spieler/317454
# Foot: right
# https://www.transfermarkt.us/Diego-Rossi/leistungsdatendetails/spieler/317454/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Diego-Rossi/transfers/spieler/317454/transfer_id/3818563
#
#  Dados de Oriol-Romeu
# https://www.transfermarkt.us/Oriol-Romeu/leistungsdatendetails/spieler/66100
# https://www.transfermarkt.us/Oriol-Romeu/profil/spieler/66100
# Foot: right
# https://www.transfermarkt.us/Oriol-Romeu/leistungsdatendetails/spieler/66100/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Oriol-Romeu/transfers/spieler/66100/transfer_id/4050487
#
#  Dados de Williot-Swedberg
# https://www.transfermarkt.us/Williot-Swedberg/leistungsdatendetails/spieler/764859
# https://www.transfermarkt.us/Williot-Swedberg/profil/spieler/764859
# Foot: right
# https://www.transfermarkt.us/Williot-Swedberg/leistungsdatendetails/spieler/764859/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Williot-Swedberg/transfers/spieler/764859/transfer_id/3890272
#
#  Dados de Salih-Ozcan
# https://www.transfermarkt.us/Salih-Ozcan/leistungsdatendetails/spieler/244940
# https://www.transfermarkt.us/Salih-Ozcan/profil/spieler/244940
# Foot: right
# https://www.transfermarkt.us/Salih-Ozcan/leistungsdatendetails/spieler/244940/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Salih-Ozcan/transfers/spieler/244940/transfer_id/3858841
#
#  Dados de Arne-Maier
# https://www.transfermarkt.us/Arne-Maier/leistungsdatendetails/spieler/296397
# https://www.transfermarkt.us/Arne-Maier/profil/spieler/296397
# Foot: right
# https://www.transfermarkt.us/Arne-Maier/leistungsdatendetails/spieler/296397/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Arne-Maier/transfers/spieler/296397/transfer_id/3859994
#
#  Dados de Luis-Milla
# https://www.transfermarkt.us/Luis-Milla/leistungsdatendetails/spieler/281989
# https://www.transfermarkt.us/Luis-Milla/profil/spieler/281989
# Foot: right
# https://www.transfermarkt.us/Luis-Milla/leistungsdatendetails/spieler/281989/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Luis-Milla/transfers/spieler/281989/transfer_id/3969817
#
#  Dados de Emiliano-Martinez
# https://www.transfermarkt.us/Emiliano-Martinez/leistungsdatendetails/spieler/707447
# https://www.transfermarkt.us/Emiliano-Martinez/profil/spieler/707447
# Foot: right
# https://www.transfermarkt.us/Emiliano-Martinez/leistungsdatendetails/spieler/707447/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Emiliano-Martinez/transfers/spieler/707447/transfer_id/4146764
#
#  Dados de Jurgen-Ekkelenkamp
# https://www.transfermarkt.us/Jurgen-Ekkelenkamp/leistungsdatendetails/spieler/361068
# https://www.transfermarkt.us/Jurgen-Ekkelenkamp/profil/spieler/361068
# Foot: right
# https://www.transfermarkt.us/Jurgen-Ekkelenkamp/leistungsdatendetails/spieler/361068/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jurgen-Ekkelenkamp/transfers/spieler/361068/transfer_id/3997813
#
#  Dados de Pablo-Torre
# https://www.transfermarkt.us/Pablo-Torre/leistungsdatendetails/spieler/720038
# https://www.transfermarkt.us/Pablo-Torre/profil/spieler/720038
# Foot: right
# https://www.transfermarkt.us/Pablo-Torre/leistungsdatendetails/spieler/720038/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Pablo-Torre/transfers/spieler/720038/transfer_id/3769942
#
#  Dados de Salis-Abdul-Samed
# https://www.transfermarkt.us/Salis-Abdul-Samed/leistungsdatendetails/spieler/688707
# https://www.transfermarkt.us/Salis-Abdul-Samed/profil/spieler/688707
# Foot: right
# https://www.transfermarkt.us/Salis-Abdul-Samed/leistungsdatendetails/spieler/688707/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Salis-Abdul-Samed/transfers/spieler/688707/transfer_id/3902127
#
#  Dados de Emirhan-Ilkhan
# https://www.transfermarkt.us/Emirhan-Ilkhan/leistungsdatendetails/spieler/743091
# https://www.transfermarkt.us/Emirhan-Ilkhan/profil/spieler/743091
# Foot: right
# https://www.transfermarkt.us/Emirhan-Ilkhan/leistungsdatendetails/spieler/743091/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Emirhan-Ilkhan/transfers/spieler/743091/transfer_id/3998957
#
#  Dados de Arthur-Melo
# https://www.transfermarkt.us/Arthur-Melo/leistungsdatendetails/spieler/362842
# https://www.transfermarkt.us/Arthur-Melo/profil/spieler/362842
# Foot: right
# https://www.transfermarkt.us/Arthur-Melo/leistungsdatendetails/spieler/362842/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Arthur-Melo/transfers/spieler/362842/transfer_id/4052114
#
#  Dados de Kristjan-Asllani
# https://www.transfermarkt.us/Kristjan-Asllani/leistungsdatendetails/spieler/543771
# https://www.transfermarkt.us/Kristjan-Asllani/profil/spieler/543771
# Foot: right
# https://www.transfermarkt.us/Kristjan-Asllani/leistungsdatendetails/spieler/543771/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Kristjan-Asllani/transfers/spieler/543771/transfer_id/3912062
#
#  Dados de Edu-Exposito
# https://www.transfermarkt.us/Edu-Exposito/leistungsdatendetails/spieler/506248
# https://www.transfermarkt.us/Edu-Exposito/profil/spieler/506248
# Foot: right
# https://www.transfermarkt.us/Edu-Exposito/leistungsdatendetails/spieler/506248/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Edu-Exposito/transfers/spieler/506248/transfer_id/4000157
#
#  Dados de Daniel-Kofi-Kyereh
# https://www.transfermarkt.us/Daniel-Kofi-Kyereh/leistungsdatendetails/spieler/272587
# https://www.transfermarkt.us/Daniel-Kofi-Kyereh/profil/spieler/272587
# Foot: right
# https://www.transfermarkt.us/Daniel-Kofi-Kyereh/leistungsdatendetails/spieler/272587/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Daniel-Kofi-Kyereh/transfers/spieler/272587/transfer_id/3906438
#
#  Dados de Johann-Lepenant
# https://www.transfermarkt.us/Johann-Lepenant/leistungsdatendetails/spieler/585973
# https://www.transfermarkt.us/Johann-Lepenant/profil/spieler/585973
# Foot: right
# https://www.transfermarkt.us/Johann-Lepenant/leistungsdatendetails/spieler/585973/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Johann-Lepenant/transfers/spieler/585973/transfer_id/3898672
#
#  Dados de Stephen-Eustaquio
# https://www.transfermarkt.us/Stephen-Eustaquio/leistungsdatendetails/spieler/512913
# https://www.transfermarkt.us/Stephen-Eustaquio/profil/spieler/512913
# Foot: right
# https://www.transfermarkt.us/Stephen-Eustaquio/leistungsdatendetails/spieler/512913/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Stephen-Eustaquio/transfers/spieler/512913/transfer_id/3868298
#
#  Dados de Idrissa-Gueye
# https://www.transfermarkt.us/Idrissa-Gueye/leistungsdatendetails/spieler/126665
# https://www.transfermarkt.us/Idrissa-Gueye/profil/spieler/126665
# Foot: right
# https://www.transfermarkt.us/Idrissa-Gueye/leistungsdatendetails/spieler/126665/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Idrissa-Gueye/transfers/spieler/126665/transfer_id/4051349
#
#  Dados de Franco-Cristaldo
# https://www.transfermarkt.us/Franco-Cristaldo/leistungsdatendetails/spieler/332259
# https://www.transfermarkt.us/Franco-Cristaldo/profil/spieler/332259
# Foot: right
# https://www.transfermarkt.us/Franco-Cristaldo/leistungsdatendetails/spieler/332259/saison/2021/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Franco-Cristaldo/transfers/spieler/332259/transfer_id/4186222
#
#  Dados de Jean-Onana
# https://www.transfermarkt.us/Jean-Onana/leistungsdatendetails/spieler/656441
# ...
#
#  Dados de Woo-yeong-Jeong
# https://www.transfermarkt.us/Woo-yeong-Jeong/leistungsdatendetails/spieler/297583
# https://www.transfermarkt.us/Woo-yeong-Jeong/profil/spieler/297583
# Foot: right
# https://www.transfermarkt.us/Woo-yeong-Jeong/leistungsdatendetails/spieler/297583/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Woo-yeong-Jeong/transfers/spieler/297583/transfer_id/4496024
#
#  Dados de Breno-Lemos
# https://www.transfermarkt.us/Breno-Lemos/leistungsdatendetails/spieler/1085060
# https://www.transfermarkt.us/Breno-Lemos/profil/spieler/1085060
# Foot: right
# https://www.transfermarkt.us/Breno-Lemos/leistungsdatendetails/spieler/1085060/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Breno-Lemos/transfers/spieler/1085060/transfer_id/4824068
#
#  Dados de Kerem-Demirbay
# https://www.transfermarkt.us/Kerem-Demirbay/leistungsdatendetails/spieler/125858
# https://www.transfermarkt.us/Kerem-Demirbay/profil/spieler/125858
# Foot: left
# https://www.transfermarkt.us/Kerem-Demirbay/leistungsdatendetails/spieler/125858/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Kerem-Demirbay/transfers/spieler/125858/transfer_id/4551035
#
#  Dados de Kevin-Castano
# https://www.transfermarkt.us/Kevin-Castano/leistungsdatendetails/spieler/857948
# https://www.transfermarkt.us/Kevin-Castano/profil/spieler/857948
# Foot: right
# https://www.transfermarkt.us/Kevin-Castano/leistungsdatendetails/spieler/857948/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Kevin-Castano/transfers/spieler/857948/transfer_id/4460217
#
#  Dados de Tomas-Belmonte
# https://www.transfermarkt.us/Tomas-Belmonte/leistungsdatendetails/spieler/483446
# https://www.transfermarkt.us/Tomas-Belmonte/profil/spieler/483446
# Foot: right
# https://www.transfermarkt.us/Tomas-Belmonte/leistungsdatendetails/spieler/483446/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Tomas-Belmonte/transfers/spieler/483446/transfer_id/4532461
#
#  Dados de Braian-Ojeda
# https://www.transfermarkt.us/Braian-Ojeda/leistungsdatendetails/spieler/491596
# https://www.transfermarkt.us/Braian-Ojeda/profil/spieler/491596
# Foot: right
# https://www.transfermarkt.us/Braian-Ojeda/leistungsdatendetails/spieler/491596/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Braian-Ojeda/transfers/spieler/491596/transfer_id/4554379
#
#  Dados de Salvatore-Esposito
# https://www.transfermarkt.us/Salvatore-Esposito/leistungsdatendetails/spieler/390160
# https://www.transfermarkt.us/Salvatore-Esposito/profil/spieler/390160
# Foot: right
# https://www.transfermarkt.us/Salvatore-Esposito/leistungsdatendetails/spieler/390160/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Salvatore-Esposito/transfers/spieler/390160/transfer_id/4410433
#
#  Dados de Jorge-Carrascal
# https://www.transfermarkt.us/Jorge-Carrascal/leistungsdatendetails/spieler/354145
# https://www.transfermarkt.us/Jorge-Carrascal/profil/spieler/354145
# Foot: right
# https://www.transfermarkt.us/Jorge-Carrascal/leistungsdatendetails/spieler/354145/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jorge-Carrascal/transfers/spieler/354145/transfer_id/4610442
#
#  Dados de Alexis-Flips
# https://www.transfermarkt.us/Alexis-Flips/leistungsdatendetails/spieler/395242
# https://www.transfermarkt.us/Alexis-Flips/profil/spieler/395242
# Foot: right
# https://www.transfermarkt.us/Alexis-Flips/leistungsdatendetails/spieler/395242/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Alexis-Flips/transfers/spieler/395242/transfer_id/4579044
#
#  Dados de Oriol-Romeu
# https://www.transfermarkt.us/Oriol-Romeu/leistungsdatendetails/spieler/66100
# https://www.transfermarkt.us/Oriol-Romeu/profil/spieler/66100
# Foot: right
# https://www.transfermarkt.us/Oriol-Romeu/leistungsdatendetails/spieler/66100/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Oriol-Romeu/transfers/spieler/66100/transfer_id/4516226
#
#  Dados de Valentino-Lazaro
# https://www.transfermarkt.us/Valentino-Lazaro/leistungsdatendetails/spieler/186368
# https://www.transfermarkt.us/Valentino-Lazaro/profil/spieler/186368
# Foot: right
# https://www.transfermarkt.us/Valentino-Lazaro/leistungsdatendetails/spieler/186368/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Valentino-Lazaro/transfers/spieler/186368/transfer_id/4602601
#
#  Dados de Szymon-Zurkowski
# https://www.transfermarkt.us/Szymon-Zurkowski/leistungsdatendetails/spieler/387234
# https://www.transfermarkt.us/Szymon-Zurkowski/profil/spieler/387234
# Foot: right
# https://www.transfermarkt.us/Szymon-Zurkowski/leistungsdatendetails/spieler/387234/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Szymon-Zurkowski/transfers/spieler/387234/transfer_id/4434057
#
#  Dados de David-Terans
# https://www.transfermarkt.us/David-Terans/leistungsdatendetails/spieler/261309
# https://www.transfermarkt.us/David-Terans/profil/spieler/261309
# Foot: left
# https://www.transfermarkt.us/David-Terans/leistungsdatendetails/spieler/261309/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/David-Terans/transfers/spieler/261309/transfer_id/4493700
#
#  Dados de Jorge-Rodriguez
# https://www.transfermarkt.us/Jorge-Rodriguez/leistungsdatendetails/spieler/333760
# https://www.transfermarkt.us/Jorge-Rodriguez/profil/spieler/333760
# Foot: right
# https://www.transfermarkt.us/Jorge-Rodriguez/leistungsdatendetails/spieler/333760/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jorge-Rodriguez/transfers/spieler/333760/transfer_id/4803781
#
#  Dados de Bartosz-Slisz
# https://www.transfermarkt.us/Bartosz-Slisz/leistungsdatendetails/spieler/382429
# https://www.transfermarkt.us/Bartosz-Slisz/profil/spieler/382429
# Foot: right
# https://www.transfermarkt.us/Bartosz-Slisz/leistungsdatendetails/spieler/382429/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Bartosz-Slisz/transfers/spieler/382429/transfer_id/4828981
#
#  Dados de Kevin-Zenon
# https://www.transfermarkt.us/Kevin-Zenon/leistungsdatendetails/spieler/829966
# https://www.transfermarkt.us/Kevin-Zenon/profil/spieler/829966
# Foot: left
# https://www.transfermarkt.us/Kevin-Zenon/leistungsdatendetails/spieler/829966/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Kevin-Zenon/transfers/spieler/829966/transfer_id/4839215
#
#  Dados de Vitor-Bueno
# https://www.transfermarkt.us/Vitor-Bueno/leistungsdatendetails/spieler/390368
# https://www.transfermarkt.us/Vitor-Bueno/profil/spieler/390368
# Foot: right
# https://www.transfermarkt.us/Vitor-Bueno/leistungsdatendetails/spieler/390368/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Vitor-Bueno/transfers/spieler/390368/transfer_id/4819186
#
#  Dados de Ondrej-Duda
# https://www.transfermarkt.us/Ondrej-Duda/leistungsdatendetails/spieler/232418
# https://www.transfermarkt.us/Ondrej-Duda/profil/spieler/232418
# Foot: right
# https://www.transfermarkt.us/Ondrej-Duda/leistungsdatendetails/spieler/232418/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ondrej-Duda/transfers/spieler/232418/transfer_id/4433385
#
#  Dados de Charles-De-Ketelaere
# https://www.transfermarkt.us/Charles-De-Ketelaere/leistungsdatendetails/spieler/435772
# https://www.transfermarkt.us/Charles-De-Ketelaere/profil/spieler/435772
# Foot: left
# https://www.transfermarkt.us/Charles-De-Ketelaere/leistungsdatendetails/spieler/435772/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Charles-De-Ketelaere/transfers/spieler/435772/transfer_id/4588441
#
#  Dados de Donny-van-de-Beek
# https://www.transfermarkt.us/Donny-van-de-Beek/leistungsdatendetails/spieler/288255
# https://www.transfermarkt.us/Donny-van-de-Beek/profil/spieler/288255
# Foot: right
# https://www.transfermarkt.us/Donny-van-de-Beek/leistungsdatendetails/spieler/288255/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Donny-van-de-Beek/transfers/spieler/288255/transfer_id/4793787
#
#  Dados de Mandela-Keita
# https://www.transfermarkt.us/Mandela-Keita/leistungsdatendetails/spieler/707844
# https://www.transfermarkt.us/Mandela-Keita/profil/spieler/707844
# Foot: right
# https://www.transfermarkt.us/Mandela-Keita/leistungsdatendetails/spieler/707844/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mandela-Keita/transfers/spieler/707844/transfer_id/4575291
#
#  Dados de Mathias-Normann
# https://www.transfermarkt.us/Mathias-Normann/leistungsdatendetails/spieler/257805
# https://www.transfermarkt.us/Mathias-Normann/profil/spieler/257805
# Foot: right
# https://www.transfermarkt.us/Mathias-Normann/leistungsdatendetails/spieler/257805/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mathias-Normann/transfers/spieler/257805/transfer_id/4595460
#
#  Dados de Fredrik-Midtsjo
# https://www.transfermarkt.us/Fredrik-Midtsjo/leistungsdatendetails/spieler/136180
# https://www.transfermarkt.us/Fredrik-Midtsjo/profil/spieler/136180
# Foot: right
# https://www.transfermarkt.us/Fredrik-Midtsjo/leistungsdatendetails/spieler/136180/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Fredrik-Midtsjo/transfers/spieler/136180/transfer_id/4635176
#
#  Dados de Marco-Richter
# https://www.transfermarkt.us/Marco-Richter/leistungsdatendetails/spieler/279009
# https://www.transfermarkt.us/Marco-Richter/profil/spieler/279009
# Foot: right
# https://www.transfermarkt.us/Marco-Richter/leistungsdatendetails/spieler/279009/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Marco-Richter/transfers/spieler/279009/transfer_id/4600511
#
#  Dados de Samu-Costa
# https://www.transfermarkt.us/Samu-Costa/leistungsdatendetails/spieler/657430
# https://www.transfermarkt.us/Samu-Costa/profil/spieler/657430
# Foot: left
# https://www.transfermarkt.us/Samu-Costa/leistungsdatendetails/spieler/657430/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Samu-Costa/transfers/spieler/657430/transfer_id/4575353
#
#  Dados de Tonny-Vilhena
# https://www.transfermarkt.us/Tonny-Vilhena/leistungsdatendetails/spieler/182581
# https://www.transfermarkt.us/Tonny-Vilhena/profil/spieler/182581
# Foot: left
# https://www.transfermarkt.us/Tonny-Vilhena/leistungsdatendetails/spieler/182581/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Tonny-Vilhena/transfers/spieler/182581/transfer_id/4487168
#
#  Dados de Paul-Akouokou
# https://www.transfermarkt.us/Paul-Akouokou/leistungsdatendetails/spieler/429901
# https://www.transfermarkt.us/Paul-Akouokou/profil/spieler/429901
# Foot: right
# https://www.transfermarkt.us/Paul-Akouokou/leistungsdatendetails/spieler/429901/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Paul-Akouokou/transfers/spieler/429901/transfer_id/4624173
#
#  Dados de Martin-Payero
# https://www.transfermarkt.us/Martin-Payero/leistungsdatendetails/spieler/555820
# https://www.transfermarkt.us/Martin-Payero/profil/spieler/555820
# Foot: right
# https://www.transfermarkt.us/Martin-Payero/leistungsdatendetails/spieler/555820/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Martin-Payero/transfers/spieler/555820/transfer_id/4623193
#
#  Dados de Mohamed-Kaba
# https://www.transfermarkt.us/Mohamed-Kaba/leistungsdatendetails/spieler/911328
# https://www.transfermarkt.us/Mohamed-Kaba/profil/spieler/911328
# Foot: right
# https://www.transfermarkt.us/Mohamed-Kaba/leistungsdatendetails/spieler/911328/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mohamed-Kaba/transfers/spieler/911328/transfer_id/4583667
#
#  Dados de Mahdi-Camara
# https://www.transfermarkt.us/Mahdi-Camara/leistungsdatendetails/spieler/324795
# https://www.transfermarkt.us/Mahdi-Camara/profil/spieler/324795
# Foot: right
# https://www.transfermarkt.us/Mahdi-Camara/leistungsdatendetails/spieler/324795/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mahdi-Camara/transfers/spieler/324795/transfer_id/4467810
#
#  Dados de Odin-Thiago-Holm
# https://www.transfermarkt.us/Odin-Thiago-Holm/leistungsdatendetails/spieler/581109
# https://www.transfermarkt.us/Odin-Thiago-Holm/profil/spieler/581109
# Foot: right
# https://www.transfermarkt.us/Odin-Thiago-Holm/leistungsdatendetails/spieler/581109/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Odin-Thiago-Holm/transfers/spieler/581109/transfer_id/4450446
#
#  Dados de Hamdi-Fathi
# https://www.transfermarkt.us/Hamdi-Fathi/leistungsdatendetails/spieler/340303
# https://www.transfermarkt.us/Hamdi-Fathi/profil/spieler/340303
# Foot: right
# https://www.transfermarkt.us/Hamdi-Fathi/leistungsdatendetails/spieler/340303/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Hamdi-Fathi/transfers/spieler/340303/transfer_id/4477382
#
#  Dados de Paulinho
# https://www.transfermarkt.us/Paulinho/leistungsdatendetails/spieler/212923
# https://www.transfermarkt.us/Paulinho/profil/spieler/212923
# Foot: left
# https://www.transfermarkt.us/Paulinho/leistungsdatendetails/spieler/212923/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Paulinho/transfers/spieler/212923/transfer_id/4592825
#
#  Dados de Mateusz-Legowski
# https://www.transfermarkt.us/Mateusz-Legowski/leistungsdatendetails/spieler/570466
# https://www.transfermarkt.us/Mateusz-Legowski/profil/spieler/570466
# Foot: right
# https://www.transfermarkt.us/Mateusz-Legowski/leistungsdatendetails/spieler/570466/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mateusz-Legowski/transfers/spieler/570466/transfer_id/4589812
#
#  Dados de Koba-Koindredi
# https://www.transfermarkt.us/Koba-Koindredi/leistungsdatendetails/spieler/569375
# https://www.transfermarkt.us/Koba-Koindredi/profil/spieler/569375
# Foot: left
# https://www.transfermarkt.us/Koba-Koindredi/leistungsdatendetails/spieler/569375/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Koba-Koindredi/transfers/spieler/569375/transfer_id/4857765
#
#  Dados de Carlos-Dotor
# https://www.transfermarkt.us/Carlos-Dotor/leistungsdatendetails/spieler/623524
# https://www.transfermarkt.us/Carlos-Dotor/profil/spieler/623524
# Foot: right
# https://www.transfermarkt.us/Carlos-Dotor/leistungsdatendetails/spieler/623524/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Carlos-Dotor/transfers/spieler/623524/transfer_id/4520765
#
#  Dados de Elione-Fernandes-Neto
# https://www.transfermarkt.us/Elione-Fernandes-Neto/leistungsdatendetails/spieler/934519
# https://www.transfermarkt.us/Elione-Fernandes-Neto/profil/spieler/934519
# Foot: both
# https://www.transfermarkt.us/Elione-Fernandes-Neto/leistungsdatendetails/spieler/934519/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Elione-Fernandes-Neto/transfers/spieler/934519/transfer_id/4571899
#
#  Dados de Luca-Lipani
# https://www.transfermarkt.us/Luca-Lipani/leistungsdatendetails/spieler/724106
# https://www.transfermarkt.us/Luca-Lipani/profil/spieler/724106
# Foot: right
# https://www.transfermarkt.us/Luca-Lipani/leistungsdatendetails/spieler/724106/saison/2022/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Luca-Lipani/transfers/spieler/724106/transfer_id/4569732
#
#  Dados de Marvelous-Nakamba

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Agrupamento de dados
agrupado_temp = Nome_Id_Temp.groupby('Temp').size()

# Configurar o estilo do gráfico
sns.set(style="whitegrid")

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x=agrupado_temp.index, y=agrupado_temp.values, palette="viridis")

# Adicionar título e rótulos aos eixos
plt.title('Número de Transferências por Temporada')
plt.xlabel('Temporada')
plt.ylabel('Número de Transferências')

# Rotacionar os rótulos do eixo x para melhor visualização
plt.xticks(rotation=45)

# Adicionar os valores em cima de cada barra
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.0f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', 
                     xytext = (0, 9), 
                     textcoords = 'offset points')

# Mostrar o gráfico
plt.show()
