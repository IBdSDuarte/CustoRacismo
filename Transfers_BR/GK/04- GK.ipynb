# %% [markdown]
# # Import/load

# %%
import pandas as pd
import numpy as np

# %%
df_base = pd.read_csv('02-GK.csv')
df_home = pd.read_csv('03-GK-home.csv')
df_stats = pd.read_csv('03-GK-stats.csv')

# %% [markdown]
# # head

# %%
df_base.head(3).T
# Out:
#                                                                      0  \
# ID                                                              177547
# Perfil                                  /matheus/profil/spieler/177547
# Nome                                                           Matheus
# Posição                                                     Goalkeeper
# Idade                                                               22
# Valor de Mercado                                                   0.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /america-futebol-clube-mg-/startseite/verein/2...
# Clube Antigo                                                América-MG
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo         /sc-braga/startseite/verein/1075/saison_id/2014
# Clube Novo                                                    SC Braga
# URL Liga Nova        /liga-nos/transfers/wettbewerb/PO1/saison_id/2014
# Liga Nova                                                     Liga NOS
# Valor Transferência                                          2400000.0
# Ano da Tranferência                                               2014
#
#                                                                      1  \
# ID                                                               75071
# Perfil                                    /aranha/profil/spieler/75071
# Nome                                                            Aranha
# Posição                                                     Goalkeeper
# Idade                                                               34
# Valor de Mercado                                             2000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo       /fc-santos/startseite/verein/221/saison_id/2014
# Clube Antigo                                                    Santos
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /se-palmeiras-sao-paulo/startseite/verein/1023...
# Clube Novo                                                   Palmeiras
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2014
#
#                                                                      2
# ID                                                               22412
# Perfil                               /julio-cesar/profil/spieler/22412
# Nome                                                       Júlio César
# Posição                                                     Goalkeeper
# Idade                                                               34
# Valor de Mercado                                             1500000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /queens-park-rangers/startseite/verein/1039/sa...
# Clube Antigo                                                       QPR
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /benfica-lissabon/startseite/verein/294/saison...
# Clube Novo                                                     Benfica
# URL Liga Nova        /liga-nos/transfers/wettbewerb/PO1/saison_id/2014
# Liga Nova                                                     Liga NOS
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2014

# %%
df_home.head(3).T
# Out:
#                                 0                  1                 2
# Unnamed: 0                      0                  1                 2
# ID                         177547              75071             22412
# nome_hifen                Matheus             Aranha       Julio-Cesar
# pe                          right               left              left
# data_nasc       Mar 29, 1992 (32)  Nov 17, 1980 (44)  Sep 3, 1979 (45)
# local_nasc         Belo Horizonte       Pouso Alegre   Duque de Caxias
# cidadania     2, Brazil, Portugal          1, Brazil         1, Brazil
# altura                     1,90 m             1,93 m            1,86 m
# convocacoes                     0                  0                87
# gols_selecao                    0                  0                 0

# %%
df_stats.head(3).T
# Out:
#                       0       1      2
# Unnamed: 0            0       1      2
# ID               177547   75071  22412
# ano_stat           2013    2013   2013
# escalado             26      58      9
# jogou                26      58      8
# ppm                1.54    1.71   1.13
# gols_para             -       -      -
# assistencias          0       0      0
# gols_contra           -       -      -
# entrou                -       -      -
# saiu                  -       -      -
# amarelo               -       5      1
# amarelo_duplo         -       -      -
# vermelho              -       -      -
# Gols_de_penalti      31      53     13
# minutos_por_gol       8      23      2
# minutos          2.340'  5.220'   720'

# %% [markdown]
# # Checagem de tipo

# %%
print("df_base:",df_base.shape)
print("df_home:",df_home.shape)
print("df_stats:",df_stats.shape)
# Out:
# df_base: (264, 17)
# df_home: (150, 10)
# df_stats: (253, 17)

# %%
df_base.dtypes
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado       float64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência    float64
# Ano da Tranferência      int64
# dtype: object

# %%
df_home.dtypes
# Out:
# Unnamed: 0       int64
# ID               int64
# nome_hifen      object
# pe              object
# data_nasc       object
# local_nasc      object
# cidadania       object
# altura          object
# convocacoes      int64
# gols_selecao     int64
# dtype: object

# %%
df_stats.dtypes
# Out:
# Unnamed: 0           int64
# ID                   int64
# ano_stat             int64
# escalado             int64
# jogou               object
# ppm                float64
# gols_para           object
# assistencias         int64
# gols_contra         object
# entrou              object
# saiu                object
# amarelo             object
# amarelo_duplo       object
# vermelho            object
# Gols_de_penalti     object
# minutos_por_gol     object
# minutos             object
# dtype: object

# %% [markdown]
# # Descarte de colunas

# %%
df_home = df_home.drop(columns=["Unnamed: 0"])
df_home = df_home.drop(columns=["nome_hifen"])


df_stats = df_stats.drop(columns=["Unnamed: 0"])

# %% [markdown]
# # Merges

# %%
df_merged = df_base.merge(df_home, on="ID", how="inner")
print("df_merged:",df_merged.shape)
# Out:
# df_merged: (264, 24)

# %%
df_merged.sample(3).T
# Out:
#                                                                    68   \
# ID                                                              105470
# Perfil                                  /alisson/profil/spieler/105470
# Nome                                                           Alisson
# Posição                                                     Goalkeeper
# Idade                                                               25
# Valor de Mercado                                            60000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo           /as-rom/startseite/verein/12/saison_id/2018
# Clube Antigo                                                   AS Roma
# URL Liga Antiga       /serie-a/transfers/wettbewerb/IT1/saison_id/2018
# Liga Antiga                                                    Serie A
# URL Clube Novo       /fc-liverpool/startseite/verein/31/saison_id/2018
# Clube Novo                                                   Liverpool
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                         62500000.0
# Ano da Tranferência                                               2018
# pe                                                               right
# data_nasc                                             Oct 2, 1992 (32)
# local_nasc                                               Novo Hamburgo
# cidadania                                           2, Brazil, England
# altura                                                          1,93 m
# convocacoes                                                         70
# gols_selecao                                                         0
#
#                                                                    253  \
# ID                                                              384159
# Perfil                                   /caique/profil/spieler/384159
# Nome                                                            Caíque
# Posição                                                     Goalkeeper
# Idade                                                               26
# Valor de Mercado                                                   0.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /ypiranga-futebol-clube-rs-/startseite/verein/...
# Clube Antigo                                               Ypiranga-RS
# URL Liga Antiga      /campeonato-brasileiro-serie-c/transfers/pokal...
# Liga Antiga                                                    Série C
# URL Clube Novo       /gremio-porto-alegre/startseite/verein/210/sai...
# Clube Novo                                                      Grêmio
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                           100000.0
# Ano da Tranferência                                               2023
# pe                                                               right
# data_nasc                                            Jul 31, 1997 (27)
# local_nasc                                                    Salvador
# cidadania                                                    1, Brazil
# altura                                                          1,98 m
# convocacoes                                                          6
# gols_selecao                                                         0
#
#                                                                    94
# ID                                                              374094
# Perfil                        /douglas-friedrich/profil/spieler/374094
# Nome                                                 Douglas Friedrich
# Posição                                                     Goalkeeper
# Idade                                                               34
# Valor de Mercado                                              275000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /al-khaleej/startseite/verein/6070/saison_id/2023
# Clube Antigo                                                Al-Khaleej
# URL Liga Antiga      /saudi-professional-league/transfers/wettbewer...
# Liga Antiga                                           Saudi Pro League
# URL Clube Novo       /avai-fc-sc-/startseite/verein/2035/saison_id/...
# Clube Novo                                                     Avaí FC
# URL Liga Nova        /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Nova                                                      Série B
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2023
# pe                                                               right
# data_nasc                                            Dec 12, 1988 (36)
# local_nasc                                                  Candelária
# cidadania                                                    1, Brazil
# altura                                                          1,94 m
# convocacoes                                                          0
# gols_selecao                                                         0

# %%
# Cria uma nova coluna em df_stats com ano_stat + 1
df_stats["ano_transferencia"] = df_stats["ano_stat"] + 1

# Faz o merge com base em ID e no ano ajustado
df_final = df_merged.merge(
    df_stats,
    left_on=["ID", "Ano da Tranferência"],
    right_on=["ID", "ano_transferencia"],
    how="left"
)

# Remove a coluna temporária "ano_transferencia" se não for mais necessária
df_final = df_final.drop(columns=["ano_transferencia"])
print("df_final:",df_final.shape)
# Out:
# df_final: (264, 39)

# %% [markdown]
# # Limpeza e tipagem

# %%
print(df_final.columns)  # Listar todas as colunas para conferir se tudo está certo
# Out:
# Index(['ID', 'Perfil', 'Nome', 'Posição', 'Idade', 'Valor de Mercado',
#        'Nacionalidade', 'URL Clube Antigo', 'Clube Antigo', 'URL Liga Antiga',
#        'Liga Antiga', 'URL Clube Novo', 'Clube Novo', 'URL Liga Nova',
#        'Liga Nova', 'Valor Transferência', 'Ano da Tranferência', 'pe',
#        'data_nasc', 'local_nasc', 'cidadania', 'altura', 'convocacoes',
#        'gols_selecao', 'ano_stat', 'escalado', 'jogou', 'ppm', 'gols_para',
#        'assistencias', 'gols_contra', 'entrou', 'saiu', 'amarelo',
#        'amarelo_duplo', 'vermelho', 'Gols_de_penalti', 'minutos_por_gol',
#        'minutos'],
#       dtype='object')

# %%
print(df_final.sample(1).T)  # Ver uma linha aleatória
# Out:
#                                                                    231
# ID                                                              258369
# Perfil                                 /georgemy/profil/spieler/258369
# Nome                                                          Georgemy
# Posição                                                     Goalkeeper
# Idade                                                               29
# Valor de Mercado                                              300000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /brusque-futebol-clube-sc-/startseite/verein/1...
# Clube Antigo                                                   Brusque
# URL Liga Antiga                                                    NaN
# Liga Antiga                                                     Brazil
# URL Clube Novo       /centro-sportivo-alagoano-al-/startseite/verei...
# Clube Novo                                                         CSA
# URL Liga Nova                                                      NaN
# Liga Nova                                                       Brazil
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2024
# pe                                                               right
# data_nasc                                            Aug 15, 1995 (29)
# local_nasc                                                   Americana
# cidadania                                             2, Brazil, Italy
# altura                                                          1,97 m
# convocacoes                                                          1
# gols_selecao                                                         0
# ano_stat                                                          2023
# escalado                                                            52
# jogou                                                                1
# ppm                                                                NaN
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 -
# amarelo                                                              -
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      1
# minutos_por_gol                                                      -
# minutos                                                            90'

# %%
print(df_final.isnull().sum())  # Verificar se há valores NaN após o merg
# Out:
# ID                      0
# Perfil                  0
# Nome                    0
# Posição                 0
# Idade                   0
# Valor de Mercado        0
# Nacionalidade           0
# URL Clube Antigo        0
# Clube Antigo            0
# URL Liga Antiga        27
# Liga Antiga             1
# URL Clube Novo          0
# Clube Novo              0
# URL Liga Nova          23
# Liga Nova               0
# Valor Transferência     0
# Ano da Tranferência     0
# pe                      3
# data_nasc               0
# local_nasc              1
# cidadania               0
# altura                  2
# convocacoes             0
# gols_selecao            0
# ano_stat                0
# escalado                0
# jogou                   0
# ppm                    23
# gols_para               0
# assistencias            0
# gols_contra             0
# entrou                  0
# saiu                    0
# amarelo                 0
# amarelo_duplo           0
# vermelho                0
# Gols_de_penalti         0
# minutos_por_gol         0
# minutos                 0
# dtype: int64

# %%
print(df_final.dtypes)
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado       float64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência    float64
# Ano da Tranferência      int64
# pe                      object
# data_nasc               object
# local_nasc              object
# cidadania               object
# altura                  object
# convocacoes              int64
# gols_selecao             int64
# ano_stat                 int64
# escalado                 int64
# jogou                   object
# ppm                    float64
# gols_para               object
# assistencias             int64
# gols_contra             object
# entrou                  object
# saiu                    object
# amarelo                 object
# amarelo_duplo           object
# vermelho                object
# Gols_de_penalti         object
# minutos_por_gol         object
# minutos                 object
# dtype: object

# %%
df_final.head(3).T
# Out:
#                                                                      0  \
# ID                                                              177547
# Perfil                                  /matheus/profil/spieler/177547
# Nome                                                           Matheus
# Posição                                                     Goalkeeper
# Idade                                                               22
# Valor de Mercado                                                   0.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /america-futebol-clube-mg-/startseite/verein/2...
# Clube Antigo                                                América-MG
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo         /sc-braga/startseite/verein/1075/saison_id/2014
# Clube Novo                                                    SC Braga
# URL Liga Nova        /liga-nos/transfers/wettbewerb/PO1/saison_id/2014
# Liga Nova                                                     Liga NOS
# Valor Transferência                                          2400000.0
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Mar 29, 1992 (32)
# local_nasc                                              Belo Horizonte
# cidadania                                          2, Brazil, Portugal
# altura                                                          1,90 m
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            26
# jogou                                                               26
# ppm                                                               1.54
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 -
# amarelo                                                              -
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                     31
# minutos_por_gol                                                      8
# minutos                                                         2.340'
#
#                                                                      1  \
# ID                                                               75071
# Perfil                                    /aranha/profil/spieler/75071
# Nome                                                            Aranha
# Posição                                                     Goalkeeper
# Idade                                                               34
# Valor de Mercado                                             2000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo       /fc-santos/startseite/verein/221/saison_id/2014
# Clube Antigo                                                    Santos
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /se-palmeiras-sao-paulo/startseite/verein/1023...
# Clube Novo                                                   Palmeiras
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2014
# pe                                                                left
# data_nasc                                            Nov 17, 1980 (44)
# local_nasc                                                Pouso Alegre
# cidadania                                                    1, Brazil
# altura                                                          1,93 m
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            58
# jogou                                                               58
# ppm                                                               1.71
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 -
# amarelo                                                              5
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                     53
# minutos_por_gol                                                     23
# minutos                                                         5.220'
#
#                                                                      2
# ID                                                               75071
# Perfil                                    /aranha/profil/spieler/75071
# Nome                                                            Aranha
# Posição                                                     Goalkeeper
# Idade                                                               35
# Valor de Mercado                                              450000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /joinville-ec-sc-/startseite/verein/3330/saiso...
# Clube Antigo                                              Joinville-SC
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo       /aa-ponte-preta/startseite/verein/1134/saison_...
# Clube Novo                                                 Ponte Preta
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                            55000.0
# Ano da Tranferência                                               2016
# pe                                                                left
# data_nasc                                            Nov 17, 1980 (44)
# local_nasc                                                Pouso Alegre
# cidadania                                                    1, Brazil
# altura                                                          1,93 m
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2015
# escalado                                                            26
# jogou                                                               26
# ppm                                                               1.31
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 1
# amarelo                                                              2
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                     30
# minutos_por_gol                                                      8
# minutos                                                         2.340'

# %%
#df_final.replace("-", pd.NA, inplace=True)

# %%
df_final["altura"] = df_final["altura"].str.replace(" m", "").str.replace(",", ".").astype(float)

# %%
# Função para converter valores no formato '1.025'
def convert_minutes(val):
    if isinstance(val, str) and val.endswith("'"):
        # Remover o apóstrofo e multiplicar por 1000
        return int(float(val.replace("'", "")) * 1000)
    return val  # Se não for uma string no formato, retorna o valor original

# Aplicando a função nas colunas 'minutos' e 'minutos_por_gol'
df_final['minutos_por_gol'] = df_final['minutos_por_gol'].apply(convert_minutes)
df_final['minutos'] = df_final['minutos'].apply(convert_minutes)

# %%
df_final["Valor de Mercado"] = df_final["Valor de Mercado"].astype("int64")
df_final["Valor Transferência"] = df_final["Valor Transferência"].astype("int64")

# %%
df_final.dtypes
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado         int64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência      int64
# Ano da Tranferência      int64
# pe                      object
# data_nasc               object
# local_nasc              object
# cidadania               object
# altura                 float64
# convocacoes              int64
# gols_selecao             int64
# ano_stat                 int64
# escalado                 int64
# jogou                   object
# ppm                    float64
# gols_para               object
# assistencias             int64
# gols_contra             object
# entrou                  object
# saiu                    object
# amarelo                 object
# amarelo_duplo           object
# vermelho                object
# Gols_de_penalti         object
# minutos_por_gol         object
# minutos                 object
# dtype: object

# %%
df_final.head(6).T
# Out:
#                                                                      0  \
# ID                                                              177547
# Perfil                                  /matheus/profil/spieler/177547
# Nome                                                           Matheus
# Posição                                                     Goalkeeper
# Idade                                                               22
# Valor de Mercado                                                     0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /america-futebol-clube-mg-/startseite/verein/2...
# Clube Antigo                                                América-MG
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo         /sc-braga/startseite/verein/1075/saison_id/2014
# Clube Novo                                                    SC Braga
# URL Liga Nova        /liga-nos/transfers/wettbewerb/PO1/saison_id/2014
# Liga Nova                                                     Liga NOS
# Valor Transferência                                            2400000
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Mar 29, 1992 (32)
# local_nasc                                              Belo Horizonte
# cidadania                                          2, Brazil, Portugal
# altura                                                             1.9
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            26
# jogou                                                               26
# ppm                                                               1.54
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 -
# amarelo                                                              -
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                     31
# minutos_por_gol                                                      8
# minutos                                                           2340
#
#                                                                      1  \
# ID                                                               75071
# Perfil                                    /aranha/profil/spieler/75071
# Nome                                                            Aranha
# Posição                                                     Goalkeeper
# Idade                                                               34
# Valor de Mercado                                               2000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo       /fc-santos/startseite/verein/221/saison_id/2014
# Clube Antigo                                                    Santos
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /se-palmeiras-sao-paulo/startseite/verein/1023...
# Clube Novo                                                   Palmeiras
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                                  0
# Ano da Tranferência                                               2014
# pe                                                                left
# data_nasc                                            Nov 17, 1980 (44)
# local_nasc                                                Pouso Alegre
# cidadania                                                    1, Brazil
# altura                                                            1.93
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            58
# jogou                                                               58
# ppm                                                               1.71
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 -
# amarelo                                                              5
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                     53
# minutos_por_gol                                                     23
# minutos                                                           5220
#
#                                                                      2  \
# ID                                                               75071
# Perfil                                    /aranha/profil/spieler/75071
# Nome                                                            Aranha
# Posição                                                     Goalkeeper
# Idade                                                               35
# Valor de Mercado                                                450000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /joinville-ec-sc-/startseite/verein/3330/saiso...
# Clube Antigo                                              Joinville-SC
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo       /aa-ponte-preta/startseite/verein/1134/saison_...
# Clube Novo                                                 Ponte Preta
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                              55000
# Ano da Tranferência                                               2016
# pe                                                                left
# data_nasc                                            Nov 17, 1980 (44)
# local_nasc                                                Pouso Alegre
# cidadania                                                    1, Brazil
# altura                                                            1.93
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2015
# escalado                                                            26
# jogou                                                               26
# ppm                                                               1.31
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 1
# amarelo                                                              2
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                     30
# minutos_por_gol                                                      8
# minutos                                                           2340
#
#                                                                      3  \
# ID                                                               75071
# Perfil                                    /aranha/profil/spieler/75071
# Nome                                                            Aranha
# Posição                                                     Goalkeeper
# Idade                                                               37
# Valor de Mercado                                                600000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /aa-ponte-preta/startseite/verein/1134/saison_...
# Clube Antigo                                               Ponte Preta
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo       /avai-fc-sc-/startseite/verein/2035/saison_id/...
# Clube Novo                                                     Avaí FC
# URL Liga Nova        /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Nova                                                      Série B
# Valor Transferência                                                  0
# Ano da Tranferência                                               2017
# pe                                                                left
# data_nasc                                            Nov 17, 1980 (44)
# local_nasc                                                Pouso Alegre
# cidadania                                                    1, Brazil
# altura                                                            1.93
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2016
# escalado                                                            62
# jogou                                                               62
# ppm                                                               1.29
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 -
# amarelo                                                              3
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                     79
# minutos_por_gol                                                     21
# minutos                                                           5580
#
#                                                                      4  \
# ID                                                               22412
# Perfil                               /julio-cesar/profil/spieler/22412
# Nome                                                       Júlio César
# Posição                                                     Goalkeeper
# Idade                                                               34
# Valor de Mercado                                               1500000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /queens-park-rangers/startseite/verein/1039/sa...
# Clube Antigo                                                       QPR
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /benfica-lissabon/startseite/verein/294/saison...
# Clube Novo                                                     Benfica
# URL Liga Nova        /liga-nos/transfers/wettbewerb/PO1/saison_id/2014
# Liga Nova                                                     Liga NOS
# Valor Transferência                                                  0
# Ano da Tranferência                                               2014
# pe                                                                left
# data_nasc                                             Sep 3, 1979 (45)
# local_nasc                                             Duque de Caxias
# cidadania                                                    1, Brazil
# altura                                                            1.86
# convocacoes                                                         87
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                             9
# jogou                                                                8
# ppm                                                               1.13
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 -
# amarelo                                                              1
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                     13
# minutos_por_gol                                                      2
# minutos                                                         720000
#
#                                                                      5
# ID                                                               19059
# Perfil                            /heurelho-gomes/profil/spieler/19059
# Nome                                                    Heurelho Gomes
# Posição                                                     Goalkeeper
# Idade                                                               33
# Valor de Mercado                                               1000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /tottenham-hotspur/startseite/verein/148/saiso...
# Clube Antigo                                                 Tottenham
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /fc-watford/startseite/verein/1010/saison_id/2014
# Clube Novo                                                     Watford
# URL Liga Nova        /championship/transfers/wettbewerb/GB2/saison_...
# Liga Nova                                                 Championship
# Valor Transferência                                                  0
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Feb 15, 1981 (43)
# local_nasc                                               João Pinheiro
# cidadania                                                    1, Brazil
# altura                                                            1.91
# convocacoes                                                         11
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                             2
# jogou                                                                -
# ppm                                                                NaN
# gols_para                                                            -
# assistencias                                                         0
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 -
# amarelo                                                              -
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                      -
# minutos                                                              -

# %%
# Substituir '-' por NaN
cols_to_clean = [
    "jogou", "gols_para", "assistencias", "gols_contra", 
    "entrou", "saiu", "amarelo", "amarelo_duplo", 
    "vermelho", "Gols_de_penalti", "minutos_por_gol", "minutos"
]

df_final[cols_to_clean] = df_final[cols_to_clean].replace('-', pd.NA)
# Convertemos para inteiros, substituindo NaN por 0 (se necessário)
#df_final[cols_to_clean] = df_final[cols_to_clean].fillna(0).astype("int64")

# %%
df_final.shape
# Out:
# (264, 39)

# %%
num_duplicatas = df_final.duplicated().sum()
print(f"Número de linhas duplicadas: {num_duplicatas}")
# Out:
# Número de linhas duplicadas: 0

# %%
df_final.head(6).T
# Out:
#                                                                      0  \
# ID                                                              177547
# Perfil                                  /matheus/profil/spieler/177547
# Nome                                                           Matheus
# Posição                                                     Goalkeeper
# Idade                                                               22
# Valor de Mercado                                                     0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /america-futebol-clube-mg-/startseite/verein/2...
# Clube Antigo                                                América-MG
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo         /sc-braga/startseite/verein/1075/saison_id/2014
# Clube Novo                                                    SC Braga
# URL Liga Nova        /liga-nos/transfers/wettbewerb/PO1/saison_id/2014
# Liga Nova                                                     Liga NOS
# Valor Transferência                                            2400000
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Mar 29, 1992 (32)
# local_nasc                                              Belo Horizonte
# cidadania                                          2, Brazil, Portugal
# altura                                                             1.9
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            26
# jogou                                                               26
# ppm                                                               1.54
# gols_para                                                         <NA>
# assistencias                                                         0
# gols_contra                                                       <NA>
# entrou                                                            <NA>
# saiu                                                              <NA>
# amarelo                                                           <NA>
# amarelo_duplo                                                     <NA>
# vermelho                                                          <NA>
# Gols_de_penalti                                                     31
# minutos_por_gol                                                      8
# minutos                                                           2340
#
#                                                                      1  \
# ID                                                               75071
# Perfil                                    /aranha/profil/spieler/75071
# Nome                                                            Aranha
# Posição                                                     Goalkeeper
# Idade                                                               34
# Valor de Mercado                                               2000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo       /fc-santos/startseite/verein/221/saison_id/2014
# Clube Antigo                                                    Santos
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /se-palmeiras-sao-paulo/startseite/verein/1023...
# Clube Novo                                                   Palmeiras
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                                  0
# Ano da Tranferência                                               2014
# pe                                                                left
# data_nasc                                            Nov 17, 1980 (44)
# local_nasc                                                Pouso Alegre
# cidadania                                                    1, Brazil
# altura                                                            1.93
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            58
# jogou                                                               58
# ppm                                                               1.71
# gols_para                                                         <NA>
# assistencias                                                         0
# gols_contra                                                       <NA>
# entrou                                                            <NA>
# saiu                                                              <NA>
# amarelo                                                              5
# amarelo_duplo                                                     <NA>
# vermelho                                                          <NA>
# Gols_de_penalti                                                     53
# minutos_por_gol                                                     23
# minutos                                                           5220
#
#                                                                      2  \
# ID                                                               75071
# Perfil                                    /aranha/profil/spieler/75071
# Nome                                                            Aranha
# Posição                                                     Goalkeeper
# Idade                                                               35
# Valor de Mercado                                                450000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /joinville-ec-sc-/startseite/verein/3330/saiso...
# Clube Antigo                                              Joinville-SC
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo       /aa-ponte-preta/startseite/verein/1134/saison_...
# Clube Novo                                                 Ponte Preta
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                              55000
# Ano da Tranferência                                               2016
# pe                                                                left
# data_nasc                                            Nov 17, 1980 (44)
# local_nasc                                                Pouso Alegre
# cidadania                                                    1, Brazil
# altura                                                            1.93
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2015
# escalado                                                            26
# jogou                                                               26
# ppm                                                               1.31
# gols_para                                                         <NA>
# assistencias                                                         0
# gols_contra                                                       <NA>
# entrou                                                            <NA>
# saiu                                                                 1
# amarelo                                                              2
# amarelo_duplo                                                     <NA>
# vermelho                                                          <NA>
# Gols_de_penalti                                                     30
# minutos_por_gol                                                      8
# minutos                                                           2340
#
#                                                                      3  \
# ID                                                               75071
# Perfil                                    /aranha/profil/spieler/75071
# Nome                                                            Aranha
# Posição                                                     Goalkeeper
# Idade                                                               37
# Valor de Mercado                                                600000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /aa-ponte-preta/startseite/verein/1134/saison_...
# Clube Antigo                                               Ponte Preta
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo       /avai-fc-sc-/startseite/verein/2035/saison_id/...
# Clube Novo                                                     Avaí FC
# URL Liga Nova        /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Nova                                                      Série B
# Valor Transferência                                                  0
# Ano da Tranferência                                               2017
# pe                                                                left
# data_nasc                                            Nov 17, 1980 (44)
# local_nasc                                                Pouso Alegre
# cidadania                                                    1, Brazil
# altura                                                            1.93
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2016
# escalado                                                            62
# jogou                                                               62
# ppm                                                               1.29
# gols_para                                                         <NA>
# assistencias                                                         0
# gols_contra                                                       <NA>
# entrou                                                            <NA>
# saiu                                                              <NA>
# amarelo                                                              3
# amarelo_duplo                                                     <NA>
# vermelho                                                          <NA>
# Gols_de_penalti                                                     79
# minutos_por_gol                                                     21
# minutos                                                           5580
#
#                                                                      4  \
# ID                                                               22412
# Perfil                               /julio-cesar/profil/spieler/22412
# Nome                                                       Júlio César
# Posição                                                     Goalkeeper
# Idade                                                               34
# Valor de Mercado                                               1500000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /queens-park-rangers/startseite/verein/1039/sa...
# Clube Antigo                                                       QPR
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /benfica-lissabon/startseite/verein/294/saison...
# Clube Novo                                                     Benfica
# URL Liga Nova        /liga-nos/transfers/wettbewerb/PO1/saison_id/2014
# Liga Nova                                                     Liga NOS
# Valor Transferência                                                  0
# Ano da Tranferência                                               2014
# pe                                                                left
# data_nasc                                             Sep 3, 1979 (45)
# local_nasc                                             Duque de Caxias
# cidadania                                                    1, Brazil
# altura                                                            1.86
# convocacoes                                                         87
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                             9
# jogou                                                                8
# ppm                                                               1.13
# gols_para                                                         <NA>
# assistencias                                                         0
# gols_contra                                                       <NA>
# entrou                                                            <NA>
# saiu                                                              <NA>
# amarelo                                                              1
# amarelo_duplo                                                     <NA>
# vermelho                                                          <NA>
# Gols_de_penalti                                                     13
# minutos_por_gol                                                      2
# minutos                                                         720000
#
#                                                                      5
# ID                                                               19059
# Perfil                            /heurelho-gomes/profil/spieler/19059
# Nome                                                    Heurelho Gomes
# Posição                                                     Goalkeeper
# Idade                                                               33
# Valor de Mercado                                               1000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /tottenham-hotspur/startseite/verein/148/saiso...
# Clube Antigo                                                 Tottenham
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /fc-watford/startseite/verein/1010/saison_id/2014
# Clube Novo                                                     Watford
# URL Liga Nova        /championship/transfers/wettbewerb/GB2/saison_...
# Liga Nova                                                 Championship
# Valor Transferência                                                  0
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Feb 15, 1981 (43)
# local_nasc                                               João Pinheiro
# cidadania                                                    1, Brazil
# altura                                                            1.91
# convocacoes                                                         11
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                             2
# jogou                                                             <NA>
# ppm                                                                NaN
# gols_para                                                         <NA>
# assistencias                                                         0
# gols_contra                                                       <NA>
# entrou                                                            <NA>
# saiu                                                              <NA>
# amarelo                                                           <NA>
# amarelo_duplo                                                     <NA>
# vermelho                                                          <NA>
# Gols_de_penalti                                                   <NA>
# minutos_por_gol                                                   <NA>
# minutos                                                           <NA>

# %%
df_final['minutos'] = df_final['minutos'].apply(lambda x: str(x)[:-3] if str(x).endswith('000') else x)

# %% [markdown]
# # Renomear Colunas

# %%
# Renomeando as colunas
df_final.rename(columns={
    'Gols_de_penalti': 'gols_sofridos',
    'minutos_por_gol': 'clean_sheets'
}, inplace=True)

# Verificando se a renomeação foi realizada com sucesso
print(df_final.columns)
# Out:
# Index(['ID', 'Perfil', 'Nome', 'Posição', 'Idade', 'Valor de Mercado',
#        'Nacionalidade', 'URL Clube Antigo', 'Clube Antigo', 'URL Liga Antiga',
#        'Liga Antiga', 'URL Clube Novo', 'Clube Novo', 'URL Liga Nova',
#        'Liga Nova', 'Valor Transferência', 'Ano da Tranferência', 'pe',
#        'data_nasc', 'local_nasc', 'cidadania', 'altura', 'convocacoes',
#        'gols_selecao', 'ano_stat', 'escalado', 'jogou', 'ppm', 'gols_para',
#        'assistencias', 'gols_contra', 'entrou', 'saiu', 'amarelo',
#        'amarelo_duplo', 'vermelho', 'gols_sofridos', 'clean_sheets',
#        'minutos'],
#       dtype='object')

# %% [markdown]
# # Salvo

# %%
df_final=df_final.drop_duplicates()
df_final.to_csv('04-GK.csv', index=True)

# %%
df_final.shape
# Out:
# (264, 39)

# %%
df_final.dtypes
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado         int64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência      int64
# Ano da Tranferência      int64
# pe                      object
# data_nasc               object
# local_nasc              object
# cidadania               object
# altura                 float64
# convocacoes              int64
# gols_selecao             int64
# ano_stat                 int64
# escalado                 int64
# jogou                   object
# ppm                    float64
# gols_para               object
# assistencias             int64
# gols_contra             object
# entrou                  object
# saiu                    object
# amarelo                 object
# amarelo_duplo           object
# vermelho                object
# gols_sofridos           object
# clean_sheets            object
# minutos                 object
# dtype: object
