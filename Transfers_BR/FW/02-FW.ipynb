# %% [markdown]
# ## Bibliotecas e carregamento de arquivo

# %%
import pandas as pd
import numpy as np
import re
import requests
import os
from bs4 import BeautifulSoup
import unidecode

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import FuncFormatter

df = pd.read_csv('01-FW.csv')
# Out:
# C:\Users\User\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.26.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# ## Formatação/Limpeza

# %%
columns = [
        'ID', 'Perfil', 'Nome', 'Nome Completo', 'URL Nome Completo', 'Repetido Nome', 'Posição',
        'Idade', 'Valor de Mercado', 'Nacionalidade', 'URL Clube Antigo', 'Vazio 1', 'URL Clube Antigo Repetido',
        'Vazio 2', 'URL Clube Antigo Repetido 2', 'Clube Antigo', 'URL Liga Antiga', 'Liga Antiga',
        'URL Clube Novo', 'Vazio 3', 'URL Clube Novo Repetido', 'Vazio 4', 'URL Clube Novo Repetido 2',
        'Clube Novo', 'URL Liga Nova', 'Liga Nova', 'Valor Transferência'
    ]
df.columns = columns

# Função para mover os valores para a direita se não houver '/' na coluna 'URL da linha antiga'
def shift_row_if_no_slash(row, col_name):
    # Verifica se não contém '/' na coluna especificada
    if '/' not in str(row[col_name]):
        # Move valores a partir da coluna especificada uma posição à direita
        row.loc[col_name:] = row.loc[col_name:].shift(1)
    return row

df.drop('Vazio 1', axis=1, inplace=True)
df.drop('Vazio 2', axis=1, inplace=True)
df.drop('URL Clube Antigo Repetido', axis=1, inplace=True)
df.drop('URL Clube Antigo Repetido 2', axis=1, inplace=True)

df = df.apply(lambda row: shift_row_if_no_slash(row, 'URL Liga Antiga'), axis=1)

df.drop('Vazio 3', axis=1, inplace=True)
df.drop('Vazio 4', axis=1, inplace=True)
df.drop('URL Clube Novo Repetido', axis=1, inplace=True)
df.drop('URL Clube Novo Repetido 2', axis=1, inplace=True)

df = df.apply(lambda row: shift_row_if_no_slash(row, 'URL Liga Nova'), axis=1)

df.drop('URL Nome Completo', axis=1, inplace=True)
df.drop('Nome Completo', axis=1, inplace=True)
df.drop('Repetido Nome', axis=1, inplace=True)


df['ID'] = df['Perfil'].str.extract(r'/(\d+)$')
df['ID'] = df['ID'].astype(int)

# Filtra as linhas que não contêm 'transfer' ou '?' na coluna 'Valor Transferencia'
df = df[~df['Valor Transferência'].str.contains(r'loan|draft|\?', case=False, na=False)]
df['Valor Transferência'] = df['Valor Transferência'].replace('free transfer', 0)
df['Valor de Mercado'] = df['Valor de Mercado'].replace('-',1)

print(df['Valor Transferência'].unique())
# Out:
# ['€15.00m' '€8.00m' '€7.50m' '€5.90m' '€5.50m' '€5.30m' 0 '€4.50m'
#  '€4.00m' '€1.80m' '€3.50m' '€3.30m' '€3.00m' '€2.50m' '€340k' '€135k'
#  '€50k' '€100k' '€2.65m' '€2.60m' '€2.40m' '€2.00m' '€1.00m' '€1.50m'
#  '€600k' '€400k' '€850k' '€320k' '€50.00m' '€41.00m' '€30.00m' '€14.00m'
#  '€11.00m' '€5.00m' '€7.00m' '€7.20m' '€3.40m' '€5.25m' '€1.90m' '€4.30m'
#  '€500k' '€200k' '€415k' '€374k' '€95k' '€170k' '€125k' '€64k' '€300'
#  '€4.20m' '€1.35m' '€3.90m' '€3.75m' '€3.60m' '€2.80m' '€2.38m' '€2.20m'
#  '€1.30m' '€1.20m' '€1.11m' '€970k' '€910k' '€750k' '€800k' '€402k'
#  '€941k' '€180k' '€700k' '€120k' '€56.00m' '€32.00m' '€29.50m' '€18.00m'
#  '€17.40m' '€6.00m' '€5.60m' '€4.40m' '€3.80m' '€3.70m' '€588k' '€443k'
#  '€8k' '€1.60m' '€2.99m' '€545k' '€1.05m' '€950k' '€830k' '€590k' '€530k'
#  '€330k' '€625k' '€222.00m' '€28.40m' '€12.40m' '€12.00m' '€10.50m'
#  '€9.00m' '€2.56m' '€2.90m' '€470k' '€30k' '€2.55m' '€390k' '€75k' '€600'
#  '€130k' '€1.70m' '€640k' '€265k' '€870k' '€745k' '€250k' '€650k' '€450k'
#  '€40.00m' '€45.00m' '€39.20m' '€38.00m' '€18.50m' '€9.50m' '€8.50m'
#  '€6.50m' '€5.80m' '€5.20m' '€447k' '€45k' '€220k' '€70k' '€150k' '€2.25m'
#  '€2.15m' '€1.25m' '€300k' '€1.37m' '€550k' '€440k' '€1.06m' '€840k'
#  '€900k' '€115k' '€815k' '€41.50m' '€25.00m' '€17.50m' '€21.00m' '€11.50m'
#  '€17.00m' '€7.10m' '€5.46m' '€3.45m' '0' '€2.70m' '€1.10m' '€15k'
#  '€20.00m' '€18.60m' '€15.75m' '€11.82m' '€5.40m' '€7.27m' '€12.05m'
#  '€364k' '€10k' '€110k' '€80k' '€2.07m' '€1.75m' '€1.65m' '€350k' '€475k'
#  '€35.00m' '€15.50m' '€15.40m' '€10.00m' '€9.91m' '€7.60m' '€441k'
#  '€4.70m' '€1.15m' '€2.85m' '€2.13m' '€1.64m' '€1.49m' '€1.32m' '€190k'
#  '€748k' '€90k' '€95.00m' '€58.00m' '€52.20m' '€15.30m' '€10.40m'
#  '€10.34m' '€245k' '€18k' '€20k' '€175k' '€5k' '€6.20m' '€2.30m' '€3.20m'
#  '€54k' '€2.35m' '€1.86m' '€3.28m' '€841k' '€375k' '€1.45m' '€4.26m'
#  '€394k' '€90.00m' '€60.00m' '€34.20m' '€22.00m' '€16.00m' '€9.10m'
#  '€9.30m' '€1.36m' '€1.18m' '€282k' '€87k' '€6.30m' '€4.10m' '€4.65m'
#  '€4.54m' '€1.85m' '€365k' '€285k' '€932k' '€465k' '€453k' '€1.09m'
#  '€1.03m' '€546k' '€457k' '€60k' '€47.50m' '€37.00m' '€33.00m' '€28.00m'
#  '€23.00m' '€13.50m' '€7.25m' '€318k' '€40k' '€1.40m' '€671k' '€488k'
#  '€238k' '€920k' '€785k' '€51k' '€34.00m']

# %%
# Função para converter os valores de string para numéricos
def convert_value(val):
    if isinstance(val, str):
        # Remove o símbolo '€'
        val = val.replace('€', '')
        # Converte valores com 'm' (milhões) para números
        if 'm' in val:
            return float(val.replace('m', '')) * 1000000
        # Converte valores com 'k' (milhares) para números
        elif 'k' in val:
            return float(val.replace('k', '')) * 1000
        # Se for só um número sem 'm' ou 'k', retorna o número como float
        else:
            return float(val)
    return val

# Aplica a função a toda a coluna 'Valor Transferência'

df['Valor Transferência'] = df['Valor Transferência'].apply(convert_value)
# Converte a coluna para tipo numérico, caso ainda tenha algum valor não numérico
df['Valor Transferência'] = pd.to_numeric(df['Valor Transferência'], errors='coerce')

df['Valor de Mercado'] = df['Valor de Mercado'].apply(convert_value)
df['Valor de Mercado'] = pd.to_numeric(df['Valor de Mercado'], errors='coerce')

# Exibe os valores únicos após a conversão
#print(df['Valor Transferência'].unique())

df['Ano da Tranferência'] = df['URL Clube Antigo'].str.extract(r'.*/(\d+)$')
df.to_csv('02-FW.csv', index=False)

# %% [markdown]
# ## Gráficos

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Agrupamento de dados
agrupado_temp = df.groupby('Ano da Tranferência').size()

# Configurar o estilo do gráfico
sns.set(style="whitegrid")

# Criar o gráfico de barras
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x=agrupado_temp.index, y=agrupado_temp.values, palette="viridis")

# Adicionar título e rótulos aos eixos
plt.title('Número de Transferências de Defensores por Temporada')
plt.xlabel('Temporada')
plt.ylabel('Número de Transferências')

# Rotacionar os rótulos do eixo x para melhor visualização
plt.xticks(rotation=45)

# Adicionar os valores em cima de cada barra
for p in barplot.patches:
    barplot.annotate(format(p.get_height(), '.0f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', 
                     xytext = (0, 9), 
                     textcoords = 'offset points')

# Mostrar o gráfico
plt.show()

# %%
# Filtrar jogadores com valor de mercado e valor de transferência maiores que zero
filtered_df = df[(df['Valor de Mercado'] > 0) & (df['Valor Transferência'] > 0)]

# Criar o vetor de índices para o eixo x
x = range(len(filtered_df))  # Índice para o eixo x

# Criar o gráfico de linha
plt.figure(figsize=(12, 6))
plt.plot(x, filtered_df['Valor de Mercado'], label='Valor de Mercado', marker='o', linestyle='-', color='blue')
plt.plot(x, filtered_df['Valor Transferência'], label='Valor Transferência', marker='o', linestyle='-', color='orange')

# Adicionando título e rótulos
plt.title('Comparação entre Valor de Mercado e Valor de Transferência')
plt.xlabel('Jogadores (Index)')
plt.ylabel('Valor (em Euros)')
plt.legend()
plt.grid(True)

# Exibir o gráfico
plt.show()

# %%
# Filtrar jogadores com valor de mercado e valor de transferência maiores que zero
filtered_df = df[(df['Valor de Mercado'] >5) & (df['Valor Transferência'] > 5)]

# Função para remover outliers
def remove_outliers(data):
    Q1 = data.quantile(0.25)
    Q3 = data.quantile(0.75)
    IQR = Q3 - Q1
    return data[(data >= (Q1 - 1.5 * IQR)) & (data <= (Q3 + 1.5 * IQR))]

# Remover outliers
filtered_df['Valor de Mercado'] = remove_outliers(filtered_df['Valor de Mercado'])
filtered_df['Valor Transferência'] = remove_outliers(filtered_df['Valor Transferência'])

# Criar uma figura
plt.figure(figsize=(4, 6))

# Configurar o estilo do seaborn
sns.set(style="whitegrid")

# Criar box plots
sns.boxplot(data=filtered_df[['Valor de Mercado', 'Valor Transferência']])

# Ajustar limites do eixo y
plt.ylim(0, filtered_df[['Valor de Mercado', 'Valor Transferência']].max().max() * 1.1)

# Adicionando título e rótulos
plt.title('Box Plot de Valor de Mercado e Valor de Transferência (sem outliers)')
plt.ylabel('Valor (em Milhões de Euros)')
plt.xticks([0, 1], ['Valor de Mercado', 'Valor de Transferência'])

# Função para formatar o eixo y em milhões
def millions(x, pos):
    return f'{int(x / 1_000_000)}M'

# Aplicar a formatação ao eixo y
formatter = FuncFormatter(millions)
plt.gca().yaxis.set_major_formatter(formatter)

# Exibir o gráfico
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_9080\1447094067.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Valor de Mercado'] = remove_outliers(filtered_df['Valor de Mercado'])
# C:\Users\User\AppData\Local\Temp\ipykernel_9080\1447094067.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_df['Valor Transferência'] = remove_outliers(filtered_df['Valor Transferência'])

# %% [markdown]
# ## Transfers

# %%
url_site = "https://www.transfermarkt.us/" ## https://www.transfermarkt.us/Jan-Oblak/leistungsdatendetails/spieler/121483 ## https://www.transfermarkt.us/Jan-Oblak/leistungsdatendetails/spieler/121483/saison/2014/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1 ## https://www.transfermarkt.us/Jan-Oblak/transfers/spieler/121483/transfer_id/1087965

# Get headers from https://www.whatismybrowser.com/detect/what-http-headers-is-my-browser-sending
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/126.0.0.0 Safari/537.36',
}

# %%
# Definir a função
def get_home(nome_hifen, id):
    url_principal = url_site + str(nome_hifen) + "/leistungsdatendetails/spieler/" + str(id)
    response = requests.get(url_principal, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    print(url_principal)
   
    # Inicializar valores padrão
    date_of_birth = "N/A"
    place_of_birth = "N/A"
    citizenship = "N/A"
    height = "N/A"
    caps = "0"
    goals = "0"

    # Extrai a data de nascimento/idade
    birth_date_elem = soup.find('span', itemprop='birthDate')
    if birth_date_elem:
        date_of_birth = birth_date_elem.get_text(strip=True)

    # Extrai o local de nascimento
    birth_place_elem = soup.find('span', itemprop='birthPlace')
    if birth_place_elem:
        place_of_birth = birth_place_elem.get_text(strip=True)

    # Extrai a cidadania
    citizenship_elem = soup.find('span', itemprop='nationality')
    if citizenship_elem:
        citizenship = citizenship_elem.get_text(strip=True)

    # Extrai a altura
    height_elem = soup.find('span', itemprop='height')
    if height_elem:
        height = height_elem.get_text(strip=True)

    # Extrai Caps/Goals
    highlight_elems = soup.find_all('a', class_='data-header__content--highlight')
    if len(highlight_elems) > 1:
        caps = highlight_elems[0].get_text(strip=True)
        goals = highlight_elems[1].get_text(strip=True)
        
    #####    PE_FAVORITO
    url_profile = url_site + str(nome_hifen) + "/profil/spieler/" + str(id)
    print(url_profile)
    response = requests.get(url_profile, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")

    # Encontra o elemento que contém a informação sobre o pé
    foot_element = soup.find('span', class_='info-table__content info-table__content--regular', text='Foot:')

    if foot_element:
        # O próximo irmão (o conteúdo que está em <span class="info-table__content info-table__content--bold">)
        foot_value = foot_element.find_next_sibling('span', class_='info-table__content info-table__content--bold').text
        print(f'Foot: {foot_value}')
    else:
        foot_value = "N/A"
        print('NA')
    #####    #####    #####    #####    #####    #####    #####    

    # Dados extraídos em uma lista
    data = [
        id,
        nome_hifen,
        foot_value,
        date_of_birth,
        place_of_birth,
        citizenship,
        height,
        caps,
        goals
        ]
    return data

# %%
def get_stats(nome_hifen, id, ano):
    ano = int(ano) - 1

    url_detalhada = url_site + str(nome_hifen) + "/leistungsdatendetails/spieler/" + str(id) + "/saison/20" + str(ano) + "/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1"
    response = requests.get(url_detalhada, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    data = []
    print(url_detalhada)
    
    # Encontrar a tabela
    table = soup.find('table', class_='items')

                
    if table:
        # Extrair todas as linhas da tabela
        rows = table.find_all('tr')

        # Inicializar variáveis
        escalado = jogou = ppm = gols_para = assistencias = gols_contra = entrou = saiu = amarelo = amarelo_duplo = vermelho = gols_de_penalti = minutos_por_gol = minutos = "0"

        # Identificar a última linha que contém o texto "Total"
        for row in rows:
            if 'Total' in row.text:
                cols = row.find_all('td')
                if len(cols) > 1:  # Verifique se a linha não está vazia
                    escalado = cols[3].get_text(strip=True)
                    jogou = cols[4].get_text(strip=True)
                    ppm = cols[5].get_text(strip=True)
                    gols_para = cols[6].get_text(strip=True)
                    assistencias = cols[7].get_text(strip=True)
                    gols_contra = cols[8].get_text(strip=True)
                    entrou = cols[9].get_text(strip=True)
                    saiu = cols[10].get_text(strip=True)
                    amarelo = cols[11].get_text(strip=True)
                    amarelo_duplo = cols[12].get_text(strip=True)
                    vermelho = cols[13].get_text(strip=True)
                    gols_de_penalti = cols[14].get_text(strip=True)
                    minutos_por_gol = cols[15].get_text(strip=True)
                    minutos = cols[16].get_text(strip=True)
    else:
        # Definir todas as variáveis como "0" se a tabela não for encontrada
        escalado = jogou = ppm = gols_para = assistencias = gols_contra = entrou = saiu = amarelo = amarelo_duplo = vermelho = gols_de_penalti = minutos_por_gol = minutos = "0"
                
    # Dados extraídos em uma lista
    data = [
        id,
        ano,
        escalado,
        jogou,
        ppm, 
        gols_para,
        assistencias,
        gols_contra,
        entrou,
        saiu,
        amarelo,
        amarelo_duplo,
        vermelho,
        gols_de_penalti,
        minutos_por_gol,
        minutos
    ]
    return data

# %%
def get_transfer(nome_hifen, id, tid):
    url_transferencia = url_site + str(nome_hifen) + "/transfers/spieler/" + str(id) + "/transfer_id/" + str(tid)
    response = requests.get(url_transferencia, headers=headers)
    soup = BeautifulSoup(response.content, "html.parser")
    print(url_transferencia)
    
    def get_text_or_empty(element):
        return element.get_text(strip=True) if element else ""

    # Extrair dados relevantes
    transfer_details_div = soup.find("div", class_="box", id=tid)

    # Transfer date and season
    transfer_date_season = get_text_or_empty(transfer_details_div.find("tr", class_="table-highlight").find("td"))
    transfer_date_season = transfer_date_season.replace("Transfer dateSeason", "").strip()
    season, date = transfer_date_season.split(" -")   

    #Ex-clube  +  #Liga do ex-clube
    ex_club = get_text_or_empty(transfer_details_div.find("td", class_="zentriert hauptlink no-border-rechts"))
    ex_club_league = get_text_or_empty(transfer_details_div.find_all("tr")[2].find("td"))
    
    # Novo clube +  # Liga do novo clube
    new_club = get_text_or_empty(transfer_details_div.find("td", class_="zentriert hauptlink no-border-links"))
    new_club_league = get_text_or_empty(transfer_details_div.find_all("tr")[2].find_all("td")[2])
      
    # Encontra todos os <td> com a classe 'zentriert' e colspan '3'
    td_elements = transfer_details_div.find_all('td', class_='zentriert', colspan='3')

    # Percorre os elementos encontrados para verificar o texto interno - Market value at time of transfer
    market_value = None
    for td in td_elements:
        if 'Market value at time of transfer' in td.get_text():
            # Extrai o valor em euro do <td>
            text = td.get_text(strip=True)
            market_value = text.split('€')[-1].strip()
            break

    # Percorre os elementos encontrados para verificar o texto interno - Age at time of transfer
    idade_transfer = None
    for td in td_elements:
        if 'Age at time of transfer' in td.get_text():
            # Extrai a idade na transferencia <td>
            idade_transfer = td.get_text(strip=True)
            idade_transfer = idade_transfer.replace("Age at time of transfer", "").strip()
            break
    
    # Percorre os elementos encontrados para verificar o texto interno - Remaining contract duration at
    contrato_rest = None
    for td in td_elements:
        if 'Remaining contract duration at' in td.get_text():
            # Extrai a idade na transferencia <td>
            contrato_rest = td.get_text(strip=True)
            contrato_rest = contrato_rest.replace("Remaining contract duration at", "").strip()
            contrato_rest = contrato_rest.replace(str(ex_club), "").strip()
            contrato_rest = contrato_rest.split('(')[0].strip()
            break
    
    # Taxa de transferência
    transfer_fee = get_text_or_empty(transfer_details_div.find_all("tr")[-1].find("p", class_="hauptfact"))

    # Dados extraídos em um dicionário
    transfer_data = [
        id,
        tid,
        season,
        date,
        ex_club, 
        ex_club_league,
        new_club,
        new_club_league,
        market_value,
        idade_transfer,
        contrato_rest,
        transfer_fee
    ]
    return transfer_data

# %%
from datetime import datetime
# Obtém a hora atual
hora_atual = datetime.now()
hora_formatada = hora_atual.strftime("%H:%M:%S")
print("Hora Inicial:", hora_formatada)

# Definir os nomes das colunas
home_columns = ["ID", "nome_hifen", "pe", "data_nasc", "local_nasc", "cidadania", "altura", "convocacoes", "gols_selecao"]
stats_columns = ["ID", "ano_stat", "escalado", "jogou", "ppm", "gols_para", "assistencias", "gols_contra", "entrou", "saiu", "amarelo", "amarelo_duplo", "vermelho", "Gols_de_penalti", "minutos_por_gol", "minutos"]
transfer_columns = ["ID","tid", "Temporada", "Data", "Ex-clube", "Liga do ex-clube", "Novo_clube", "L_novo_clube", "VdM_epoca", "Idade_transfer", "Duração restante do contrato", "Taxa de transferência"]

df_home = pd.DataFrame(columns=home_columns)
df_stats = pd.DataFrame(columns=stats_columns)
df_transfer = pd.DataFrame(columns=transfer_columns)
print("AGORA VEM O LOOP")

# Loop através de cada linha do DataFrame Id_Temp
for index, row in Nome_Id_Temp.iterrows():
    nome_val = row['Nome'].strip().replace(' ', '-')
    nome_val = nome_val.replace('\'', '')
    nome_val = nome_val.replace('.', '')
    nome_val = unidecode.unidecode(nome_val)
    id_val = row['ID']
    tid_val = row['T_ID']
    ano = row['Temp'].split('/')[0]  # Pegar o ano antes da barra

    
    print(f'\n Dados de {nome_val}')
    lista_home=get_home(nome_val, id_val)
    #print(f'{lista_home}')
    
    lista_stats=get_stats(nome_val, id_val, ano)
    #print(f'{lista_stats}')

    lista_transfer = get_transfer(nome_val, id_val, tid_val)
    #print(f'{lista_transfer}')
    
    # New list for append into df
    df_home.loc[len(df_home)] = lista_home
    df_stats.loc[len(df_stats)] = lista_stats
    df_transfer.loc[len(df_transfer)] = lista_transfer

df_home=df_home.drop_duplicates()
df_stats=df_stats.drop_duplicates()
df_transfer=df_transfer.drop_duplicates()

df_home.to_csv('dt_home_4.csv', index=True)
df_stats.to_csv('dt_stats_4.csv', index=True)
df_transfer.to_csv('dt_transfer_4.csv', index=True)

    
# Realizar o merge dos DataFrames
#merged_df = df_home.merge(df_stats, on='ID').merge(df_transfer, on='ID')

# DataFrame final
#merged_df.to_csv('dados_transferencias.csv', index=True)

# Obtém a hora atual
hora_atual = datetime.now()
hora_formatada = hora_atual.strftime("%H:%M:%S")
print("Hora Final:", hora_formatada)
# Out:
# Hora Inicial: 20:56:10
# AGORA VEM O LOOP
#
#  Dados de Michael-Olise
# https://www.transfermarkt.us/Michael-Olise/leistungsdatendetails/spieler/566723
# https://www.transfermarkt.us/Michael-Olise/profil/spieler/566723
# Foot: left
# https://www.transfermarkt.us/Michael-Olise/leistungsdatendetails/spieler/566723/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Michael-Olise/transfers/spieler/566723/transfer_id/5100331
#
#  Dados de Endrick
# https://www.transfermarkt.us/Endrick/leistungsdatendetails/spieler/971570
# https://www.transfermarkt.us/Endrick/profil/spieler/971570
# Foot: left
# https://www.transfermarkt.us/Endrick/leistungsdatendetails/spieler/971570/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Endrick/transfers/spieler/971570/transfer_id/4177921
#
#  Dados de Yankuba-Minteh
# https://www.transfermarkt.us/Yankuba-Minteh/leistungsdatendetails/spieler/1012534
# https://www.transfermarkt.us/Yankuba-Minteh/profil/spieler/1012534
# Foot: left
# https://www.transfermarkt.us/Yankuba-Minteh/leistungsdatendetails/spieler/1012534/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Yankuba-Minteh/transfers/spieler/1012534/transfer_id/5083812
#
#  Dados de Igor-Thiago
# https://www.transfermarkt.us/Igor-Thiago/leistungsdatendetails/spieler/739443
# https://www.transfermarkt.us/Igor-Thiago/profil/spieler/739443
# Foot: right
# https://www.transfermarkt.us/Igor-Thiago/leistungsdatendetails/spieler/739443/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Igor-Thiago/transfers/spieler/739443/transfer_id/4889199
#
#  Dados de Ernest-Nuamah
# https://www.transfermarkt.us/Ernest-Nuamah/leistungsdatendetails/spieler/955070
# https://www.transfermarkt.us/Ernest-Nuamah/profil/spieler/955070
# Foot: left
# https://www.transfermarkt.us/Ernest-Nuamah/leistungsdatendetails/spieler/955070/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ernest-Nuamah/transfers/spieler/955070/transfer_id/5100508
#
#  Dados de Omari-Hutchinson
# https://www.transfermarkt.us/Omari-Hutchinson/leistungsdatendetails/spieler/741238
# https://www.transfermarkt.us/Omari-Hutchinson/profil/spieler/741238
# Foot: left
# https://www.transfermarkt.us/Omari-Hutchinson/leistungsdatendetails/spieler/741238/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Omari-Hutchinson/transfers/spieler/741238/transfer_id/5083618
#
#  Dados de Luis-Sinisterra
# https://www.transfermarkt.us/Luis-Sinisterra/leistungsdatendetails/spieler/512385
# https://www.transfermarkt.us/Luis-Sinisterra/profil/spieler/512385
# Foot: right
# https://www.transfermarkt.us/Luis-Sinisterra/leistungsdatendetails/spieler/512385/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Luis-Sinisterra/transfers/spieler/512385/transfer_id/4880236
#
#  Dados de Luis-Guilherme
# https://www.transfermarkt.us/Luis-Guilherme/leistungsdatendetails/spieler/991800
# https://www.transfermarkt.us/Luis-Guilherme/profil/spieler/991800
# Foot: left
# https://www.transfermarkt.us/Luis-Guilherme/leistungsdatendetails/spieler/991800/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Luis-Guilherme/transfers/spieler/991800/transfer_id/5054073
#
#  Dados de Ibrahim-Osman
# https://www.transfermarkt.us/Ibrahim-Osman/leistungsdatendetails/spieler/1110406
# https://www.transfermarkt.us/Ibrahim-Osman/profil/spieler/1110406
# Foot: right
# https://www.transfermarkt.us/Ibrahim-Osman/leistungsdatendetails/spieler/1110406/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ibrahim-Osman/transfers/spieler/1110406/transfer_id/4882105
#
#  Dados de Vangelis-Pavlidis
# https://www.transfermarkt.us/Vangelis-Pavlidis/leistungsdatendetails/spieler/324503
# https://www.transfermarkt.us/Vangelis-Pavlidis/profil/spieler/324503
# Foot: both
# https://www.transfermarkt.us/Vangelis-Pavlidis/leistungsdatendetails/spieler/324503/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Vangelis-Pavlidis/transfers/spieler/324503/transfer_id/5084826
#
#  Dados de Iliman-Ndiaye
# https://www.transfermarkt.us/Iliman-Ndiaye/leistungsdatendetails/spieler/623570
# https://www.transfermarkt.us/Iliman-Ndiaye/profil/spieler/623570
# Foot: right
# https://www.transfermarkt.us/Iliman-Ndiaye/leistungsdatendetails/spieler/623570/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Iliman-Ndiaye/transfers/spieler/623570/transfer_id/5090494
#
#  Dados de Mike-Tresor
# https://www.transfermarkt.us/Mike-Tresor/leistungsdatendetails/spieler/381963
# https://www.transfermarkt.us/Mike-Tresor/profil/spieler/381963
# Foot: right
# https://www.transfermarkt.us/Mike-Tresor/leistungsdatendetails/spieler/381963/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mike-Tresor/transfers/spieler/381963/transfer_id/4710803
#
#  Dados de Issahaku-Fatawu
# https://www.transfermarkt.us/Issahaku-Fatawu/leistungsdatendetails/spieler/864121
# https://www.transfermarkt.us/Issahaku-Fatawu/profil/spieler/864121
# Foot: left
# https://www.transfermarkt.us/Issahaku-Fatawu/leistungsdatendetails/spieler/864121/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Issahaku-Fatawu/transfers/spieler/864121/transfer_id/4994995
#
#  Dados de Cameron-Archer
# https://www.transfermarkt.us/Cameron-Archer/leistungsdatendetails/spieler/533662
# https://www.transfermarkt.us/Cameron-Archer/profil/spieler/533662
# Foot: right
# https://www.transfermarkt.us/Cameron-Archer/leistungsdatendetails/spieler/533662/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Cameron-Archer/transfers/spieler/533662/transfer_id/5111302
#
#  Dados de Hugo-Ekitike
# https://www.transfermarkt.us/Hugo-Ekitike/leistungsdatendetails/spieler/709726
# https://www.transfermarkt.us/Hugo-Ekitike/profil/spieler/709726
# Foot: right
# https://www.transfermarkt.us/Hugo-Ekitike/leistungsdatendetails/spieler/709726/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Hugo-Ekitike/transfers/spieler/709726/transfer_id/4994282
#
#  Dados de Enes-Unal
# https://www.transfermarkt.us/Enes-Unal/leistungsdatendetails/spieler/251106
# https://www.transfermarkt.us/Enes-Unal/profil/spieler/251106
# Foot: right
# https://www.transfermarkt.us/Enes-Unal/leistungsdatendetails/spieler/251106/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Enes-Unal/transfers/spieler/251106/transfer_id/5031870
#
#  Dados de Vitinha
# https://www.transfermarkt.us/Vitinha/leistungsdatendetails/spieler/586853
# https://www.transfermarkt.us/Vitinha/profil/spieler/586853
# Foot: right
# https://www.transfermarkt.us/Vitinha/leistungsdatendetails/spieler/586853/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Vitinha/transfers/spieler/586853/transfer_id/5067978
#
#  Dados de Alvaro-Djalo
# https://www.transfermarkt.us/Alvaro-Djalo/leistungsdatendetails/spieler/671649
# https://www.transfermarkt.us/Alvaro-Djalo/profil/spieler/671649
# Foot: right
# https://www.transfermarkt.us/Alvaro-Djalo/leistungsdatendetails/spieler/671649/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Alvaro-Djalo/transfers/spieler/671649/transfer_id/4921671
#
#  Dados de Said-Benrahma
# https://www.transfermarkt.us/Said-Benrahma/leistungsdatendetails/spieler/290532
# https://www.transfermarkt.us/Said-Benrahma/profil/spieler/290532
# Foot: right
# https://www.transfermarkt.us/Said-Benrahma/leistungsdatendetails/spieler/290532/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Said-Benrahma/transfers/spieler/290532/transfer_id/5083022
#
#  Dados de Samuel-Iling-Junior
# https://www.transfermarkt.us/Samuel-Iling-Junior/leistungsdatendetails/spieler/581672
# https://www.transfermarkt.us/Samuel-Iling-Junior/profil/spieler/581672
# Foot: left
# https://www.transfermarkt.us/Samuel-Iling-Junior/leistungsdatendetails/spieler/581672/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Samuel-Iling-Junior/transfers/spieler/581672/transfer_id/5084355
#
#  Dados de Julian-Quinones
# https://www.transfermarkt.us/Julian-Quinones/leistungsdatendetails/spieler/416090
# https://www.transfermarkt.us/Julian-Quinones/profil/spieler/416090
# Foot: right
# https://www.transfermarkt.us/Julian-Quinones/leistungsdatendetails/spieler/416090/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Julian-Quinones/transfers/spieler/416090/transfer_id/5066835
#
#  Dados de Georges-Mikautadze
# https://www.transfermarkt.us/Georges-Mikautadze/leistungsdatendetails/spieler/729814
# https://www.transfermarkt.us/Georges-Mikautadze/profil/spieler/729814
# Foot: right
# https://www.transfermarkt.us/Georges-Mikautadze/leistungsdatendetails/spieler/729814/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Georges-Mikautadze/transfers/spieler/729814/transfer_id/5036720
#
#  Dados de Moise-Kean
# https://www.transfermarkt.us/Moise-Kean/leistungsdatendetails/spieler/364135
# https://www.transfermarkt.us/Moise-Kean/profil/spieler/364135
# Foot: right
# https://www.transfermarkt.us/Moise-Kean/leistungsdatendetails/spieler/364135/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Moise-Kean/transfers/spieler/364135/transfer_id/5104666
#
#  Dados de Bryan-Zaragoza
# https://www.transfermarkt.us/Bryan-Zaragoza/leistungsdatendetails/spieler/713644
# https://www.transfermarkt.us/Bryan-Zaragoza/profil/spieler/713644
# Foot: right
# https://www.transfermarkt.us/Bryan-Zaragoza/leistungsdatendetails/spieler/713644/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Bryan-Zaragoza/transfers/spieler/713644/transfer_id/4755830
#
#  Dados de Lewis-Dobbin
# https://www.transfermarkt.us/Lewis-Dobbin/leistungsdatendetails/spieler/627248
# https://www.transfermarkt.us/Lewis-Dobbin/profil/spieler/627248
# NA
# https://www.transfermarkt.us/Lewis-Dobbin/leistungsdatendetails/spieler/627248/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Lewis-Dobbin/transfers/spieler/627248/transfer_id/5070907
#
#  Dados de Francisco-Conceicao
# https://www.transfermarkt.us/Francisco-Conceicao/leistungsdatendetails/spieler/487474
# https://www.transfermarkt.us/Francisco-Conceicao/profil/spieler/487474
# Foot: left
# https://www.transfermarkt.us/Francisco-Conceicao/leistungsdatendetails/spieler/487474/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Francisco-Conceicao/transfers/spieler/487474/transfer_id/4989906
#
#  Dados de Rafa-Mujica
# https://www.transfermarkt.us/Rafa-Mujica/leistungsdatendetails/spieler/361504
# https://www.transfermarkt.us/Rafa-Mujica/profil/spieler/361504
# Foot: right
# https://www.transfermarkt.us/Rafa-Mujica/leistungsdatendetails/spieler/361504/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Rafa-Mujica/transfers/spieler/361504/transfer_id/5033684
#
#  Dados de Loum-Tchaouna
# https://www.transfermarkt.us/Loum-Tchaouna/leistungsdatendetails/spieler/607226
# https://www.transfermarkt.us/Loum-Tchaouna/profil/spieler/607226
# Foot: left
# https://www.transfermarkt.us/Loum-Tchaouna/leistungsdatendetails/spieler/607226/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Loum-Tchaouna/transfers/spieler/607226/transfer_id/5084424
#
#  Dados de Matthis-Abline
# https://www.transfermarkt.us/Matthis-Abline/leistungsdatendetails/spieler/659543
# https://www.transfermarkt.us/Matthis-Abline/profil/spieler/659543
# Foot: right
# https://www.transfermarkt.us/Matthis-Abline/leistungsdatendetails/spieler/659543/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Matthis-Abline/transfers/spieler/659543/transfer_id/5091598
#
#  Dados de Benjamin-Rollheiser
# https://www.transfermarkt.us/Benjamin-Rollheiser/leistungsdatendetails/spieler/491704
# https://www.transfermarkt.us/Benjamin-Rollheiser/profil/spieler/491704
# Foot: left
# https://www.transfermarkt.us/Benjamin-Rollheiser/leistungsdatendetails/spieler/491704/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Benjamin-Rollheiser/transfers/spieler/491704/transfer_id/4836589
#
#  Dados de Georgios-Giakoumakis
# https://www.transfermarkt.us/Georgios-Giakoumakis/leistungsdatendetails/spieler/234850
# https://www.transfermarkt.us/Georgios-Giakoumakis/profil/spieler/234850
# Foot: right
# https://www.transfermarkt.us/Georgios-Giakoumakis/leistungsdatendetails/spieler/234850/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Georgios-Giakoumakis/transfers/spieler/234850/transfer_id/5058345
#
#  Dados de Abel-Ruiz
# https://www.transfermarkt.us/Abel-Ruiz/leistungsdatendetails/spieler/340376
# https://www.transfermarkt.us/Abel-Ruiz/profil/spieler/340376
# Foot: right
# https://www.transfermarkt.us/Abel-Ruiz/leistungsdatendetails/spieler/340376/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Abel-Ruiz/transfers/spieler/340376/transfer_id/5077886
#
#  Dados de Ezequiel-Ponce
# https://www.transfermarkt.us/Ezequiel-Ponce/leistungsdatendetails/spieler/296783
# https://www.transfermarkt.us/Ezequiel-Ponce/profil/spieler/296783
# Foot: right
# https://www.transfermarkt.us/Ezequiel-Ponce/leistungsdatendetails/spieler/296783/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ezequiel-Ponce/transfers/spieler/296783/transfer_id/5061548
#
#  Dados de Tijjani-Noslin
# https://www.transfermarkt.us/Tijjani-Noslin/leistungsdatendetails/spieler/457736
# https://www.transfermarkt.us/Tijjani-Noslin/profil/spieler/457736
# Foot: right
# https://www.transfermarkt.us/Tijjani-Noslin/leistungsdatendetails/spieler/457736/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Tijjani-Noslin/transfers/spieler/457736/transfer_id/5083411
#
#  Dados de Lorenzo-Lucca
# https://www.transfermarkt.us/Lorenzo-Lucca/leistungsdatendetails/spieler/572265
# https://www.transfermarkt.us/Lorenzo-Lucca/profil/spieler/572265
# Foot: right
# https://www.transfermarkt.us/Lorenzo-Lucca/leistungsdatendetails/spieler/572265/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Lorenzo-Lucca/transfers/spieler/572265/transfer_id/5054626
#
#  Dados de Marko-Arnautovic
# https://www.transfermarkt.us/Marko-Arnautovic/leistungsdatendetails/spieler/41384
# https://www.transfermarkt.us/Marko-Arnautovic/profil/spieler/41384
# Foot: both
# https://www.transfermarkt.us/Marko-Arnautovic/leistungsdatendetails/spieler/41384/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Marko-Arnautovic/transfers/spieler/41384/transfer_id/4884993
#
#  Dados de Paulinho
# https://www.transfermarkt.us/Paulinho/leistungsdatendetails/spieler/211072
# https://www.transfermarkt.us/Paulinho/profil/spieler/211072
# Foot: left
# https://www.transfermarkt.us/Paulinho/leistungsdatendetails/spieler/211072/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Paulinho/transfers/spieler/211072/transfer_id/5077025
#
#  Dados de Ahmed-Al-Ghamdi
# https://www.transfermarkt.us/Ahmed-Al-Ghamdi/leistungsdatendetails/spieler/671043
# https://www.transfermarkt.us/Ahmed-Al-Ghamdi/profil/spieler/671043
# NA
# https://www.transfermarkt.us/Ahmed-Al-Ghamdi/leistungsdatendetails/spieler/671043/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ahmed-Al-Ghamdi/transfers/spieler/671043/transfer_id/5041117
#
#  Dados de Kaio-Jorge
# https://www.transfermarkt.us/Kaio-Jorge/leistungsdatendetails/spieler/620477
# https://www.transfermarkt.us/Kaio-Jorge/profil/spieler/620477
# Foot: right
# https://www.transfermarkt.us/Kaio-Jorge/leistungsdatendetails/spieler/620477/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Kaio-Jorge/transfers/spieler/620477/transfer_id/5050761
#
#  Dados de Osman-Bukari
# https://www.transfermarkt.us/Osman-Bukari/leistungsdatendetails/spieler/548650
# https://www.transfermarkt.us/Osman-Bukari/profil/spieler/548650
# Foot: both
# https://www.transfermarkt.us/Osman-Bukari/leistungsdatendetails/spieler/548650/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Osman-Bukari/transfers/spieler/548650/transfer_id/5033906
#
#  Dados de Tim-Kleindienst
# https://www.transfermarkt.us/Tim-Kleindienst/leistungsdatendetails/spieler/193033
# https://www.transfermarkt.us/Tim-Kleindienst/profil/spieler/193033
# Foot: both
# https://www.transfermarkt.us/Tim-Kleindienst/leistungsdatendetails/spieler/193033/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Tim-Kleindienst/transfers/spieler/193033/transfer_id/5067563
#
#  Dados de Christos-Tzolis
# https://www.transfermarkt.us/Christos-Tzolis/leistungsdatendetails/spieler/451677
# https://www.transfermarkt.us/Christos-Tzolis/profil/spieler/451677
# Foot: right
# https://www.transfermarkt.us/Christos-Tzolis/leistungsdatendetails/spieler/451677/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Christos-Tzolis/transfers/spieler/451677/transfer_id/5094083
#
#  Dados de Maksim-Glushenkov
# https://www.transfermarkt.us/Maksim-Glushenkov/leistungsdatendetails/spieler/448981
# https://www.transfermarkt.us/Maksim-Glushenkov/profil/spieler/448981
# Foot: left
# https://www.transfermarkt.us/Maksim-Glushenkov/leistungsdatendetails/spieler/448981/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Maksim-Glushenkov/transfers/spieler/448981/transfer_id/5066386
#
#  Dados de Marc-Guiu
# https://www.transfermarkt.us/Marc-Guiu/leistungsdatendetails/spieler/938158
# https://www.transfermarkt.us/Marc-Guiu/profil/spieler/938158
# Foot: right
# https://www.transfermarkt.us/Marc-Guiu/leistungsdatendetails/spieler/938158/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Marc-Guiu/transfers/spieler/938158/transfer_id/5085430
#
#  Dados de Mama-Balde
# https://www.transfermarkt.us/Mama-Balde/leistungsdatendetails/spieler/325223
# https://www.transfermarkt.us/Mama-Balde/profil/spieler/325223
# Foot: right
# https://www.transfermarkt.us/Mama-Balde/leistungsdatendetails/spieler/325223/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mama-Balde/transfers/spieler/325223/transfer_id/5087500
#
#  Dados de Zuriko-Davitashvili
# https://www.transfermarkt.us/Zuriko-Davitashvili/leistungsdatendetails/spieler/427572
# https://www.transfermarkt.us/Zuriko-Davitashvili/profil/spieler/427572
# Foot: right
# https://www.transfermarkt.us/Zuriko-Davitashvili/leistungsdatendetails/spieler/427572/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Zuriko-Davitashvili/transfers/spieler/427572/transfer_id/5111614
#
#  Dados de Duvan-Zapata
# https://www.transfermarkt.us/Duvan-Zapata/leistungsdatendetails/spieler/73794
# https://www.transfermarkt.us/Duvan-Zapata/profil/spieler/73794
# Foot: right
# https://www.transfermarkt.us/Duvan-Zapata/leistungsdatendetails/spieler/73794/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Duvan-Zapata/transfers/spieler/73794/transfer_id/4971417
#
#  Dados de Florinel-Coman
# https://www.transfermarkt.us/Florinel-Coman/leistungsdatendetails/spieler/340982
# https://www.transfermarkt.us/Florinel-Coman/profil/spieler/340982
# Foot: right
# https://www.transfermarkt.us/Florinel-Coman/leistungsdatendetails/spieler/340982/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Florinel-Coman/transfers/spieler/340982/transfer_id/5103377
#
#  Dados de Oscar-Perea
# https://www.transfermarkt.us/Oscar-Perea/leistungsdatendetails/spieler/1015624
# https://www.transfermarkt.us/Oscar-Perea/profil/spieler/1015624
# Foot: right
# https://www.transfermarkt.us/Oscar-Perea/leistungsdatendetails/spieler/1015624/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Oscar-Perea/transfers/spieler/1015624/transfer_id/5089354
#
#  Dados de Eren-Dinkci
# https://www.transfermarkt.us/Eren-Dinkci/leistungsdatendetails/spieler/645774
# https://www.transfermarkt.us/Eren-Dinkci/profil/spieler/645774
# Foot: right
# https://www.transfermarkt.us/Eren-Dinkci/leistungsdatendetails/spieler/645774/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Eren-Dinkci/transfers/spieler/645774/transfer_id/4966179
#
#  Dados de Jamie-Leweling
# https://www.transfermarkt.us/Jamie-Leweling/leistungsdatendetails/spieler/518505
# https://www.transfermarkt.us/Jamie-Leweling/profil/spieler/518505
# Foot: both
# https://www.transfermarkt.us/Jamie-Leweling/leistungsdatendetails/spieler/518505/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jamie-Leweling/transfers/spieler/518505/transfer_id/5019803
#
#  Dados de Gabriel-Strefezza
# https://www.transfermarkt.us/Gabriel-Strefezza/leistungsdatendetails/spieler/457673
# https://www.transfermarkt.us/Gabriel-Strefezza/profil/spieler/457673
# Foot: right
# https://www.transfermarkt.us/Gabriel-Strefezza/leistungsdatendetails/spieler/457673/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Gabriel-Strefezza/transfers/spieler/457673/transfer_id/5014000
#
#  Dados de Brian-Aguirre
# https://www.transfermarkt.us/Brian-Aguirre/leistungsdatendetails/spieler/668549
# https://www.transfermarkt.us/Brian-Aguirre/profil/spieler/668549
# Foot: right
# https://www.transfermarkt.us/Brian-Aguirre/leistungsdatendetails/spieler/668549/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Brian-Aguirre/transfers/spieler/668549/transfer_id/5100715
#
#  Dados de Andrea-Belotti
# https://www.transfermarkt.us/Andrea-Belotti/leistungsdatendetails/spieler/167727
# https://www.transfermarkt.us/Andrea-Belotti/profil/spieler/167727
# Foot: right
# https://www.transfermarkt.us/Andrea-Belotti/leistungsdatendetails/spieler/167727/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Andrea-Belotti/transfers/spieler/167727/transfer_id/5074959
#
#  Dados de Rafael-Navarro
# https://www.transfermarkt.us/Rafael-Navarro/leistungsdatendetails/spieler/371267
# https://www.transfermarkt.us/Rafael-Navarro/profil/spieler/371267
# Foot: right
# https://www.transfermarkt.us/Rafael-Navarro/leistungsdatendetails/spieler/371267/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Rafael-Navarro/transfers/spieler/371267/transfer_id/5078651
#
#  Dados de Mika-Biereth
# https://www.transfermarkt.us/Mika-Biereth/leistungsdatendetails/spieler/565821
# https://www.transfermarkt.us/Mika-Biereth/profil/spieler/565821
# Foot: right
# https://www.transfermarkt.us/Mika-Biereth/leistungsdatendetails/spieler/565821/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mika-Biereth/transfers/spieler/565821/transfer_id/5101953
#
#  Dados de Adam-Buksa
# https://www.transfermarkt.us/Adam-Buksa/leistungsdatendetails/spieler/267160
# https://www.transfermarkt.us/Adam-Buksa/profil/spieler/267160
# Foot: left
# https://www.transfermarkt.us/Adam-Buksa/leistungsdatendetails/spieler/267160/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Adam-Buksa/transfers/spieler/267160/transfer_id/5109860
#
#  Dados de Jens-Odgaard
# https://www.transfermarkt.us/Jens-Odgaard/leistungsdatendetails/spieler/345590
# https://www.transfermarkt.us/Jens-Odgaard/profil/spieler/345590
# Foot: left
# https://www.transfermarkt.us/Jens-Odgaard/leistungsdatendetails/spieler/345590/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jens-Odgaard/transfers/spieler/345590/transfer_id/5016787
#
#  Dados de Stipe-Biuk
# https://www.transfermarkt.us/Stipe-Biuk/leistungsdatendetails/spieler/587520
# https://www.transfermarkt.us/Stipe-Biuk/profil/spieler/587520
# Foot: right
# https://www.transfermarkt.us/Stipe-Biuk/leistungsdatendetails/spieler/587520/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Stipe-Biuk/transfers/spieler/587520/transfer_id/5028810
#
#  Dados de Wilson-Isidor
# https://www.transfermarkt.us/Wilson-Isidor/leistungsdatendetails/spieler/494237
# https://www.transfermarkt.us/Wilson-Isidor/profil/spieler/494237
# Foot: right
# https://www.transfermarkt.us/Wilson-Isidor/leistungsdatendetails/spieler/494237/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Wilson-Isidor/transfers/spieler/494237/transfer_id/5029098
#
#  Dados de Samuel-Essende
# https://www.transfermarkt.us/Samuel-Essende/leistungsdatendetails/spieler/395522
# https://www.transfermarkt.us/Samuel-Essende/profil/spieler/395522
# Foot: right
# https://www.transfermarkt.us/Samuel-Essende/leistungsdatendetails/spieler/395522/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Samuel-Essende/transfers/spieler/395522/transfer_id/5079785
#
#  Dados de Peque-Fernandez
# https://www.transfermarkt.us/Peque-Fernandez/leistungsdatendetails/spieler/639733
# https://www.transfermarkt.us/Peque-Fernandez/profil/spieler/639733
# Foot: right
# https://www.transfermarkt.us/Peque-Fernandez/leistungsdatendetails/spieler/639733/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Peque-Fernandez/transfers/spieler/639733/transfer_id/5110146
#
#  Dados de Fidel-Barajas
# https://www.transfermarkt.us/Fidel-Barajas/leistungsdatendetails/spieler/994267
# https://www.transfermarkt.us/Fidel-Barajas/profil/spieler/994267
# Foot: left
# https://www.transfermarkt.us/Fidel-Barajas/leistungsdatendetails/spieler/994267/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Fidel-Barajas/transfers/spieler/994267/transfer_id/5089497
#
#  Dados de Enzo-Copetti
# https://www.transfermarkt.us/Enzo-Copetti/leistungsdatendetails/spieler/504254
# https://www.transfermarkt.us/Enzo-Copetti/profil/spieler/504254
# Foot: right
# https://www.transfermarkt.us/Enzo-Copetti/leistungsdatendetails/spieler/504254/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Enzo-Copetti/transfers/spieler/504254/transfer_id/5017190
#
#  Dados de Milton-Gimenez
# https://www.transfermarkt.us/Milton-Gimenez/leistungsdatendetails/spieler/730779
# https://www.transfermarkt.us/Milton-Gimenez/profil/spieler/730779
# Foot: right
# https://www.transfermarkt.us/Milton-Gimenez/leistungsdatendetails/spieler/730779/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Milton-Gimenez/transfers/spieler/730779/transfer_id/5100641
#
#  Dados de Christos-Tzolis
# https://www.transfermarkt.us/Christos-Tzolis/leistungsdatendetails/spieler/451677
# https://www.transfermarkt.us/Christos-Tzolis/profil/spieler/451677
# Foot: right
# https://www.transfermarkt.us/Christos-Tzolis/leistungsdatendetails/spieler/451677/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Christos-Tzolis/transfers/spieler/451677/transfer_id/5033461
#
#  Dados de Damian-Pizarro
# https://www.transfermarkt.us/Damian-Pizarro/leistungsdatendetails/spieler/950593
# https://www.transfermarkt.us/Damian-Pizarro/profil/spieler/950593
# Foot: right
# https://www.transfermarkt.us/Damian-Pizarro/leistungsdatendetails/spieler/950593/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Damian-Pizarro/transfers/spieler/950593/transfer_id/5089005
#
#  Dados de Couhaib-Driouech
# https://www.transfermarkt.us/Couhaib-Driouech/leistungsdatendetails/spieler/593837
# https://www.transfermarkt.us/Couhaib-Driouech/profil/spieler/593837
# Foot: right
# https://www.transfermarkt.us/Couhaib-Driouech/leistungsdatendetails/spieler/593837/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Couhaib-Driouech/transfers/spieler/593837/transfer_id/5100002
#
#  Dados de Joao-Marques
# https://www.transfermarkt.us/Joao-Marques/leistungsdatendetails/spieler/891971
# https://www.transfermarkt.us/Joao-Marques/profil/spieler/891971
# Foot: right
# https://www.transfermarkt.us/Joao-Marques/leistungsdatendetails/spieler/891971/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Joao-Marques/transfers/spieler/891971/transfer_id/4864026
#
#  Dados de Philip-Otele
# https://www.transfermarkt.us/Philip-Otele/leistungsdatendetails/spieler/678655
# https://www.transfermarkt.us/Philip-Otele/profil/spieler/678655
# Foot: right
# https://www.transfermarkt.us/Philip-Otele/leistungsdatendetails/spieler/678655/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Philip-Otele/transfers/spieler/678655/transfer_id/5102191
#
#  Dados de Fally-Mayulu
# https://www.transfermarkt.us/Fally-Mayulu/leistungsdatendetails/spieler/826719
# https://www.transfermarkt.us/Fally-Mayulu/profil/spieler/826719
# Foot: right
# https://www.transfermarkt.us/Fally-Mayulu/leistungsdatendetails/spieler/826719/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Fally-Mayulu/transfers/spieler/826719/transfer_id/5084361
#
#  Dados de Amine-El-Ouazzani
# https://www.transfermarkt.us/Amine-El-Ouazzani/leistungsdatendetails/spieler/735051
# https://www.transfermarkt.us/Amine-El-Ouazzani/profil/spieler/735051
# Foot: right
# https://www.transfermarkt.us/Amine-El-Ouazzani/leistungsdatendetails/spieler/735051/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Amine-El-Ouazzani/transfers/spieler/735051/transfer_id/5070908
#
#  Dados de Gennaro-Borrelli
# https://www.transfermarkt.us/Gennaro-Borrelli/leistungsdatendetails/spieler/459988
# https://www.transfermarkt.us/Gennaro-Borrelli/profil/spieler/459988
# Foot: right
# https://www.transfermarkt.us/Gennaro-Borrelli/leistungsdatendetails/spieler/459988/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Gennaro-Borrelli/transfers/spieler/459988/transfer_id/5053565
#
#  Dados de Nestory-Irankunda
# https://www.transfermarkt.us/Nestory-Irankunda/leistungsdatendetails/spieler/956920
# https://www.transfermarkt.us/Nestory-Irankunda/profil/spieler/956920
# Foot: right
# https://www.transfermarkt.us/Nestory-Irankunda/leistungsdatendetails/spieler/956920/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Nestory-Irankunda/transfers/spieler/956920/transfer_id/4730375
#
#  Dados de Jorgen-Strand-Larsen
# https://www.transfermarkt.us/Jorgen-Strand-Larsen/leistungsdatendetails/spieler/429983
# https://www.transfermarkt.us/Jorgen-Strand-Larsen/profil/spieler/429983
# Foot: right
# https://www.transfermarkt.us/Jorgen-Strand-Larsen/leistungsdatendetails/spieler/429983/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jorgen-Strand-Larsen/transfers/spieler/429983/transfer_id/5087874
#
#  Dados de Mohamed-Amoura
# https://www.transfermarkt.us/Mohamed-Amoura/leistungsdatendetails/spieler/746910
# https://www.transfermarkt.us/Mohamed-Amoura/profil/spieler/746910
# Foot: right
# https://www.transfermarkt.us/Mohamed-Amoura/leistungsdatendetails/spieler/746910/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mohamed-Amoura/transfers/spieler/746910/transfer_id/5102143
#
#  Dados de Tomas-Chory
# https://www.transfermarkt.us/Tomas-Chory/leistungsdatendetails/spieler/198614
# https://www.transfermarkt.us/Tomas-Chory/profil/spieler/198614
# Foot: right
# https://www.transfermarkt.us/Tomas-Chory/leistungsdatendetails/spieler/198614/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Tomas-Chory/transfers/spieler/198614/transfer_id/5092082
#
#  Dados de Jhonder-Cadiz
# https://www.transfermarkt.us/Jhonder-Cadiz/leistungsdatendetails/spieler/271256
# https://www.transfermarkt.us/Jhonder-Cadiz/profil/spieler/271256
# Foot: right
# https://www.transfermarkt.us/Jhonder-Cadiz/leistungsdatendetails/spieler/271256/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jhonder-Cadiz/transfers/spieler/271256/transfer_id/5105636
#
#  Dados de Estanis-Pedrola
# https://www.transfermarkt.us/Estanis-Pedrola/leistungsdatendetails/spieler/913539
# https://www.transfermarkt.us/Estanis-Pedrola/profil/spieler/913539
# Foot: right
# https://www.transfermarkt.us/Estanis-Pedrola/leistungsdatendetails/spieler/913539/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Estanis-Pedrola/transfers/spieler/913539/transfer_id/4700074
#
#  Dados de Andri-Gudjohnsen
# https://www.transfermarkt.us/Andri-Gudjohnsen/leistungsdatendetails/spieler/490967
# https://www.transfermarkt.us/Andri-Gudjohnsen/profil/spieler/490967
# Foot: right
# https://www.transfermarkt.us/Andri-Gudjohnsen/leistungsdatendetails/spieler/490967/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Andri-Gudjohnsen/transfers/spieler/490967/transfer_id/5044356
#
#  Dados de Delano-Burgzorg
# https://www.transfermarkt.us/Delano-Burgzorg/leistungsdatendetails/spieler/436585
# https://www.transfermarkt.us/Delano-Burgzorg/profil/spieler/436585
# Foot: right
# https://www.transfermarkt.us/Delano-Burgzorg/leistungsdatendetails/spieler/436585/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Delano-Burgzorg/transfers/spieler/436585/transfer_id/5055752
#
#  Dados de Lautaro-Diaz
# https://www.transfermarkt.us/Lautaro-Diaz/leistungsdatendetails/spieler/720294
# https://www.transfermarkt.us/Lautaro-Diaz/profil/spieler/720294
# Foot: right
# https://www.transfermarkt.us/Lautaro-Diaz/leistungsdatendetails/spieler/720294/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Lautaro-Diaz/transfers/spieler/720294/transfer_id/5051080
#
#  Dados de Gennaro-Tutino
# https://www.transfermarkt.us/Gennaro-Tutino/leistungsdatendetails/spieler/202979
# https://www.transfermarkt.us/Gennaro-Tutino/profil/spieler/202979
# Foot: right
# https://www.transfermarkt.us/Gennaro-Tutino/leistungsdatendetails/spieler/202979/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Gennaro-Tutino/transfers/spieler/202979/transfer_id/5055574
#
#  Dados de Moussa-Sylla
# https://www.transfermarkt.us/Moussa-Sylla/leistungsdatendetails/spieler/460655
# https://www.transfermarkt.us/Moussa-Sylla/profil/spieler/460655
# Foot: right
# https://www.transfermarkt.us/Moussa-Sylla/leistungsdatendetails/spieler/460655/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Moussa-Sylla/transfers/spieler/460655/transfer_id/5072777
#
#  Dados de Raul-Moro
# https://www.transfermarkt.us/Raul-Moro/leistungsdatendetails/spieler/624942
# https://www.transfermarkt.us/Raul-Moro/profil/spieler/624942
# Foot: right
# https://www.transfermarkt.us/Raul-Moro/leistungsdatendetails/spieler/624942/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Raul-Moro/transfers/spieler/624942/transfer_id/5029404
#
#  Dados de Anis-Hadj-Moussa
# https://www.transfermarkt.us/Anis-Hadj-Moussa/leistungsdatendetails/spieler/917911
# https://www.transfermarkt.us/Anis-Hadj-Moussa/profil/spieler/917911
# Foot: left
# https://www.transfermarkt.us/Anis-Hadj-Moussa/leistungsdatendetails/spieler/917911/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Anis-Hadj-Moussa/transfers/spieler/917911/transfer_id/4964369
#
#  Dados de Dmitriy-Vorobyev
# https://www.transfermarkt.us/Dmitriy-Vorobyev/leistungsdatendetails/spieler/370287
# https://www.transfermarkt.us/Dmitriy-Vorobyev/profil/spieler/370287
# Foot: right
# https://www.transfermarkt.us/Dmitriy-Vorobyev/leistungsdatendetails/spieler/370287/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Dmitriy-Vorobyev/transfers/spieler/370287/transfer_id/5048297
#
#  Dados de Hamza-Igamane
# https://www.transfermarkt.us/Hamza-Igamane/leistungsdatendetails/spieler/885445
# https://www.transfermarkt.us/Hamza-Igamane/profil/spieler/885445
# Foot: right
# https://www.transfermarkt.us/Hamza-Igamane/leistungsdatendetails/spieler/885445/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Hamza-Igamane/transfers/spieler/885445/transfer_id/5071007
#
#  Dados de Jose-Juan-Macias
# https://www.transfermarkt.us/Jose-Juan-Macias/leistungsdatendetails/spieler/546047
# https://www.transfermarkt.us/Jose-Juan-Macias/profil/spieler/546047
# Foot: right
# https://www.transfermarkt.us/Jose-Juan-Macias/leistungsdatendetails/spieler/546047/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jose-Juan-Macias/transfers/spieler/546047/transfer_id/5072632
#
#  Dados de Veljko-Birmancevic
# https://www.transfermarkt.us/Veljko-Birmancevic/leistungsdatendetails/spieler/419648
# https://www.transfermarkt.us/Veljko-Birmancevic/profil/spieler/419648
# Foot: right
# https://www.transfermarkt.us/Veljko-Birmancevic/leistungsdatendetails/spieler/419648/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Veljko-Birmancevic/transfers/spieler/419648/transfer_id/4923402
#
#  Dados de Willian-Jose
# https://www.transfermarkt.us/Willian-Jose/leistungsdatendetails/spieler/122155
# https://www.transfermarkt.us/Willian-Jose/profil/spieler/122155
# Foot: right
# https://www.transfermarkt.us/Willian-Jose/leistungsdatendetails/spieler/122155/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Willian-Jose/transfers/spieler/122155/transfer_id/5085769
#
#  Dados de Tomas-Conechny
# https://www.transfermarkt.us/Tomas-Conechny/leistungsdatendetails/spieler/401571
# https://www.transfermarkt.us/Tomas-Conechny/profil/spieler/401571
# Foot: left
# https://www.transfermarkt.us/Tomas-Conechny/leistungsdatendetails/spieler/401571/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Tomas-Conechny/transfers/spieler/401571/transfer_id/5096813
#
#  Dados de Sead-Haksabanovic
# https://www.transfermarkt.us/Sead-Haksabanovic/leistungsdatendetails/spieler/349300
# https://www.transfermarkt.us/Sead-Haksabanovic/profil/spieler/349300
# Foot: right
# https://www.transfermarkt.us/Sead-Haksabanovic/leistungsdatendetails/spieler/349300/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Sead-Haksabanovic/transfers/spieler/349300/transfer_id/5076514
#
#  Dados de Cihan-Canak
# https://www.transfermarkt.us/Cihan-Canak/leistungsdatendetails/spieler/743376
# https://www.transfermarkt.us/Cihan-Canak/profil/spieler/743376
# Foot: left
# https://www.transfermarkt.us/Cihan-Canak/leistungsdatendetails/spieler/743376/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Cihan-Canak/transfers/spieler/743376/transfer_id/5074855
#
#  Dados de Keke-Topp
# https://www.transfermarkt.us/Keke-Topp/leistungsdatendetails/spieler/701757
# https://www.transfermarkt.us/Keke-Topp/profil/spieler/701757
# Foot: right
# https://www.transfermarkt.us/Keke-Topp/leistungsdatendetails/spieler/701757/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Keke-Topp/transfers/spieler/701757/transfer_id/5064100
#
#  Dados de Peter-Federico
# https://www.transfermarkt.us/Peter-Federico/leistungsdatendetails/spieler/710004
# https://www.transfermarkt.us/Peter-Federico/profil/spieler/710004
# Foot: left
# https://www.transfermarkt.us/Peter-Federico/leistungsdatendetails/spieler/710004/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Peter-Federico/transfers/spieler/710004/transfer_id/5094612
#
#  Dados de Miguel-de-la-Fuente
# https://www.transfermarkt.us/Miguel-de-la-Fuente/leistungsdatendetails/spieler/480883
# https://www.transfermarkt.us/Miguel-de-la-Fuente/profil/spieler/480883
# Foot: right
# https://www.transfermarkt.us/Miguel-de-la-Fuente/leistungsdatendetails/spieler/480883/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Miguel-de-la-Fuente/transfers/spieler/480883/transfer_id/5038646
#
#  Dados de Mohammed-Fuseini
# https://www.transfermarkt.us/Mohammed-Fuseini/leistungsdatendetails/spieler/979410
# https://www.transfermarkt.us/Mohammed-Fuseini/profil/spieler/979410
# NA
# https://www.transfermarkt.us/Mohammed-Fuseini/leistungsdatendetails/spieler/979410/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mohammed-Fuseini/transfers/spieler/979410/transfer_id/5087551
#
#  Dados de Puma
# https://www.transfermarkt.us/Puma/leistungsdatendetails/spieler/425028
# https://www.transfermarkt.us/Puma/profil/spieler/425028
# Foot: left
# https://www.transfermarkt.us/Puma/leistungsdatendetails/spieler/425028/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Puma/transfers/spieler/425028/transfer_id/5068137
#
#  Dados de Marvin-Park
# https://www.transfermarkt.us/Marvin-Park/leistungsdatendetails/spieler/603940
# https://www.transfermarkt.us/Marvin-Park/profil/spieler/603940
# Foot: right
# https://www.transfermarkt.us/Marvin-Park/leistungsdatendetails/spieler/603940/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Marvin-Park/transfers/spieler/603940/transfer_id/5031600
#
#  Dados de Ermal-Krasniqi
# https://www.transfermarkt.us/Ermal-Krasniqi/leistungsdatendetails/spieler/606893
# https://www.transfermarkt.us/Ermal-Krasniqi/profil/spieler/606893
# Foot: right
# https://www.transfermarkt.us/Ermal-Krasniqi/leistungsdatendetails/spieler/606893/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ermal-Krasniqi/transfers/spieler/606893/transfer_id/5044763
#
#  Dados de Amath-Ndiaye
# https://www.transfermarkt.us/Amath-Ndiaye/leistungsdatendetails/spieler/339820
# https://www.transfermarkt.us/Amath-Ndiaye/profil/spieler/339820
# Foot: right
# https://www.transfermarkt.us/Amath-Ndiaye/leistungsdatendetails/spieler/339820/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Amath-Ndiaye/transfers/spieler/339820/transfer_id/5029405
#
#  Dados de Mattia-Felici
# https://www.transfermarkt.us/Mattia-Felici/leistungsdatendetails/spieler/600041
# https://www.transfermarkt.us/Mattia-Felici/profil/spieler/600041
# Foot: right
# https://www.transfermarkt.us/Mattia-Felici/leistungsdatendetails/spieler/600041/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mattia-Felici/transfers/spieler/600041/transfer_id/5109728
#
#  Dados de Javier-Correa
# https://www.transfermarkt.us/Javier-Correa/leistungsdatendetails/spieler/130413
# https://www.transfermarkt.us/Javier-Correa/profil/spieler/130413
# Foot: right
# https://www.transfermarkt.us/Javier-Correa/leistungsdatendetails/spieler/130413/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Javier-Correa/transfers/spieler/130413/transfer_id/5086876
#
#  Dados de Iker-Losada
# https://www.transfermarkt.us/Iker-Losada/leistungsdatendetails/spieler/632741
# https://www.transfermarkt.us/Iker-Losada/profil/spieler/632741
# Foot: right
# https://www.transfermarkt.us/Iker-Losada/leistungsdatendetails/spieler/632741/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Iker-Losada/transfers/spieler/632741/transfer_id/5097832
#
#  Dados de Roberto-Fernandez
# https://www.transfermarkt.us/Roberto-Fernandez/leistungsdatendetails/spieler/720518
# https://www.transfermarkt.us/Roberto-Fernandez/profil/spieler/720518
# Foot: right
# https://www.transfermarkt.us/Roberto-Fernandez/leistungsdatendetails/spieler/720518/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Roberto-Fernandez/transfers/spieler/720518/transfer_id/5105597
#
#  Dados de Emil-Hansson
# https://www.transfermarkt.us/Emil-Hansson/leistungsdatendetails/spieler/276002
# https://www.transfermarkt.us/Emil-Hansson/profil/spieler/276002
# Foot: right
# https://www.transfermarkt.us/Emil-Hansson/leistungsdatendetails/spieler/276002/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Emil-Hansson/transfers/spieler/276002/transfer_id/5097009
#
#  Dados de Denis-Dragus
# https://www.transfermarkt.us/Denis-Dragus/leistungsdatendetails/spieler/405399
# https://www.transfermarkt.us/Denis-Dragus/profil/spieler/405399
# Foot: right
# https://www.transfermarkt.us/Denis-Dragus/leistungsdatendetails/spieler/405399/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Denis-Dragus/transfers/spieler/405399/transfer_id/5071662
#
#  Dados de Sebastian-Villa
# https://www.transfermarkt.us/Sebastian-Villa/leistungsdatendetails/spieler/493000
# https://www.transfermarkt.us/Sebastian-Villa/profil/spieler/493000
# Foot: right
# https://www.transfermarkt.us/Sebastian-Villa/leistungsdatendetails/spieler/493000/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Sebastian-Villa/transfers/spieler/493000/transfer_id/5088181
#
#  Dados de Matias-Reali
# https://www.transfermarkt.us/Matias-Reali/leistungsdatendetails/spieler/984692
# https://www.transfermarkt.us/Matias-Reali/profil/spieler/984692
# Foot: both
# https://www.transfermarkt.us/Matias-Reali/leistungsdatendetails/spieler/984692/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Matias-Reali/transfers/spieler/984692/transfer_id/5083809
#
#  Dados de Ebrima-Colley
# https://www.transfermarkt.us/Ebrima-Colley/leistungsdatendetails/spieler/567217
# https://www.transfermarkt.us/Ebrima-Colley/profil/spieler/567217
# Foot: right
# https://www.transfermarkt.us/Ebrima-Colley/leistungsdatendetails/spieler/567217/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ebrima-Colley/transfers/spieler/567217/transfer_id/5044586
#
#  Dados de Elad-Madmon
# https://www.transfermarkt.us/Elad-Madmon/leistungsdatendetails/spieler/1079637
# https://www.transfermarkt.us/Elad-Madmon/profil/spieler/1079637
# Foot: both
# https://www.transfermarkt.us/Elad-Madmon/leistungsdatendetails/spieler/1079637/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Elad-Madmon/transfers/spieler/1079637/transfer_id/4867868
#
#  Dados de Joselu
# https://www.transfermarkt.us/Joselu/leistungsdatendetails/spieler/81999
# https://www.transfermarkt.us/Joselu/profil/spieler/81999
# Foot: right
# https://www.transfermarkt.us/Joselu/leistungsdatendetails/spieler/81999/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Joselu/transfers/spieler/81999/transfer_id/5078179
#
#  Dados de Joselu
# https://www.transfermarkt.us/Joselu/leistungsdatendetails/spieler/81999
# https://www.transfermarkt.us/Joselu/profil/spieler/81999
# Foot: right
# https://www.transfermarkt.us/Joselu/leistungsdatendetails/spieler/81999/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Joselu/transfers/spieler/81999/transfer_id/5080778
#
#  Dados de Jean-Philippe-Krasso
# https://www.transfermarkt.us/Jean-Philippe-Krasso/leistungsdatendetails/spieler/358515
# https://www.transfermarkt.us/Jean-Philippe-Krasso/profil/spieler/358515
# Foot: left
# https://www.transfermarkt.us/Jean-Philippe-Krasso/leistungsdatendetails/spieler/358515/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# ...
# https://www.transfermarkt.us/Jeppe-Erenbjerg/transfers/spieler/543302/transfer_id/5065557
#
#  Dados de Dimitar-Trajkov
# https://www.transfermarkt.us/Dimitar-Trajkov/leistungsdatendetails/spieler/898135
# https://www.transfermarkt.us/Dimitar-Trajkov/profil/spieler/898135
# Foot: left
# https://www.transfermarkt.us/Dimitar-Trajkov/leistungsdatendetails/spieler/898135/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Dimitar-Trajkov/transfers/spieler/898135/transfer_id/5014733
#
#  Dados de Ayrton-Portillo
# https://www.transfermarkt.us/Ayrton-Portillo/leistungsdatendetails/spieler/841207
# https://www.transfermarkt.us/Ayrton-Portillo/profil/spieler/841207
# Foot: right
# https://www.transfermarkt.us/Ayrton-Portillo/leistungsdatendetails/spieler/841207/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ayrton-Portillo/transfers/spieler/841207/transfer_id/5109478
#
#  Dados de Pelle-van-Amersfoort
# https://www.transfermarkt.us/Pelle-van-Amersfoort/leistungsdatendetails/spieler/262613
# https://www.transfermarkt.us/Pelle-van-Amersfoort/profil/spieler/262613
# Foot: right
# https://www.transfermarkt.us/Pelle-van-Amersfoort/leistungsdatendetails/spieler/262613/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Pelle-van-Amersfoort/transfers/spieler/262613/transfer_id/5110879
#
#  Dados de Isak-Jansson
# https://www.transfermarkt.us/Isak-Jansson/leistungsdatendetails/spieler/535820
# https://www.transfermarkt.us/Isak-Jansson/profil/spieler/535820
# Foot: right
# https://www.transfermarkt.us/Isak-Jansson/leistungsdatendetails/spieler/535820/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Isak-Jansson/transfers/spieler/535820/transfer_id/5031065
#
#  Dados de Robert-Polievka
# https://www.transfermarkt.us/Robert-Polievka/leistungsdatendetails/spieler/291234
# https://www.transfermarkt.us/Robert-Polievka/profil/spieler/291234
# Foot: right
# https://www.transfermarkt.us/Robert-Polievka/leistungsdatendetails/spieler/291234/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Robert-Polievka/transfers/spieler/291234/transfer_id/5059338
#
#  Dados de Andrey-Okladnikov
# https://www.transfermarkt.us/Andrey-Okladnikov/leistungsdatendetails/spieler/909076
# https://www.transfermarkt.us/Andrey-Okladnikov/profil/spieler/909076
# Foot: right
# https://www.transfermarkt.us/Andrey-Okladnikov/leistungsdatendetails/spieler/909076/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Andrey-Okladnikov/transfers/spieler/909076/transfer_id/5066012
#
#  Dados de Davide-Lamesta
# https://www.transfermarkt.us/Davide-Lamesta/leistungsdatendetails/spieler/689090
# https://www.transfermarkt.us/Davide-Lamesta/profil/spieler/689090
# Foot: left
# https://www.transfermarkt.us/Davide-Lamesta/leistungsdatendetails/spieler/689090/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Davide-Lamesta/transfers/spieler/689090/transfer_id/5098285
#
#  Dados de Andrea-Adorante
# https://www.transfermarkt.us/Andrea-Adorante/leistungsdatendetails/spieler/364206
# https://www.transfermarkt.us/Andrea-Adorante/profil/spieler/364206
# Foot: right
# https://www.transfermarkt.us/Andrea-Adorante/leistungsdatendetails/spieler/364206/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Andrea-Adorante/transfers/spieler/364206/transfer_id/4975192
#
#  Dados de Noel-Futkeu
# https://www.transfermarkt.us/Noel-Futkeu/leistungsdatendetails/spieler/675535
# https://www.transfermarkt.us/Noel-Futkeu/profil/spieler/675535
# Foot: right
# https://www.transfermarkt.us/Noel-Futkeu/leistungsdatendetails/spieler/675535/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Noel-Futkeu/transfers/spieler/675535/transfer_id/5017917
#
#  Dados de Rio-Nitta
# https://www.transfermarkt.us/Rio-Nitta/leistungsdatendetails/spieler/903366
# https://www.transfermarkt.us/Rio-Nitta/profil/spieler/903366
# NA
# https://www.transfermarkt.us/Rio-Nitta/leistungsdatendetails/spieler/903366/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Rio-Nitta/transfers/spieler/903366/transfer_id/5077724
#
#  Dados de Daniel-Vasulin
# https://www.transfermarkt.us/Daniel-Vasulin/leistungsdatendetails/spieler/558473
# https://www.transfermarkt.us/Daniel-Vasulin/profil/spieler/558473
# Foot: right
# https://www.transfermarkt.us/Daniel-Vasulin/leistungsdatendetails/spieler/558473/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Daniel-Vasulin/transfers/spieler/558473/transfer_id/5054248
#
#  Dados de Mark-Assinor
# https://www.transfermarkt.us/Mark-Assinor/leistungsdatendetails/spieler/1033040
# https://www.transfermarkt.us/Mark-Assinor/profil/spieler/1033040
# Foot: right
# https://www.transfermarkt.us/Mark-Assinor/leistungsdatendetails/spieler/1033040/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mark-Assinor/transfers/spieler/1033040/transfer_id/5067658
#
#  Dados de Ruslan-Bart
# https://www.transfermarkt.us/Ruslan-Bart/leistungsdatendetails/spieler/918824
# https://www.transfermarkt.us/Ruslan-Bart/profil/spieler/918824
# Foot: right
# https://www.transfermarkt.us/Ruslan-Bart/leistungsdatendetails/spieler/918824/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ruslan-Bart/transfers/spieler/918824/transfer_id/5083822
#
#  Dados de Stenio
# https://www.transfermarkt.us/Stenio/leistungsdatendetails/spieler/796574
# https://www.transfermarkt.us/Stenio/profil/spieler/796574
# Foot: right
# https://www.transfermarkt.us/Stenio/leistungsdatendetails/spieler/796574/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Stenio/transfers/spieler/796574/transfer_id/5108084
#
#  Dados de Kevin-Rosero
# https://www.transfermarkt.us/Kevin-Rosero/leistungsdatendetails/spieler/630032
# https://www.transfermarkt.us/Kevin-Rosero/profil/spieler/630032
# Foot: right
# https://www.transfermarkt.us/Kevin-Rosero/leistungsdatendetails/spieler/630032/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Kevin-Rosero/transfers/spieler/630032/transfer_id/5062830
#
#  Dados de Giuseppe-Panico
# https://www.transfermarkt.us/Giuseppe-Panico/leistungsdatendetails/spieler/287648
# https://www.transfermarkt.us/Giuseppe-Panico/profil/spieler/287648
# Foot: right
# https://www.transfermarkt.us/Giuseppe-Panico/leistungsdatendetails/spieler/287648/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Giuseppe-Panico/transfers/spieler/287648/transfer_id/4539843
#
#  Dados de Zdravko-Dimitrov
# https://www.transfermarkt.us/Zdravko-Dimitrov/leistungsdatendetails/spieler/587688
# https://www.transfermarkt.us/Zdravko-Dimitrov/profil/spieler/587688
# Foot: right
# https://www.transfermarkt.us/Zdravko-Dimitrov/leistungsdatendetails/spieler/587688/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Zdravko-Dimitrov/transfers/spieler/587688/transfer_id/5072997
#
#  Dados de Manuel-Polster
# https://www.transfermarkt.us/Manuel-Polster/leistungsdatendetails/spieler/488072
# https://www.transfermarkt.us/Manuel-Polster/profil/spieler/488072
# Foot: left
# https://www.transfermarkt.us/Manuel-Polster/leistungsdatendetails/spieler/488072/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Manuel-Polster/transfers/spieler/488072/transfer_id/5089911
#
#  Dados de Ronaldo-Tavares
# https://www.transfermarkt.us/Ronaldo-Tavares/leistungsdatendetails/spieler/340531
# https://www.transfermarkt.us/Ronaldo-Tavares/profil/spieler/340531
# Foot: right
# https://www.transfermarkt.us/Ronaldo-Tavares/leistungsdatendetails/spieler/340531/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ronaldo-Tavares/transfers/spieler/340531/transfer_id/5056671
#
#  Dados de Declan-Frith
# https://www.transfermarkt.us/Declan-Frith/leistungsdatendetails/spieler/865917
# https://www.transfermarkt.us/Declan-Frith/profil/spieler/865917
# Foot: left
# https://www.transfermarkt.us/Declan-Frith/leistungsdatendetails/spieler/865917/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Declan-Frith/transfers/spieler/865917/transfer_id/5109984
#
#  Dados de Ivan-Djantou
# https://www.transfermarkt.us/Ivan-Djantou/leistungsdatendetails/spieler/1074629
# https://www.transfermarkt.us/Ivan-Djantou/profil/spieler/1074629
# Foot: right
# https://www.transfermarkt.us/Ivan-Djantou/leistungsdatendetails/spieler/1074629/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ivan-Djantou/transfers/spieler/1074629/transfer_id/5056669
#
#  Dados de Enzo-Cabrera
# https://www.transfermarkt.us/Enzo-Cabrera/leistungsdatendetails/spieler/538527
# https://www.transfermarkt.us/Enzo-Cabrera/profil/spieler/538527
# Foot: right
# https://www.transfermarkt.us/Enzo-Cabrera/leistungsdatendetails/spieler/538527/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Enzo-Cabrera/transfers/spieler/538527/transfer_id/5084140
#
#  Dados de Ilya-Stefanovich
# https://www.transfermarkt.us/Ilya-Stefanovich/leistungsdatendetails/spieler/398726
# https://www.transfermarkt.us/Ilya-Stefanovich/profil/spieler/398726
# Foot: right
# https://www.transfermarkt.us/Ilya-Stefanovich/leistungsdatendetails/spieler/398726/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Ilya-Stefanovich/transfers/spieler/398726/transfer_id/5108325
#
#  Dados de Mihajlo-Neskovic
# https://www.transfermarkt.us/Mihajlo-Neskovic/leistungsdatendetails/spieler/469828
# https://www.transfermarkt.us/Mihajlo-Neskovic/profil/spieler/469828
# Foot: right
# https://www.transfermarkt.us/Mihajlo-Neskovic/leistungsdatendetails/spieler/469828/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mihajlo-Neskovic/transfers/spieler/469828/transfer_id/5011576
#
#  Dados de Marios-Ilia
# https://www.transfermarkt.us/Marios-Ilia/leistungsdatendetails/spieler/327870
# https://www.transfermarkt.us/Marios-Ilia/profil/spieler/327870
# Foot: right
# https://www.transfermarkt.us/Marios-Ilia/leistungsdatendetails/spieler/327870/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Marios-Ilia/transfers/spieler/327870/transfer_id/5076606
#
#  Dados de Devin-Haen
# https://www.transfermarkt.us/Devin-Haen/leistungsdatendetails/spieler/704771
# https://www.transfermarkt.us/Devin-Haen/profil/spieler/704771
# Foot: right
# https://www.transfermarkt.us/Devin-Haen/leistungsdatendetails/spieler/704771/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Devin-Haen/transfers/spieler/704771/transfer_id/5090495
#
#  Dados de Nikita-Glushkov
# https://www.transfermarkt.us/Nikita-Glushkov/leistungsdatendetails/spieler/444833
# https://www.transfermarkt.us/Nikita-Glushkov/profil/spieler/444833
# Foot: right
# https://www.transfermarkt.us/Nikita-Glushkov/leistungsdatendetails/spieler/444833/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Nikita-Glushkov/transfers/spieler/444833/transfer_id/5088794
#
#  Dados de Robert-Street
# https://www.transfermarkt.us/Robert-Street/leistungsdatendetails/spieler/703474
# https://www.transfermarkt.us/Robert-Street/profil/spieler/703474
# Foot: right
# https://www.transfermarkt.us/Robert-Street/leistungsdatendetails/spieler/703474/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Robert-Street/transfers/spieler/703474/transfer_id/5088416
#
#  Dados de Yegor-Gunichev
# https://www.transfermarkt.us/Yegor-Gunichev/leistungsdatendetails/spieler/809569
# https://www.transfermarkt.us/Yegor-Gunichev/profil/spieler/809569
# Foot: right
# https://www.transfermarkt.us/Yegor-Gunichev/leistungsdatendetails/spieler/809569/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Yegor-Gunichev/transfers/spieler/809569/transfer_id/5088553
#
#  Dados de Aodhan-Doherty
# https://www.transfermarkt.us/Aodhan-Doherty/leistungsdatendetails/spieler/1077242
# https://www.transfermarkt.us/Aodhan-Doherty/profil/spieler/1077242
# Foot: left
# https://www.transfermarkt.us/Aodhan-Doherty/leistungsdatendetails/spieler/1077242/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Aodhan-Doherty/transfers/spieler/1077242/transfer_id/5033468
#
#  Dados de Cassiano
# https://www.transfermarkt.us/Cassiano/leistungsdatendetails/spieler/238367
# https://www.transfermarkt.us/Cassiano/profil/spieler/238367
# Foot: right
# https://www.transfermarkt.us/Cassiano/leistungsdatendetails/spieler/238367/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Cassiano/transfers/spieler/238367/transfer_id/5083304
#
#  Dados de Samir-Farhud
# https://www.transfermarkt.us/Samir-Farhud/leistungsdatendetails/spieler/807391
# https://www.transfermarkt.us/Samir-Farhud/profil/spieler/807391
# NA
# https://www.transfermarkt.us/Samir-Farhud/leistungsdatendetails/spieler/807391/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Samir-Farhud/transfers/spieler/807391/transfer_id/5076743
#
#  Dados de Jonas-Saliger
# https://www.transfermarkt.us/Jonas-Saliger/leistungsdatendetails/spieler/784710
# https://www.transfermarkt.us/Jonas-Saliger/profil/spieler/784710
# Foot: both
# https://www.transfermarkt.us/Jonas-Saliger/leistungsdatendetails/spieler/784710/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Jonas-Saliger/transfers/spieler/784710/transfer_id/5024214
#
#  Dados de Vicky-Kiankaulua
# https://www.transfermarkt.us/Vicky-Kiankaulua/leistungsdatendetails/spieler/796893
# https://www.transfermarkt.us/Vicky-Kiankaulua/profil/spieler/796893
# Foot: right
# https://www.transfermarkt.us/Vicky-Kiankaulua/leistungsdatendetails/spieler/796893/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Vicky-Kiankaulua/transfers/spieler/796893/transfer_id/5022643
#
#  Dados de Chuma
# https://www.transfermarkt.us/Chuma/leistungsdatendetails/spieler/251853
# https://www.transfermarkt.us/Chuma/profil/spieler/251853
# NA
# https://www.transfermarkt.us/Chuma/leistungsdatendetails/spieler/251853/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Chuma/transfers/spieler/251853/transfer_id/5053176
#
#  Dados de Kebba-Sowe
# https://www.transfermarkt.us/Kebba-Sowe/leistungsdatendetails/spieler/669379
# https://www.transfermarkt.us/Kebba-Sowe/profil/spieler/669379
# Foot: left
# https://www.transfermarkt.us/Kebba-Sowe/leistungsdatendetails/spieler/669379/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Kebba-Sowe/transfers/spieler/669379/transfer_id/4872623
#
#  Dados de Stanislav-Lapinskiy
# https://www.transfermarkt.us/Stanislav-Lapinskiy/leistungsdatendetails/spieler/715384
# https://www.transfermarkt.us/Stanislav-Lapinskiy/profil/spieler/715384
# Foot: right
# https://www.transfermarkt.us/Stanislav-Lapinskiy/leistungsdatendetails/spieler/715384/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Stanislav-Lapinskiy/transfers/spieler/715384/transfer_id/5093020
#
#  Dados de Mamadou-Kanoute
# https://www.transfermarkt.us/Mamadou-Kanoute/leistungsdatendetails/spieler/201734
# https://www.transfermarkt.us/Mamadou-Kanoute/profil/spieler/201734
# Foot: right
# https://www.transfermarkt.us/Mamadou-Kanoute/leistungsdatendetails/spieler/201734/saison/2023/verein/0/liga/0/wettbewerb//pos/0/trainer_id/0/plus/1
# https://www.transfermarkt.us/Mamadou-Kanoute/transfers/spieler/201734/transfer_id/5090850
# Hora Final: 21:19:22
