# %% [markdown]
# # Import/load

# %%
import pandas as pd
import numpy as np

# %%
df_base = pd.read_csv('02-FW.csv')
df_home = pd.read_csv('03-FW-home.csv')
df_stats = pd.read_csv('03-FW-stats.csv')

# %% [markdown]
# # head

# %%
df_base.head(3).T
# Out:
#                                                                      0  \
# ID                                                              106076
# Perfil                          /ricardo-goulart/profil/spieler/106076
# Nome                                                   Ricardo Goulart
# Posição                                                 Second Striker
# Idade                                                               23
# Valor de Mercado                                            11000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /ec-cruzeiro-belo-horizonte/startseite/verein/...
# Clube Antigo                                                  Cruzeiro
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /guangzhou-fc/startseite/verein/10948/saison_i...
# Clube Novo                                               GZ Evergrande
# URL Liga Nova        /chinese-super-league/transfers/wettbewerb/CSL...
# Liga Nova                                                 Super League
# Valor Transferência                                         15000000.0
# Ano da Tranferência                                               2014
#
#                                                                      1  \
# ID                                                               29424
# Perfil                                  /paulinho/profil/spieler/29424
# Nome                                                          Paulinho
# Posição                                                 Centre-Forward
# Idade                                                               28
# Valor de Mercado                                             8500000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /as-livorno/startseite/verein/1210/saison_id/2014
# Clube Antigo                                                AS Livorno
# URL Liga Antiga       /serie-b/transfers/wettbewerb/IT2/saison_id/2014
# Liga Antiga                                                    Serie B
# URL Clube Novo       /al-arabi-sc/startseite/verein/1230/saison_id/...
# Clube Novo                                                 Al-Arabi SC
# URL Liga Nova        /qatar-stars-league/transfers/wettbewerb/QSL/s...
# Liga Nova                                                 Stars League
# Valor Transferência                                          8000000.0
# Ano da Tranferência                                               2014
#
#                                                                      2
# ID                                                              193925
# Perfil                                /romarinho/profil/spieler/193925
# Nome                                                         Romarinho
# Posição                                                 Centre-Forward
# Idade                                                               23
# Valor de Mercado                                             2000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /corinthians-sao-paulo/startseite/verein/199/s...
# Clube Antigo                                               Corinthians
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /el-jaish-sports-club/startseite/verein/33288/...
# Clube Novo                                                    El-Jaish
# URL Liga Nova        /qatar-stars-league/transfers/wettbewerb/QSL/s...
# Liga Nova                                                 Stars League
# Valor Transferência                                          7500000.0
# Ano da Tranferência                                               2014

# %%
df_home.head(3).T
# Out:
#                              0                  1                        2
# Unnamed: 0                   0                  1                        2
# ID                      106076              29424                   193925
# nome_hifen     Ricardo-Goulart           Paulinho                Romarinho
# pe                       right              right                    right
# data_nasc     Jun 5, 1991 (33)  Jan 10, 1986 (39)        Dec 12, 1990 (34)
# local_nasc           São Paulo      Caxias do Sul                Palestina
# cidadania     2, Brazil, China   2, Brazil, Italy  2, Brazil, Saudi Arabia
# altura                  1,81 m             1,76 m                   1,76 m
# convocacoes                  1                 12                        0
# gols_selecao                 0                  4                        0

# %%
df_stats.head(3).T
# Out:
#                       0       1       2
# Unnamed: 0            0       1       2
# ID               106076   29424  193925
# ano_stat           2013    2013    2013
# escalado             52      37      39
# jogou                50      36      37
# ppm                 2.0    0.69    1.76
# gols_para            20      15      12
# assistencias          8       4       1
# gols_contra           -       -       -
# entrou                3       -      12
# saiu                 21       2      16
# amarelo               4       8       2
# amarelo_duplo         -       -       -
# vermelho              -       -       -
# Gols_de_penalti       -       3       -
# minutos_por_gol    199'    216'    193'
# minutos          3.982'  3.234'  2.315'

# %% [markdown]
# # Checagem de tipo

# %%
print("df_base:",df_base.shape)
print("df_home:",df_home.shape)
print("df_stats:",df_stats.shape)
# Out:
# df_base: (3029, 17)
# df_home: (1017, 10)
# df_stats: (2309, 17)

# %%
df_base.dtypes
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado       float64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência    float64
# Ano da Tranferência      int64
# dtype: object

# %%
df_home.dtypes
# Out:
# Unnamed: 0       int64
# ID               int64
# nome_hifen      object
# pe              object
# data_nasc       object
# local_nasc      object
# cidadania       object
# altura          object
# convocacoes      int64
# gols_selecao     int64
# dtype: object

# %%
df_stats.dtypes
# Out:
# Unnamed: 0           int64
# ID                   int64
# ano_stat             int64
# escalado             int64
# jogou               object
# ppm                float64
# gols_para           object
# assistencias        object
# gols_contra         object
# entrou              object
# saiu                object
# amarelo             object
# amarelo_duplo       object
# vermelho            object
# Gols_de_penalti     object
# minutos_por_gol     object
# minutos             object
# dtype: object

# %% [markdown]
# # Descarte de colunas

# %%
df_home = df_home.drop(columns=["Unnamed: 0"])
df_home = df_home.drop(columns=["nome_hifen"])


df_stats = df_stats.drop(columns=["Unnamed: 0"])

# %% [markdown]
# # Merges

# %%
df_merged = df_base.merge(df_home, on="ID", how="inner")
print("df_merged:",df_merged.shape)
# Out:
# df_merged: (3035, 24)

# %%
df_merged.sample(3).T
# Out:
#                                                                   708   \
# ID                                                              105466
# Perfil                           /wesley-pacheco/profil/spieler/105466
# Nome                                                    Wesley Pacheco
# Posição                                                 Centre-Forward
# Idade                                                               29
# Valor de Mercado                                              400000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /paysandu-sport-club-pa-/startseite/verein/634...
# Clube Antigo                                                  Paysandu
# URL Liga Antiga      /campeonato-brasileiro-serie-c/transfers/pokal...
# Liga Antiga                                                    Série C
# URL Clube Novo       /gremio-esportivo-brasil-rs-/startseite/verein...
# Clube Novo                                              Brasil Pelotas
# URL Liga Nova        /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Nova                                                      Série B
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2019
# pe                                                               right
# data_nasc                                            Apr 24, 1990 (34)
# local_nasc                                                   São Paulo
# cidadania                                                    1, Brazil
# altura                                                          1,82 m
# convocacoes                                                          0
# gols_selecao                                                         0
#
#                                                                   914   \
# ID                                                              378710
# Perfil                              /richarlison/profil/spieler/378710
# Nome                                                       Richarlison
# Posição                                                 Centre-Forward
# Idade                                                               20
# Valor de Mercado                                             2000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /fluminense-rio-de-janeiro/startseite/verein/2...
# Clube Antigo                                                Fluminense
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /fc-watford/startseite/verein/1010/saison_id/2017
# Clube Novo                                                     Watford
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                         12400000.0
# Ano da Tranferência                                               2017
# pe                                                               right
# data_nasc                                            May 10, 1997 (27)
# local_nasc                                                Nova Venécia
# cidadania                                           2, Brazil, England
# altura                                                          1,84 m
# convocacoes                                                         48
# gols_selecao                                                        20
#
#                                                                   2969
# ID                                                              696655
# Perfil                                     /kibe/profil/spieler/696655
# Nome                                                              Kibe
# Posição                                                 Centre-Forward
# Idade                                                               24
# Valor de Mercado                                              150000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /kf-bylis-ballsh/startseite/verein/21234/saiso...
# Clube Antigo                                                  FK Bylis
# URL Liga Antiga      /kategoria-superiore/transfers/wettbewerb/ALB1...
# Liga Antiga                                        Kategoria Superiore
# URL Clube Novo       /leixoes-sc/startseite/verein/3345/saison_id/2024
# Clube Novo                                                     Leixões
# URL Liga Nova        /liga-portugal-2/transfers/wettbewerb/PO2/sais...
# Liga Nova                                              Liga Portugal 2
# Valor Transferência                                            50000.0
# Ano da Tranferência                                               2024
# pe                                                               right
# data_nasc                                            Mar 13, 2000 (24)
# local_nasc                                              Rio de Janeiro
# cidadania                                          2, Brazil, Portugal
# altura                                                          1,91 m
# convocacoes                                                          0
# gols_selecao                                                         0

# %%
# Cria uma nova coluna em df_stats com ano_stat + 1
df_stats["ano_transferencia"] = df_stats["ano_stat"] + 1

# Faz o merge com base em ID e no ano ajustado
df_final = df_merged.merge(
    df_stats,
    left_on=["ID", "Ano da Tranferência"],
    right_on=["ID", "ano_transferencia"],
    how="left"
)

# Remove a coluna temporária "ano_transferencia" se não for mais necessária
df_final = df_final.drop(columns=["ano_transferencia"])
print("df_final:",df_final.shape)
# Out:
# df_final: (3035, 39)

# %% [markdown]
# # Limpeza e tipagem

# %%
print(df_final.columns)  # Listar todas as colunas para conferir se tudo está certo
# Out:
# Index(['ID', 'Perfil', 'Nome', 'Posição', 'Idade', 'Valor de Mercado',
#        'Nacionalidade', 'URL Clube Antigo', 'Clube Antigo', 'URL Liga Antiga',
#        'Liga Antiga', 'URL Clube Novo', 'Clube Novo', 'URL Liga Nova',
#        'Liga Nova', 'Valor Transferência', 'Ano da Tranferência', 'pe',
#        'data_nasc', 'local_nasc', 'cidadania', 'altura', 'convocacoes',
#        'gols_selecao', 'ano_stat', 'escalado', 'jogou', 'ppm', 'gols_para',
#        'assistencias', 'gols_contra', 'entrou', 'saiu', 'amarelo',
#        'amarelo_duplo', 'vermelho', 'Gols_de_penalti', 'minutos_por_gol',
#        'minutos'],
#       dtype='object')

# %%
print(df_final.sample(1).T)  # Ver uma linha aleatória
# Out:
#                                                                     64
# ID                                                               15094
# Perfil                                    /robert/profil/spieler/15094
# Nome                                                            Robert
# Posição                                                 Centre-Forward
# Idade                                                               35
# Valor de Mercado                                              450000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /esporte-clube-vitoria/startseite/verein/2125/...
# Clube Antigo                                                EC Vitória
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /parana-clube/startseite/verein/309/saison_id/...
# Clube Novo                                                      Paraná
# URL Liga Nova        /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Nova                                                      Série B
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2015
# pe                                                               right
# data_nasc                                            Feb 27, 1981 (43)
# local_nasc                                                    Salvador
# cidadania                                                    1, Brazil
# altura                                                          1,86 m
# convocacoes                                                          4
# gols_selecao                                                         2
# ano_stat                                                          2014
# escalado                                                            35
# jogou                                                               22
# ppm                                                               1.41
# gols_para                                                           12
# assistencias                                                         3
# gols_contra                                                          -
# entrou                                                               8
# saiu                                                                 7
# amarelo                                                              1
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      1
# minutos_por_gol                                                   113'
# minutos                                                         1.351'

# %%
print(df_final.isnull().sum())  # Verificar se há valores NaN após o merg
# Out:
# ID                       0
# Perfil                   0
# Nome                     0
# Posição                  0
# Idade                    0
# Valor de Mercado         0
# Nacionalidade            0
# URL Clube Antigo         0
# Clube Antigo             0
# URL Liga Antiga        464
# Liga Antiga             23
# URL Clube Novo           0
# Clube Novo               0
# URL Liga Nova          423
# Liga Nova                5
# Valor Transferência      0
# Ano da Tranferência      0
# pe                      44
# data_nasc                0
# local_nasc              68
# cidadania                0
# altura                  30
# convocacoes              0
# gols_selecao             0
# ano_stat                 0
# escalado                 0
# jogou                    0
# ppm                     38
# gols_para                0
# assistencias             0
# gols_contra              0
# entrou                   0
# saiu                     0
# amarelo                  0
# amarelo_duplo            0
# vermelho                 0
# Gols_de_penalti          0
# minutos_por_gol          0
# minutos                  0
# dtype: int64

# %%
print(df_final.dtypes)
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado       float64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência    float64
# Ano da Tranferência      int64
# pe                      object
# data_nasc               object
# local_nasc              object
# cidadania               object
# altura                  object
# convocacoes              int64
# gols_selecao             int64
# ano_stat                 int64
# escalado                 int64
# jogou                   object
# ppm                    float64
# gols_para               object
# assistencias            object
# gols_contra             object
# entrou                  object
# saiu                    object
# amarelo                 object
# amarelo_duplo           object
# vermelho                object
# Gols_de_penalti         object
# minutos_por_gol         object
# minutos                 object
# dtype: object

# %%
df_final.head(3).T
# Out:
#                                                                      0  \
# ID                                                              106076
# Perfil                          /ricardo-goulart/profil/spieler/106076
# Nome                                                   Ricardo Goulart
# Posição                                                 Second Striker
# Idade                                                               23
# Valor de Mercado                                            11000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /ec-cruzeiro-belo-horizonte/startseite/verein/...
# Clube Antigo                                                  Cruzeiro
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /guangzhou-fc/startseite/verein/10948/saison_i...
# Clube Novo                                               GZ Evergrande
# URL Liga Nova        /chinese-super-league/transfers/wettbewerb/CSL...
# Liga Nova                                                 Super League
# Valor Transferência                                         15000000.0
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                             Jun 5, 1991 (33)
# local_nasc                                                   São Paulo
# cidadania                                             2, Brazil, China
# altura                                                          1,81 m
# convocacoes                                                          1
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            52
# jogou                                                               50
# ppm                                                                2.0
# gols_para                                                           20
# assistencias                                                         8
# gols_contra                                                          -
# entrou                                                               3
# saiu                                                                21
# amarelo                                                              4
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   199'
# minutos                                                         3.982'
#
#                                                                      1  \
# ID                                                              106076
# Perfil                          /ricardo-goulart/profil/spieler/106076
# Nome                                                   Ricardo Goulart
# Posição                                                 Second Striker
# Idade                                                               30
# Valor de Mercado                                             6000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /guangzhou-fc/startseite/verein/10948/saison_i...
# Clube Antigo                                                   GuaZ FC
# URL Liga Antiga      /chinese-super-league/transfers/wettbewerb/CSL...
# Liga Antiga                                               Super League
# URL Clube Novo         /fc-santos/startseite/verein/221/saison_id/2021
# Clube Novo                                                      Santos
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2021
# pe                                                               right
# data_nasc                                             Jun 5, 1991 (33)
# local_nasc                                                   São Paulo
# cidadania                                             2, Brazil, China
# altura                                                          1,81 m
# convocacoes                                                          1
# gols_selecao                                                         0
# ano_stat                                                          2020
# escalado                                                            14
# jogou                                                               13
# ppm                                                               2.08
# gols_para                                                            7
# assistencias                                                         2
# gols_contra                                                          -
# entrou                                                               4
# saiu                                                                 7
# amarelo                                                              1
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   110'
# minutos                                                           770'
#
#                                                                      2
# ID                                                              106076
# Perfil                          /ricardo-goulart/profil/spieler/106076
# Nome                                                   Ricardo Goulart
# Posição                                                 Second Striker
# Idade                                                               31
# Valor de Mercado                                             5000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo       /fc-santos/startseite/verein/221/saison_id/2022
# Clube Antigo                                                    Santos
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /esporte-clube-bahia/startseite/verein/10010/s...
# Clube Novo                                                    EC Bahia
# URL Liga Nova        /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Nova                                                      Série B
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2022
# pe                                                               right
# data_nasc                                             Jun 5, 1991 (33)
# local_nasc                                                   São Paulo
# cidadania                                             2, Brazil, China
# altura                                                          1,81 m
# convocacoes                                                          1
# gols_selecao                                                         0
# ano_stat                                                          2021
# escalado                                                            50
# jogou                                                               46
# ppm                                                               1.48
# gols_para                                                            6
# assistencias                                                         4
# gols_contra                                                          1
# entrou                                                              12
# saiu                                                                30
# amarelo                                                              4
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   448'
# minutos                                                         2.688'

# %%
#df_final.replace("-", pd.NA, inplace=True)

# %%
df_final["altura"] = df_final["altura"].str.replace(" m", "").str.replace(",", ".").astype(float)

# %%
# Função para converter valores no formato '1.025'
def convert_minutes(val):
    if isinstance(val, str) and val.endswith("'"):
        # Remover o apóstrofo e multiplicar por 1000
        return int(float(val.replace("'", "")) * 1000)
    return val  # Se não for uma string no formato, retorna o valor original

# Aplicando a função nas colunas 'minutos' e 'minutos_por_gol'
df_final['minutos_por_gol'] = df_final['minutos_por_gol'].apply(convert_minutes)
df_final['minutos'] = df_final['minutos'].apply(convert_minutes)

# %%
df_final["Valor de Mercado"] = df_final["Valor de Mercado"].astype("int64")
df_final["Valor Transferência"] = df_final["Valor Transferência"].astype("int64")

# %%
df_final.dtypes
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado         int64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência      int64
# Ano da Tranferência      int64
# pe                      object
# data_nasc               object
# local_nasc              object
# cidadania               object
# altura                 float64
# convocacoes              int64
# gols_selecao             int64
# ano_stat                 int64
# escalado                 int64
# jogou                   object
# ppm                    float64
# gols_para               object
# assistencias            object
# gols_contra             object
# entrou                  object
# saiu                    object
# amarelo                 object
# amarelo_duplo           object
# vermelho                object
# Gols_de_penalti         object
# minutos_por_gol         object
# minutos                 object
# dtype: object

# %%
df_final.head(10).T
# Out:
#                                                                      0  \
# ID                                                              106076
# Perfil                          /ricardo-goulart/profil/spieler/106076
# Nome                                                   Ricardo Goulart
# Posição                                                 Second Striker
# Idade                                                               23
# Valor de Mercado                                              11000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /ec-cruzeiro-belo-horizonte/startseite/verein/...
# Clube Antigo                                                  Cruzeiro
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /guangzhou-fc/startseite/verein/10948/saison_i...
# Clube Novo                                               GZ Evergrande
# URL Liga Nova        /chinese-super-league/transfers/wettbewerb/CSL...
# Liga Nova                                                 Super League
# Valor Transferência                                           15000000
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                             Jun 5, 1991 (33)
# local_nasc                                                   São Paulo
# cidadania                                             2, Brazil, China
# altura                                                            1.81
# convocacoes                                                          1
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            52
# jogou                                                               50
# ppm                                                                2.0
# gols_para                                                           20
# assistencias                                                         8
# gols_contra                                                          -
# entrou                                                               3
# saiu                                                                21
# amarelo                                                              4
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                 199000
# minutos                                                           3982
#
#                                                                      1  \
# ID                                                              106076
# Perfil                          /ricardo-goulart/profil/spieler/106076
# Nome                                                   Ricardo Goulart
# Posição                                                 Second Striker
# Idade                                                               30
# Valor de Mercado                                               6000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /guangzhou-fc/startseite/verein/10948/saison_i...
# Clube Antigo                                                   GuaZ FC
# URL Liga Antiga      /chinese-super-league/transfers/wettbewerb/CSL...
# Liga Antiga                                               Super League
# URL Clube Novo         /fc-santos/startseite/verein/221/saison_id/2021
# Clube Novo                                                      Santos
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                                  0
# Ano da Tranferência                                               2021
# pe                                                               right
# data_nasc                                             Jun 5, 1991 (33)
# local_nasc                                                   São Paulo
# cidadania                                             2, Brazil, China
# altura                                                            1.81
# convocacoes                                                          1
# gols_selecao                                                         0
# ano_stat                                                          2020
# escalado                                                            14
# jogou                                                               13
# ppm                                                               2.08
# gols_para                                                            7
# assistencias                                                         2
# gols_contra                                                          -
# entrou                                                               4
# saiu                                                                 7
# amarelo                                                              1
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                 110000
# minutos                                                         770000
#
#                                                                      2  \
# ID                                                              106076
# Perfil                          /ricardo-goulart/profil/spieler/106076
# Nome                                                   Ricardo Goulart
# Posição                                                 Second Striker
# Idade                                                               31
# Valor de Mercado                                               5000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo       /fc-santos/startseite/verein/221/saison_id/2022
# Clube Antigo                                                    Santos
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /esporte-clube-bahia/startseite/verein/10010/s...
# Clube Novo                                                    EC Bahia
# URL Liga Nova        /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Nova                                                      Série B
# Valor Transferência                                                  0
# Ano da Tranferência                                               2022
# pe                                                               right
# data_nasc                                             Jun 5, 1991 (33)
# local_nasc                                                   São Paulo
# cidadania                                             2, Brazil, China
# altura                                                            1.81
# convocacoes                                                          1
# gols_selecao                                                         0
# ano_stat                                                          2021
# escalado                                                            50
# jogou                                                               46
# ppm                                                               1.48
# gols_para                                                            6
# assistencias                                                         4
# gols_contra                                                          1
# entrou                                                              12
# saiu                                                                30
# amarelo                                                              4
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                 448000
# minutos                                                           2688
#
#                                                                      3  \
# ID                                                               29424
# Perfil                                  /paulinho/profil/spieler/29424
# Nome                                                          Paulinho
# Posição                                                 Centre-Forward
# Idade                                                               28
# Valor de Mercado                                               8500000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /as-livorno/startseite/verein/1210/saison_id/2014
# Clube Antigo                                                AS Livorno
# URL Liga Antiga       /serie-b/transfers/wettbewerb/IT2/saison_id/2014
# Liga Antiga                                                    Serie B
# URL Clube Novo       /al-arabi-sc/startseite/verein/1230/saison_id/...
# Clube Novo                                                 Al-Arabi SC
# URL Liga Nova        /qatar-stars-league/transfers/wettbewerb/QSL/s...
# Liga Nova                                                 Stars League
# Valor Transferência                                            8000000
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Jan 10, 1986 (39)
# local_nasc                                               Caxias do Sul
# cidadania                                             2, Brazil, Italy
# altura                                                            1.76
# convocacoes                                                         12
# gols_selecao                                                         4
# ano_stat                                                          2013
# escalado                                                            37
# jogou                                                               36
# ppm                                                               0.69
# gols_para                                                           15
# assistencias                                                         4
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 2
# amarelo                                                              8
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      3
# minutos_por_gol                                                 216000
# minutos                                                           3234
#
#                                                                      4  \
# ID                                                               29424
# Perfil                                  /paulinho/profil/spieler/29424
# Nome                                                          Paulinho
# Posição                                                 Centre-Forward
# Idade                                                               31
# Valor de Mercado                                               2500000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /al-arabi-sc/startseite/verein/1230/saison_id/...
# Clube Antigo                                               Al-Arabi SC
# URL Liga Antiga      /qatar-stars-league/transfers/wettbewerb/QSL/s...
# Liga Antiga                                               Stars League
# URL Clube Novo       /us-cremonese/startseite/verein/2239/saison_id...
# Clube Novo                                                   Cremonese
# URL Liga Nova         /serie-b/transfers/wettbewerb/IT2/saison_id/2017
# Liga Nova                                                      Serie B
# Valor Transferência                                                  0
# Ano da Tranferência                                               2017
# pe                                                               right
# data_nasc                                            Jan 10, 1986 (39)
# local_nasc                                               Caxias do Sul
# cidadania                                             2, Brazil, Italy
# altura                                                            1.76
# convocacoes                                                         12
# gols_selecao                                                         4
# ano_stat                                                          2016
# escalado                                                            14
# jogou                                                               14
# ppm                                                               0.79
# gols_para                                                            1
# assistencias                                                         1
# gols_contra                                                          -
# entrou                                                               2
# saiu                                                                 7
# amarelo                                                              2
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      1
# minutos_por_gol                                                 962000
# minutos                                                         962000
#
#                                                                      5  \
# ID                                                              193925
# Perfil                                /romarinho/profil/spieler/193925
# Nome                                                         Romarinho
# Posição                                                 Centre-Forward
# Idade                                                               23
# Valor de Mercado                                               2000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /corinthians-sao-paulo/startseite/verein/199/s...
# Clube Antigo                                               Corinthians
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo       /el-jaish-sports-club/startseite/verein/33288/...
# Clube Novo                                                    El-Jaish
# URL Liga Nova        /qatar-stars-league/transfers/wettbewerb/QSL/s...
# Liga Nova                                                 Stars League
# Valor Transferência                                            7500000
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Dec 12, 1990 (34)
# local_nasc                                                   Palestina
# cidadania                                      2, Brazil, Saudi Arabia
# altura                                                            1.76
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            39
# jogou                                                               37
# ppm                                                               1.76
# gols_para                                                           12
# assistencias                                                         1
# gols_contra                                                          -
# entrou                                                              12
# saiu                                                                16
# amarelo                                                              2
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                 193000
# minutos                                                           2315
#
#                                                                      6  \
# ID                                                              193925
# Perfil                                /romarinho/profil/spieler/193925
# Nome                                                         Romarinho
# Posição                                                 Centre-Forward
# Idade                                                               26
# Valor de Mercado                                               4000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /el-jaish-sports-club/startseite/verein/33288/...
# Clube Antigo                                                  El-Jaish
# URL Liga Antiga                                                    NaN
# Liga Antiga                                                      Qatar
# URL Clube Novo       /al-jazira-abu-dhabi-/startseite/verein/2524/s...
# Clube Novo                                                   Al-Jazira
# URL Liga Nova        /uae-arabian-gulf-league/transfers/wettbewerb/...
# Liga Nova                                               UAE Pro League
# Valor Transferência                                                  0
# Ano da Tranferência                                               2017
# pe                                                               right
# data_nasc                                            Dec 12, 1990 (34)
# local_nasc                                                   Palestina
# cidadania                                      2, Brazil, Saudi Arabia
# altura                                                            1.76
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2016
# escalado                                                            25
# jogou                                                               25
# ppm                                                               1.76
# gols_para                                                           14
# assistencias                                                         2
# gols_contra                                                          -
# entrou                                                               2
# saiu                                                                 4
# amarelo                                                              1
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      4
# minutos_por_gol                                                 146000
# minutos                                                           2044
#
#                                                                      7  \
# ID                                                              193925
# Perfil                                /romarinho/profil/spieler/193925
# Nome                                                         Romarinho
# Posição                                                 Centre-Forward
# Idade                                                               27
# Valor de Mercado                                               4000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /al-jazira-abu-dhabi-/startseite/verein/2524/s...
# Clube Antigo                                                 Al-Jazira
# URL Liga Antiga      /uae-arabian-gulf-league/transfers/wettbewerb/...
# Liga Antiga                                             UAE Pro League
# URL Clube Novo       /al-ittihad-dschidda/startseite/verein/8023/sa...
# Clube Novo                                                  Al-Ittihad
# URL Liga Nova        /saudi-professional-league/transfers/wettbewer...
# Liga Nova                                             Saudi Pro League
# Valor Transferência                                            7000000
# Ano da Tranferência                                               2018
# pe                                                               right
# data_nasc                                            Dec 12, 1990 (34)
# local_nasc                                                   Palestina
# cidadania                                      2, Brazil, Saudi Arabia
# altura                                                            1.76
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2017
# escalado                                                            33
# jogou                                                               32
# ppm                                                               1.31
# gols_para                                                           15
# assistencias                                                         9
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 4
# amarelo                                                              3
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                 188000
# minutos                                                           2816
#
#                                                                      8  \
# ID                                                              193925
# Perfil                                /romarinho/profil/spieler/193925
# Nome                                                         Romarinho
# Posição                                                 Centre-Forward
# Idade                                                               33
# Valor de Mercado                                               2500000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /al-ittihad-dschidda/startseite/verein/8023/sa...
# Clube Antigo                                                Al-Ittihad
# URL Liga Antiga      /saudi-professional-league/transfers/wettbewer...
# Liga Antiga                                           Saudi Pro League
# URL Clube Novo       /al-suqoor/startseite/verein/34911/saison_id/2024
# Clube Novo                                                     NEOM SC
# URL Liga Nova        /yelo-league/transfers/wettbewerb/SA2L/saison_...
# Liga Nova                                  Saudi First Division League
# Valor Transferência                                                  0
# Ano da Tranferência                                               2024
# pe                                                               right
# data_nasc                                            Dec 12, 1990 (34)
# local_nasc                                                   Palestina
# cidadania                                      2, Brazil, Saudi Arabia
# altura                                                            1.76
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2023
# escalado                                                            43
# jogou                                                               42
# ppm                                                               1.57
# gols_para                                                            8
# assistencias                                                         5
# gols_contra                                                          -
# entrou                                                               3
# saiu                                                                25
# amarelo                                                              4
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      1
# minutos_por_gol                                                 405000
# minutos                                                           3241
#
#                                                                      9
# ID                                                               74249
# Perfil                                   /muriqui/profil/spieler/74249
# Nome                                                           Muriqui
# Posição                                                    Left Winger
# Idade                                                               28
# Valor de Mercado                                               3500000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /guangzhou-fc/startseite/verein/10948/saison_i...
# Clube Antigo                                             GZ Evergrande
# URL Liga Antiga      /chinese-super-league/transfers/wettbewerb/CSL...
# Liga Antiga                                               Super League
# URL Clube Novo        /al-sadd-sc/startseite/verein/656/saison_id/2014
# Clube Novo                                                  Al-Sadd SC
# URL Liga Nova        /qatar-stars-league/transfers/wettbewerb/QSL/s...
# Liga Nova                                                 Stars League
# Valor Transferência                                            5900000
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Jun 16, 1986 (38)
# local_nasc                                                      Itaguá
# cidadania                                                    1, Brazil
# altura                                                            1.74
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            18
# jogou                                                               18
# ppm                                                               1.61
# gols_para                                                            5
# assistencias                                                         8
# gols_contra                                                          -
# entrou                                                               2
# saiu                                                                11
# amarelo                                                              2
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                 251000
# minutos                                                           1255

# %%
# Substituir '-' por NaN
cols_to_clean = [
    "jogou", "gols_para", "assistencias", "gols_contra", 
    "entrou", "saiu", "amarelo", "amarelo_duplo", 
    "vermelho", "Gols_de_penalti", "minutos_por_gol", "minutos"
]

df_final[cols_to_clean] = df_final[cols_to_clean].replace('-', pd.NA)
# Convertemos para inteiros, substituindo NaN por 0 (se necessário)
#df_final[cols_to_clean] = df_final[cols_to_clean].fillna(0).astype("int64")

# %%
df_final.shape
# Out:
# (3035, 39)

# %%
num_duplicatas = df_final.duplicated().sum()
print(f"Número de linhas duplicadas: {num_duplicatas}")
# Out:
# Número de linhas duplicadas: 384

# %%
df_final['minutos_por_gol'] = df_final['minutos_por_gol'].apply(lambda x: str(x)[:-3] if str(x).endswith('000') else x)
df_final['minutos'] = df_final['minutos'].apply(lambda x: str(x)[:-3] if str(x).endswith('000') else x)

# %%
df_final=df_final.drop_duplicates()
df_final.to_csv('04-FW.csv', index=True)

# %%
df_final.shape
# Out:
# (2651, 39)
