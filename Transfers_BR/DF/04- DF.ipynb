# %% [markdown]
# # Import/load

# %%
import pandas as pd
import numpy as np

# %%
df_base = pd.read_csv('02-DF.csv')
df_home = pd.read_csv('03-DF-home.csv')
df_stats = pd.read_csv('03-DF-stats.csv')

# %% [markdown]
# # head

# %%
df_base.head(3).T
# Out:
#                                                                      0  \
# ID                                                               46741
# Perfil                                /david-luiz/profil/spieler/46741
# Nome                                                        David Luiz
# Posição                                                    Centre-Back
# Idade                                                               27
# Valor de Mercado                                            26000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo      /fc-chelsea/startseite/verein/631/saison_id/2014
# Clube Antigo                                                   Chelsea
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /fc-paris-saint-germain/startseite/verein/583/...
# Clube Novo                                                    Paris SG
# URL Liga Nova         /ligue-1/transfers/wettbewerb/FR1/saison_id/2014
# Liga Nova                                                      Ligue 1
# Valor Transferência                                         49500000.0
# Ano da Tranferência                                               2014
#
#                                                                      1  \
# ID                                                               21725
# Perfil                               /filipe-luis/profil/spieler/21725
# Nome                                                       Filipe Luís
# Posição                                                      Left-Back
# Idade                                                               28
# Valor de Mercado                                            15000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /atletico-madrid/startseite/verein/13/saison_i...
# Clube Antigo                                           Atlético Madrid
# URL Liga Antiga        /laliga/transfers/wettbewerb/ES1/saison_id/2014
# Liga Antiga                                                     LaLiga
# URL Clube Novo        /fc-chelsea/startseite/verein/631/saison_id/2014
# Clube Novo                                                     Chelsea
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                         20000000.0
# Ano da Tranferência                                               2014
#
#                                                                      2
# ID                                                              149498
# Perfil                         /gabriel-paulista/profil/spieler/149498
# Nome                                                  Gabriel Paulista
# Posição                                                    Centre-Back
# Idade                                                               24
# Valor de Mercado                                             8000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /fc-villarreal/startseite/verein/1050/saison_i...
# Clube Antigo                                                Villarreal
# URL Liga Antiga        /laliga/transfers/wettbewerb/ES1/saison_id/2014
# Liga Antiga                                                     LaLiga
# URL Clube Novo         /fc-arsenal/startseite/verein/11/saison_id/2014
# Clube Novo                                                     Arsenal
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                         15000000.0
# Ano da Tranferência                                               2014

# %%
df_home.head(3).T
# Out:
#                                 0                  1  \
# Unnamed: 0                      0                  1
# ID                          46741              21725
# nome_hifen             David-Luiz        Filipe-Luis
# pe                          right               left
# data_nasc       Apr 22, 1987 (37)   Aug 9, 1985 (39)
# local_nasc                Diadema     Jaraguá do Sul
# cidadania     2, Brazil, Portugal  2, Brazil, Poland
# altura                     1,89 m             1,82 m
# convocacoes                    57                 44
# gols_selecao                    3                  2
#
#                                       2
# Unnamed: 0                            2
# ID                               149498
# nome_hifen             Gabriel-Paulista
# pe                                right
# data_nasc             Nov 26, 1990 (34)
# local_nasc                    São Paulo
# cidadania     3, Brazil, Spain, Türkiye
# altura                           1,85 m
# convocacoes                           0
# gols_selecao                          0

# %%
df_stats.head(3).T
# Out:
#                       0       1       2
# Unnamed: 0            0       1       2
# ID                46741   21725  149498
# ano_stat           2013    2013    2013
# escalado             42      50      32
# jogou                34      49      21
# ppm                1.91    2.35    1.48
# gols_para             -       1       -
# assistencias          3       6       -
# gols_contra           1       1       1
# entrou                5       -       1
# saiu                  2       3       -
# amarelo              11       7       4
# amarelo_duplo         -       1       1
# vermelho              -       1       -
# Gols_de_penalti       -       -       -
# minutos_por_gol       -  4.273'       -
# minutos          2.684'  4.273'  1.789'

# %% [markdown]
# # Checagem de tipo

# %%
print("df_base:",df_base.shape)
print("df_home:",df_home.shape)
print("df_stats:",df_stats.shape)
# Out:
# df_base: (2068, 17)
# df_home: (836, 10)
# df_stats: (1711, 17)

# %%
df_base.dtypes
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado       float64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência    float64
# Ano da Tranferência      int64
# dtype: object

# %%
df_home.dtypes
# Out:
# Unnamed: 0       int64
# ID               int64
# nome_hifen      object
# pe              object
# data_nasc       object
# local_nasc      object
# cidadania       object
# altura          object
# convocacoes      int64
# gols_selecao     int64
# dtype: object

# %%
df_stats.dtypes
# Out:
# Unnamed: 0           int64
# ID                   int64
# ano_stat             int64
# escalado             int64
# jogou               object
# ppm                float64
# gols_para           object
# assistencias        object
# gols_contra         object
# entrou              object
# saiu                object
# amarelo             object
# amarelo_duplo       object
# vermelho            object
# Gols_de_penalti     object
# minutos_por_gol     object
# minutos             object
# dtype: object

# %% [markdown]
# # Descarte de colunas

# %%
df_home = df_home.drop(columns=["Unnamed: 0"])
df_home = df_home.drop(columns=["nome_hifen"])


df_stats = df_stats.drop(columns=["Unnamed: 0"])

# %% [markdown]
# # Merges

# %%
df_merged = df_base.merge(df_home, on="ID", how="inner")
print("df_merged:",df_merged.shape)
# Out:
# df_merged: (2068, 24)

# %%
df_merged.sample(3).T
# Out:
#                                                                   1927  \
# ID                                                              552236
# Perfil                               /leo-santos/profil/spieler/552236
# Nome                                                        Léo Santos
# Posição                                                    Centre-Back
# Idade                                                               28
# Valor de Mercado                                              350000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /ituano-futebol-clube-sp-/startseite/verein/47...
# Clube Antigo                                                    Ituano
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo       /nongbua-pitchaya-fc/startseite/verein/55226/s...
# Clube Novo                                                  Nongbua FC
# URL Liga Nova        /thai-league/transfers/wettbewerb/THA1/saison_...
# Liga Nova                                                  Thai League
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2022
# pe                                                               right
# data_nasc                                             Jun 3, 1994 (30)
# local_nasc                                                         Itu
# cidadania                                                    1, Brazil
# altura                                                          1,97 m
# convocacoes                                                          0
# gols_selecao                                                         0
#
#                                                                   1011  \
# ID                                                              341710
# Perfil                                  /william/profil/spieler/341710
# Nome                                                           William
# Posição                                                     Right-Back
# Idade                                                               22
# Valor de Mercado                                             2750000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /sc-internacional-porto-alegre/startseite/vere...
# Clube Antigo                                             Internacional
# URL Liga Antiga      /campeonato-brasileiro-serie-b/transfers/wettb...
# Liga Antiga                                                    Série B
# URL Clube Novo       /vfl-wolfsburg/startseite/verein/82/saison_id/...
# Clube Novo                                               VfL Wolfsburg
# URL Liga Nova        /bundesliga/transfers/wettbewerb/L1/saison_id/...
# Liga Nova                                                   Bundesliga
# Valor Transferência                                          5000000.0
# Ano da Tranferência                                               2017
# pe                                                               right
# data_nasc                                             Apr 3, 1995 (29)
# local_nasc                                                     Pelotas
# cidadania                                                    1, Brazil
# altura                                                          1,71 m
# convocacoes                                                          0
# gols_selecao                                                         0
#
#                                                                   590
# ID                                                              193135
# Perfil                                  /jackson/profil/spieler/193135
# Nome                                                           Jackson
# Posição                                                    Centre-Back
# Idade                                                               31
# Valor de Mercado                                              500000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /fortaleza-esporte-clube/startseite/verein/108...
# Clube Antigo                                                 Fortaleza
# URL Liga Antiga      /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Antiga                                                    Série A
# URL Clube Novo        /sabah-fc/startseite/verein/15630/saison_id/2021
# Clube Novo                                                       Sabah
# URL Liga Nova        /malaysia-super-league/transfers/wettbewerb/MY...
# Liga Nova                                                 Super League
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2021
# pe                                                               right
# data_nasc                                             May 1, 1990 (34)
# local_nasc                                                      Cuiabá
# cidadania                                                    1, Brazil
# altura                                                          1,86 m
# convocacoes                                                          0
# gols_selecao                                                         0

# %%
# Cria uma nova coluna em df_stats com ano_stat + 1
df_stats["ano_transferencia"] = df_stats["ano_stat"] + 1

# Faz o merge com base em ID e no ano ajustado
df_final = df_merged.merge(
    df_stats,
    left_on=["ID", "Ano da Tranferência"],
    right_on=["ID", "ano_transferencia"],
    how="left"
)

# Remove a coluna temporária "ano_transferencia" se não for mais necessária
df_final = df_final.drop(columns=["ano_transferencia"])
print("df_final:",df_final.shape)
# Out:
# df_final: (2068, 39)

# %% [markdown]
# # Limpeza e tipagem

# %%
print(df_final.columns)  # Listar todas as colunas para conferir se tudo está certo
# Out:
# Index(['ID', 'Perfil', 'Nome', 'Posição', 'Idade', 'Valor de Mercado',
#        'Nacionalidade', 'URL Clube Antigo', 'Clube Antigo', 'URL Liga Antiga',
#        'Liga Antiga', 'URL Clube Novo', 'Clube Novo', 'URL Liga Nova',
#        'Liga Nova', 'Valor Transferência', 'Ano da Tranferência', 'pe',
#        'data_nasc', 'local_nasc', 'cidadania', 'altura', 'convocacoes',
#        'gols_selecao', 'ano_stat', 'escalado', 'jogou', 'ppm', 'gols_para',
#        'assistencias', 'gols_contra', 'entrou', 'saiu', 'amarelo',
#        'amarelo_duplo', 'vermelho', 'Gols_de_penalti', 'minutos_por_gol',
#        'minutos'],
#       dtype='object')

# %%
print(df_final.sample(1).T)  # Ver uma linha aleatória
# Out:
#                                                                   1146
# ID                                                              116084
# Perfil                                  /juninho/profil/spieler/116084
# Nome                                                           Juninho
# Posição                                                      Left-Back
# Idade                                                               27
# Valor de Mercado                                             1300000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /fk-aktobe/startseite/verein/10157/saison_id/2017
# Clube Antigo                                                    Aktobe
# URL Liga Antiga      /premier-liga/transfers/wettbewerb/KAS1/saison...
# Liga Antiga                                               Premier Liga
# URL Clube Novo       /esporte-clube-vitoria/startseite/verein/2125/...
# Clube Novo                                                  EC Vitória
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                                0.0
# Ano da Tranferência                                               2017
# pe                                                                left
# data_nasc                                            Jan 11, 1990 (35)
# local_nasc                                                    Salvador
# cidadania                                                    1, Brazil
# altura                                                          1,71 m
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2016
# escalado                                                            31
# jogou                                                               31
# ppm                                                               1.03
# gols_para                                                            1
# assistencias                                                         3
# gols_contra                                                          -
# entrou                                                               -
# saiu                                                                 3
# amarelo                                                              3
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                 2.782'
# minutos                                                         2.782'

# %%
print(df_final.isnull().sum())  # Verificar se há valores NaN após o merg
# Out:
# ID                       0
# Perfil                   0
# Nome                     0
# Posição                  0
# Idade                    0
# Valor de Mercado         0
# Nacionalidade            0
# URL Clube Antigo         0
# Clube Antigo             0
# URL Liga Antiga        277
# Liga Antiga             16
# URL Clube Novo           0
# Clube Novo               0
# URL Liga Nova          201
# Liga Nova                7
# Valor Transferência      0
# Ano da Tranferência      0
# pe                      22
# data_nasc                0
# local_nasc              25
# cidadania                0
# altura                  14
# convocacoes              0
# gols_selecao             0
# ano_stat                 0
# escalado                 0
# jogou                    0
# ppm                     53
# gols_para                0
# assistencias             0
# gols_contra              0
# entrou                   0
# saiu                     0
# amarelo                  0
# amarelo_duplo            0
# vermelho                 0
# Gols_de_penalti          0
# minutos_por_gol          0
# minutos                  0
# dtype: int64

# %%
print(df_final.dtypes)
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado       float64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência    float64
# Ano da Tranferência      int64
# pe                      object
# data_nasc               object
# local_nasc              object
# cidadania               object
# altura                  object
# convocacoes              int64
# gols_selecao             int64
# ano_stat                 int64
# escalado                 int64
# jogou                   object
# ppm                    float64
# gols_para               object
# assistencias            object
# gols_contra             object
# entrou                  object
# saiu                    object
# amarelo                 object
# amarelo_duplo           object
# vermelho                object
# Gols_de_penalti         object
# minutos_por_gol         object
# minutos                 object
# dtype: object

# %%
df_final.head(3).T
# Out:
#                                                                      0  \
# ID                                                               46741
# Perfil                                /david-luiz/profil/spieler/46741
# Nome                                                        David Luiz
# Posição                                                    Centre-Back
# Idade                                                               27
# Valor de Mercado                                            26000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo      /fc-chelsea/startseite/verein/631/saison_id/2014
# Clube Antigo                                                   Chelsea
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /fc-paris-saint-germain/startseite/verein/583/...
# Clube Novo                                                    Paris SG
# URL Liga Nova         /ligue-1/transfers/wettbewerb/FR1/saison_id/2014
# Liga Nova                                                      Ligue 1
# Valor Transferência                                         49500000.0
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Apr 22, 1987 (37)
# local_nasc                                                     Diadema
# cidadania                                          2, Brazil, Portugal
# altura                                                          1,89 m
# convocacoes                                                         57
# gols_selecao                                                         3
# ano_stat                                                          2013
# escalado                                                            42
# jogou                                                               34
# ppm                                                               1.91
# gols_para                                                            -
# assistencias                                                         3
# gols_contra                                                          1
# entrou                                                               5
# saiu                                                                 2
# amarelo                                                             11
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                      -
# minutos                                                         2.684'
#
#                                                                      1  \
# ID                                                               46741
# Perfil                                /david-luiz/profil/spieler/46741
# Nome                                                        David Luiz
# Posição                                                    Centre-Back
# Idade                                                               29
# Valor de Mercado                                            28000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /fc-paris-saint-germain/startseite/verein/583/...
# Clube Antigo                                                  Paris SG
# URL Liga Antiga       /ligue-1/transfers/wettbewerb/FR1/saison_id/2016
# Liga Antiga                                                    Ligue 1
# URL Clube Novo        /fc-chelsea/startseite/verein/631/saison_id/2016
# Clube Novo                                                     Chelsea
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                         35000000.0
# Ano da Tranferência                                               2016
# pe                                                               right
# data_nasc                                            Apr 22, 1987 (37)
# local_nasc                                                     Diadema
# cidadania                                          2, Brazil, Portugal
# altura                                                          1,89 m
# convocacoes                                                         57
# gols_selecao                                                         3
# ano_stat                                                          2015
# escalado                                                            45
# jogou                                                               40
# ppm                                                               2.58
# gols_para                                                            3
# assistencias                                                         3
# gols_contra                                                          -
# entrou                                                               5
# saiu                                                                 1
# amarelo                                                             12
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                 1.069'
# minutos                                                         3.208'
#
#                                                                      2
# ID                                                               46741
# Perfil                                /david-luiz/profil/spieler/46741
# Nome                                                        David Luiz
# Posição                                                    Centre-Back
# Idade                                                               32
# Valor de Mercado                                            20000000.0
# Nacionalidade                                                   Brazil
# URL Clube Antigo      /fc-chelsea/startseite/verein/631/saison_id/2019
# Clube Antigo                                                   Chelsea
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo         /fc-arsenal/startseite/verein/11/saison_id/2019
# Clube Novo                                                     Arsenal
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                          8700000.0
# Ano da Tranferência                                               2019
# pe                                                               right
# data_nasc                                            Apr 22, 1987 (37)
# local_nasc                                                     Diadema
# cidadania                                          2, Brazil, Portugal
# altura                                                          1,89 m
# convocacoes                                                         57
# gols_selecao                                                         3
# ano_stat                                                          2018
# escalado                                                            58
# jogou                                                               50
# ppm                                                                2.0
# gols_para                                                            3
# assistencias                                                         2
# gols_contra                                                          -
# entrou                                                               3
# saiu                                                                 1
# amarelo                                                              5
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                 1.446'
# minutos                                                         4.339'

# %%
#df_final.replace("-", pd.NA, inplace=True)

# %%
df_final["altura"] = df_final["altura"].str.replace(" m", "").str.replace(",", ".").astype(float)

# %%
# Função para converter valores no formato '1.025'
def convert_minutes(val):
    if isinstance(val, str) and val.endswith("'"):
        # Remover o apóstrofo e multiplicar por 1000
        return int(float(val.replace("'", "")) * 1000)
    return val  # Se não for uma string no formato, retorna o valor original

# Aplicando a função nas colunas 'minutos' e 'minutos_por_gol'
df_final['minutos_por_gol'] = df_final['minutos_por_gol'].apply(convert_minutes)
df_final['minutos'] = df_final['minutos'].apply(convert_minutes)

# %%
df_final["Valor de Mercado"] = df_final["Valor de Mercado"].astype("int64")
df_final["Valor Transferência"] = df_final["Valor Transferência"].astype("int64")

# %%
df_final.dtypes
# Out:
# ID                       int64
# Perfil                  object
# Nome                    object
# Posição                 object
# Idade                    int64
# Valor de Mercado         int64
# Nacionalidade           object
# URL Clube Antigo        object
# Clube Antigo            object
# URL Liga Antiga         object
# Liga Antiga             object
# URL Clube Novo          object
# Clube Novo              object
# URL Liga Nova           object
# Liga Nova               object
# Valor Transferência      int64
# Ano da Tranferência      int64
# pe                      object
# data_nasc               object
# local_nasc              object
# cidadania               object
# altura                 float64
# convocacoes              int64
# gols_selecao             int64
# ano_stat                 int64
# escalado                 int64
# jogou                   object
# ppm                    float64
# gols_para               object
# assistencias            object
# gols_contra             object
# entrou                  object
# saiu                    object
# amarelo                 object
# amarelo_duplo           object
# vermelho                object
# Gols_de_penalti         object
# minutos_por_gol         object
# minutos                 object
# dtype: object

# %%
df_final.head(10).T
# Out:
#                                                                      0  \
# ID                                                               46741
# Perfil                                /david-luiz/profil/spieler/46741
# Nome                                                        David Luiz
# Posição                                                    Centre-Back
# Idade                                                               27
# Valor de Mercado                                              26000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo      /fc-chelsea/startseite/verein/631/saison_id/2014
# Clube Antigo                                                   Chelsea
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /fc-paris-saint-germain/startseite/verein/583/...
# Clube Novo                                                    Paris SG
# URL Liga Nova         /ligue-1/transfers/wettbewerb/FR1/saison_id/2014
# Liga Nova                                                      Ligue 1
# Valor Transferência                                           49500000
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Apr 22, 1987 (37)
# local_nasc                                                     Diadema
# cidadania                                          2, Brazil, Portugal
# altura                                                            1.89
# convocacoes                                                         57
# gols_selecao                                                         3
# ano_stat                                                          2013
# escalado                                                            42
# jogou                                                               34
# ppm                                                               1.91
# gols_para                                                            -
# assistencias                                                         3
# gols_contra                                                          1
# entrou                                                               5
# saiu                                                                 2
# amarelo                                                             11
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                      -
# minutos                                                           2684
#
#                                                                      1  \
# ID                                                               46741
# Perfil                                /david-luiz/profil/spieler/46741
# Nome                                                        David Luiz
# Posição                                                    Centre-Back
# Idade                                                               29
# Valor de Mercado                                              28000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /fc-paris-saint-germain/startseite/verein/583/...
# Clube Antigo                                                  Paris SG
# URL Liga Antiga       /ligue-1/transfers/wettbewerb/FR1/saison_id/2016
# Liga Antiga                                                    Ligue 1
# URL Clube Novo        /fc-chelsea/startseite/verein/631/saison_id/2016
# Clube Novo                                                     Chelsea
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                           35000000
# Ano da Tranferência                                               2016
# pe                                                               right
# data_nasc                                            Apr 22, 1987 (37)
# local_nasc                                                     Diadema
# cidadania                                          2, Brazil, Portugal
# altura                                                            1.89
# convocacoes                                                         57
# gols_selecao                                                         3
# ano_stat                                                          2015
# escalado                                                            45
# jogou                                                               40
# ppm                                                               2.58
# gols_para                                                            3
# assistencias                                                         3
# gols_contra                                                          -
# entrou                                                               5
# saiu                                                                 1
# amarelo                                                             12
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   1069
# minutos                                                           3208
#
#                                                                      2  \
# ID                                                               46741
# Perfil                                /david-luiz/profil/spieler/46741
# Nome                                                        David Luiz
# Posição                                                    Centre-Back
# Idade                                                               32
# Valor de Mercado                                              20000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo      /fc-chelsea/startseite/verein/631/saison_id/2019
# Clube Antigo                                                   Chelsea
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo         /fc-arsenal/startseite/verein/11/saison_id/2019
# Clube Novo                                                     Arsenal
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                            8700000
# Ano da Tranferência                                               2019
# pe                                                               right
# data_nasc                                            Apr 22, 1987 (37)
# local_nasc                                                     Diadema
# cidadania                                          2, Brazil, Portugal
# altura                                                            1.89
# convocacoes                                                         57
# gols_selecao                                                         3
# ano_stat                                                          2018
# escalado                                                            58
# jogou                                                               50
# ppm                                                                2.0
# gols_para                                                            3
# assistencias                                                         2
# gols_contra                                                          -
# entrou                                                               3
# saiu                                                                 1
# amarelo                                                              5
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   1446
# minutos                                                           4339
#
#                                                                      3  \
# ID                                                               46741
# Perfil                                /david-luiz/profil/spieler/46741
# Nome                                                        David Luiz
# Posição                                                    Centre-Back
# Idade                                                               34
# Valor de Mercado                                               4000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo       /fc-arsenal/startseite/verein/11/saison_id/2021
# Clube Antigo                                                   Arsenal
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /flamengo-rio-de-janeiro/startseite/verein/614...
# Clube Novo                                                    Flamengo
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                                  0
# Ano da Tranferência                                               2021
# pe                                                               right
# data_nasc                                            Apr 22, 1987 (37)
# local_nasc                                                     Diadema
# cidadania                                          2, Brazil, Portugal
# altura                                                            1.89
# convocacoes                                                         57
# gols_selecao                                                         3
# ano_stat                                                          2020
# escalado                                                            45
# jogou                                                               40
# ppm                                                                1.9
# gols_para                                                            2
# assistencias                                                         -
# gols_contra                                                          -
# entrou                                                               3
# saiu                                                                 9
# amarelo                                                              2
# amarelo_duplo                                                        -
# vermelho                                                             1
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   1493
# minutos                                                           2985
#
#                                                                      4  \
# ID                                                               21725
# Perfil                               /filipe-luis/profil/spieler/21725
# Nome                                                       Filipe Luís
# Posição                                                      Left-Back
# Idade                                                               28
# Valor de Mercado                                              15000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /atletico-madrid/startseite/verein/13/saison_i...
# Clube Antigo                                           Atlético Madrid
# URL Liga Antiga        /laliga/transfers/wettbewerb/ES1/saison_id/2014
# Liga Antiga                                                     LaLiga
# URL Clube Novo        /fc-chelsea/startseite/verein/631/saison_id/2014
# Clube Novo                                                     Chelsea
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                           20000000
# Ano da Tranferência                                               2014
# pe                                                                left
# data_nasc                                             Aug 9, 1985 (39)
# local_nasc                                              Jaraguá do Sul
# cidadania                                            2, Brazil, Poland
# altura                                                            1.82
# convocacoes                                                         44
# gols_selecao                                                         2
# ano_stat                                                          2013
# escalado                                                            50
# jogou                                                               49
# ppm                                                               2.35
# gols_para                                                            1
# assistencias                                                         6
# gols_contra                                                          1
# entrou                                                               -
# saiu                                                                 3
# amarelo                                                              7
# amarelo_duplo                                                        1
# vermelho                                                             1
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   4273
# minutos                                                           4273
#
#                                                                      5  \
# ID                                                               21725
# Perfil                               /filipe-luis/profil/spieler/21725
# Nome                                                       Filipe Luís
# Posição                                                      Left-Back
# Idade                                                               29
# Valor de Mercado                                              15000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo      /fc-chelsea/startseite/verein/631/saison_id/2015
# Clube Antigo                                                   Chelsea
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /atletico-madrid/startseite/verein/13/saison_i...
# Clube Novo                                             Atlético Madrid
# URL Liga Nova          /laliga/transfers/wettbewerb/ES1/saison_id/2015
# Liga Nova                                                       LaLiga
# Valor Transferência                                           16000000
# Ano da Tranferência                                               2015
# pe                                                                left
# data_nasc                                             Aug 9, 1985 (39)
# local_nasc                                              Jaraguá do Sul
# cidadania                                            2, Brazil, Poland
# altura                                                            1.82
# convocacoes                                                         44
# gols_selecao                                                         2
# ano_stat                                                          2014
# escalado                                                            50
# jogou                                                               26
# ppm                                                               2.23
# gols_para                                                            1
# assistencias                                                         1
# gols_contra                                                          -
# entrou                                                               6
# saiu                                                                 3
# amarelo                                                              4
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   1883
# minutos                                                           1883
#
#                                                                      6  \
# ID                                                               21725
# Perfil                               /filipe-luis/profil/spieler/21725
# Nome                                                       Filipe Luís
# Posição                                                      Left-Back
# Idade                                                               33
# Valor de Mercado                                               3000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /atletico-madrid/startseite/verein/13/saison_i...
# Clube Antigo                                           Atlético Madrid
# URL Liga Antiga        /laliga/transfers/wettbewerb/ES1/saison_id/2019
# Liga Antiga                                                     LaLiga
# URL Clube Novo       /flamengo-rio-de-janeiro/startseite/verein/614...
# Clube Novo                                                    Flamengo
# URL Liga Nova        /campeonato-brasileiro-serie-a/transfers/wettb...
# Liga Nova                                                      Série A
# Valor Transferência                                                  0
# Ano da Tranferência                                               2019
# pe                                                                left
# data_nasc                                             Aug 9, 1985 (39)
# local_nasc                                              Jaraguá do Sul
# cidadania                                            2, Brazil, Poland
# altura                                                            1.82
# convocacoes                                                         44
# gols_selecao                                                         2
# ano_stat                                                          2018
# escalado                                                            65
# jogou                                                               53
# ppm                                                               2.11
# gols_para                                                            2
# assistencias                                                         3
# gols_contra                                                          -
# entrou                                                               5
# saiu                                                                16
# amarelo                                                              9
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   2084
# minutos                                                           4167
#
#                                                                      7  \
# ID                                                              149498
# Perfil                         /gabriel-paulista/profil/spieler/149498
# Nome                                                  Gabriel Paulista
# Posição                                                    Centre-Back
# Idade                                                               24
# Valor de Mercado                                               8000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /fc-villarreal/startseite/verein/1050/saison_i...
# Clube Antigo                                                Villarreal
# URL Liga Antiga        /laliga/transfers/wettbewerb/ES1/saison_id/2014
# Liga Antiga                                                     LaLiga
# URL Clube Novo         /fc-arsenal/startseite/verein/11/saison_id/2014
# Clube Novo                                                     Arsenal
# URL Liga Nova        /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Nova                                               Premier League
# Valor Transferência                                           15000000
# Ano da Tranferência                                               2014
# pe                                                               right
# data_nasc                                            Nov 26, 1990 (34)
# local_nasc                                                   São Paulo
# cidadania                                    3, Brazil, Spain, Türkiye
# altura                                                            1.85
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2013
# escalado                                                            32
# jogou                                                               21
# ppm                                                               1.48
# gols_para                                                            -
# assistencias                                                         -
# gols_contra                                                          1
# entrou                                                               1
# saiu                                                                 -
# amarelo                                                              4
# amarelo_duplo                                                        1
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                      -
# minutos                                                           1789
#
#                                                                      8  \
# ID                                                              149498
# Perfil                         /gabriel-paulista/profil/spieler/149498
# Nome                                                  Gabriel Paulista
# Posição                                                    Centre-Back
# Idade                                                               26
# Valor de Mercado                                              13000000
# Nacionalidade                                                   Brazil
# URL Clube Antigo       /fc-arsenal/startseite/verein/11/saison_id/2017
# Clube Antigo                                                   Arsenal
# URL Liga Antiga      /premier-league/transfers/wettbewerb/GB1/saiso...
# Liga Antiga                                             Premier League
# URL Clube Novo       /fc-valencia/startseite/verein/1049/saison_id/...
# Clube Novo                                                    Valencia
# URL Liga Nova          /laliga/transfers/wettbewerb/ES1/saison_id/2017
# Liga Nova                                                       LaLiga
# Valor Transferência                                           11000000
# Ano da Tranferência                                               2017
# pe                                                               right
# data_nasc                                            Nov 26, 1990 (34)
# local_nasc                                                   São Paulo
# cidadania                                    3, Brazil, Spain, Türkiye
# altura                                                            1.85
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2016
# escalado                                                            47
# jogou                                                               27
# ppm                                                               1.96
# gols_para                                                            -
# assistencias                                                         -
# gols_contra                                                          -
# entrou                                                               5
# saiu                                                                 2
# amarelo                                                              7
# amarelo_duplo                                                        -
# vermelho                                                             -
# Gols_de_penalti                                                      -
# minutos_por_gol                                                      -
# minutos                                                           2217
#
#                                                                      9
# ID                                                              149498
# Perfil                         /gabriel-paulista/profil/spieler/149498
# Nome                                                  Gabriel Paulista
# Posição                                                    Centre-Back
# Idade                                                               33
# Valor de Mercado                                               2500000
# Nacionalidade                                                   Brazil
# URL Clube Antigo     /fc-valencia/startseite/verein/1049/saison_id/...
# Clube Antigo                                                  Valencia
# URL Liga Antiga        /laliga/transfers/wettbewerb/ES1/saison_id/2023
# Liga Antiga                                                     LaLiga
# URL Clube Novo       /atletico-madrid/startseite/verein/13/saison_i...
# Clube Novo                                             Atlético Madrid
# URL Liga Nova          /laliga/transfers/wettbewerb/ES1/saison_id/2023
# Liga Nova                                                       LaLiga
# Valor Transferência                                                  0
# Ano da Tranferência                                               2023
# pe                                                               right
# data_nasc                                            Nov 26, 1990 (34)
# local_nasc                                                   São Paulo
# cidadania                                    3, Brazil, Spain, Türkiye
# altura                                                            1.85
# convocacoes                                                          0
# gols_selecao                                                         0
# ano_stat                                                          2022
# escalado                                                            33
# jogou                                                               23
# ppm                                                               1.39
# gols_para                                                            1
# assistencias                                                         -
# gols_contra                                                          -
# entrou                                                               3
# saiu                                                                 3
# amarelo                                                              2
# amarelo_duplo                                                        1
# vermelho                                                             1
# Gols_de_penalti                                                      -
# minutos_por_gol                                                   1684
# minutos                                                           1684

# %%
# Substituir '-' por NaN
cols_to_clean = [
    "jogou", "gols_para", "assistencias", "gols_contra", 
    "entrou", "saiu", "amarelo", "amarelo_duplo", 
    "vermelho", "Gols_de_penalti", "minutos_por_gol", "minutos"
]

df_final[cols_to_clean] = df_final[cols_to_clean].replace('-', pd.NA)
# Convertemos para inteiros, substituindo NaN por 0 (se necessário)
#df_final[cols_to_clean] = df_final[cols_to_clean].astype("int64")

# %%
df_final.shape
# Out:
# (2068, 39)

# %%
num_duplicatas = df_final.duplicated().sum()
print(f"Número de linhas duplicadas: {num_duplicatas}")
# Out:
# Número de linhas duplicadas: 174

# %%
df_final['minutos_por_gol'] = df_final['minutos_por_gol'].apply(lambda x: str(x)[:-3] if str(x).endswith('000') else x)
df_final['minutos'] = df_final['minutos'].apply(lambda x: str(x)[:-3] if str(x).endswith('000') else x)

# %%
df_final=df_final.drop_duplicates()
df_final.to_csv('04-DF.csv', index=True)

# %%
df_final.shape
# Out:
# (1894, 39)
